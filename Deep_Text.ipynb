# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/My Drive/last.csv",engine="python")

# %%
from gensim import models
# model2 = models.Word2Vec.load_word2vec_format('GoogleNews-vectors-negative300.bin', binary=True) 
model2 = models.KeyedVectors.load_word2vec_format('/content/drive/My Drive/GoogleNews-vectors-negative300.bin', binary=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:253: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
print(model2['king'].shape)
print(model2['dog'].shape)
# Out:
# (300,)
# (300,)

# %%
# !pip install stop_words
# Out:
# Collecting stop_words
#   Downloading https://files.pythonhosted.org/packages/1c/cb/d58290804b7a4c5daa42abbbe2a93c477ae53e45541b1825e86f0dfaaf63/stop-words-2018.7.23.tar.gz
# Building wheels for collected packages: stop-words
#   Building wheel for stop-words (setup.py) ... done
#   Created wheel for stop-words: filename=stop_words-2018.7.23-cp36-none-any.whl size=32917 sha256=e357f5ca5c6dd7f2b40f8d6439f40494b8af0a46249b4be7d429015a460f2d09
#   Stored in directory: /root/.cache/pip/wheels/75/37/6a/2b295e03bd07290f0da95c3adb9a74ba95fbc333aa8b0c7c78
# Successfully built stop-words
# Installing collected packages: stop-words
# Successfully installed stop-words-2018.7.23

# %%
from nltk.tokenize import RegexpTokenizer
from stop_words import get_stop_words
tokenizer = RegexpTokenizer(r'\w+')

en_stop = get_stop_words('en')

# %%
len(en_stop)
# Out:
# 174

# %%
import numpy as np

movie_mean_wordvec=np.zeros((len(df),300))
movie_mean_wordvec.shape
# Out:
# (79244, 300)

# %%
from ast import literal_eval
df.genre_ids=df.genre_ids.apply(literal_eval)

# %%
genres=[]
rows_to_delete=[]
for i in range(len(df)):
    movie_genres=df.genre_ids[i]
    genres.append(movie_genres)
    overview=df.overview[i]
    tokens = tokenizer.tokenize(overview)
    stopped_tokens = [k for k in tokens if not k in en_stop]
    count_in_vocab=0
    s=0
    if len(stopped_tokens)==0:
        rows_to_delete.append(i)
        genres.pop(-1)
#         print(overview)
#         print("sample ",i,"had no nonstops")
    else:
        for tok in stopped_tokens:
            if tok.lower() in model2.vocab:
                count_in_vocab+=1
                s+=model2[tok.lower()]
        if count_in_vocab!=0:
            movie_mean_wordvec[i]=s/float(count_in_vocab)
        else:
            rows_to_delete.append(i)
            genres.pop(-1)
#             print(overview)
#             print("sample ",i,"had no word2vec")

# %%
mask2=[]
for row in range(len(movie_mean_wordvec)):
    if row in rows_to_delete:
        mask2.append(False)
    else:
        mask2.append(True)

# %%
X=movie_mean_wordvec[mask2]

# %%
X.shape
# Out:
# (79238, 300)

# %%
from sklearn.preprocessing import MultiLabelBinarizer
mlb = MultiLabelBinarizer()

Y=mlb.fit_transform(genres)
Y.shape
# Out:
# (79238, 19)

# %%
import pickle

textual_features=(X,Y)
f9=open('textual_features.pckl','wb')
pickle.dump(textual_features,f9)
f9.close()

# %%
import pickle
# textual_features=(X,Y)
f9=open('/content/drive/My Drive/textual_features.pckl','rb')
textual_features=pickle.load(f9)
f9.close()

# %%
(X,Y)=textual_features

print(X.shape)
print(Y.shape)
# Out:
# (79238, 300)
# (79238, 14)

# %%
import numpy as np
mask_text=np.random.rand(len(X))<0.8

X_train=X[mask_text]
Y_train=Y[mask_text]
X_test=X[~mask_text]
Y_test=Y[~mask_text]

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation

model_textual = Sequential([
    Dense(300, input_shape=(300,)),
    Activation('relu'),
    Dense(14),
    Activation('softmax'),
])

model_textual.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
model_textual.fit(X_train, Y_train, epochs=10, batch_size=500)
# Out:
# Epoch 1/10
# 63383/63383 [==============================] - 2s 36us/step - loss: 1.3641 - accuracy: 0.4654
# Epoch 2/10
# 63383/63383 [==============================] - 1s 9us/step - loss: 1.3465 - accuracy: 0.4654
# Epoch 3/10
# 63383/63383 [==============================] - 1s 9us/step - loss: 1.3414 - accuracy: 0.4655
# Epoch 4/10
# 63383/63383 [==============================] - 1s 10us/step - loss: 1.3382 - accuracy: 0.4655
# Epoch 5/10
# 63383/63383 [==============================] - 1s 9us/step - loss: 1.3359 - accuracy: 0.4655
# Epoch 6/10
# 63383/63383 [==============================] - 1s 9us/step - loss: 1.3340 - accuracy: 0.4655
# Epoch 7/10
# 63383/63383 [==============================] - 1s 9us/step - loss: 1.3324 - accuracy: 0.4655
# Epoch 8/10
# 63383/63383 [==============================] - 1s 9us/step - loss: 1.3310 - accuracy: 0.4655
# Epoch 9/10
# 63383/63383 [==============================] - 1s 9us/step - loss: 1.3298 - accuracy: 0.4655
# Epoch 10/10
# 63383/63383 [==============================] - 1s 10us/step - loss: 1.3288 - accuracy: 0.4655

# %%
model_textual.fit(X_train, Y_train, epochs=10000, batch_size=500,verbose = 0)

# %%
score = model_textual.evaluate(X_test, Y_test, batch_size=249)
print(score)
# Out:
# 15855/15855 [==============================] - 0s 11us/step
# [1.4957971551334848, 0.4728701412677765]

# %%
print("%s: %.2f%%" % (model_textual.metrics_names[1], score[1]*100))
# Out:
# accuracy: 47.29%

# %%
Y_preds=model_textual.predict(X_test)

# %%
# !pip install tmdbsimple
import tmdbsimple as tmdb
# Out:
# Collecting tmdbsimple
#   Downloading https://files.pythonhosted.org/packages/04/81/10dcd72324b032333df76c223bac4598d45c806ad8b207f208dae3972046/tmdbsimple-2.2.3-py2.py3-none-any.whl
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from tmdbsimple) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->tmdbsimple) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->tmdbsimple) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->tmdbsimple) (2020.4.5.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->tmdbsimple) (3.0.4)
# Installing collected packages: tmdbsimple
# Successfully installed tmdbsimple-2.2.3

# %%
api_key = "d0ccc864ded48afb6a7e28b2d32001ed"
tmdb.API_KEY = api_key
genres=tmdb.Genres()
list_of_genres=genres.movie_list()['genres']
Genre_ID_to_name={}
for i in range(len(list_of_genres)):
  genre_id=list_of_genres[i]['id']
  genre_name=list_of_genres[i]['name']
  Genre_ID_to_name[genre_id]=genre_name

# %%
genre_list=sorted(list(Genre_ID_to_name.keys()))

# %%
def precision_recall(gt,preds):
   TP=0
   FP=0
   FN=0
   for t in gt:
       if t in preds:
           TP+=1
       else:
           FN+=1
   for p in preds:
       if p not in gt:
           FP+=1
   if TP+FP==0:
       precision=0
   else:
       precision=TP/float(TP+FP)
   if TP+FN==0:
       recall=0
   else:
       recall=TP/float(TP+FN)
   return precision,recall

# %%
print("Our predictions for the movies are - \n")
precs=[]
recs=[]
for i in range(len(Y_preds)):
    row=Y_preds[i]
    gt_genres=Y_test[i]
    gt_genre_names=[]
    for j in range(14):
        if gt_genres[j]==1:
            gt_genre_names.append(Genre_ID_to_name[genre_list[j]])
    top_3=np.argsort(row)[-3:]
    predicted_genres=[]
    for genre in top_3:
        predicted_genres.append(Genre_ID_to_name[genre_list[genre]])
    (precision,recall)=precision_recall(gt_genre_names,predicted_genres)
    precs.append(precision)
    recs.append(recall)
    if i%50==0:
        print("Predicted: ",predicted_genres," Actual: ",gt_genre_names)
# Out:
# Our predictions for the movies are -
#
# Predicted:  ['Fantasy', 'History', 'Action']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Horror', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Thriller', 'Mystery', 'Science Fiction']  Actual:  ['Adventure', 'Fantasy', 'Horror', 'Thriller', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Western']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Horror', 'Comedy', 'History', 'Thriller', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Thriller', 'Mystery', 'Science Fiction']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Horror', 'Comedy', 'Thriller', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Horror', 'History', 'Action']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Horror', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Western']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Horror', 'Action', 'History', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Fantasy', 'Adventure', 'Horror']  Actual:  ['Adventure', 'Fantasy', 'Horror', 'Action', 'History', 'Thriller', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Action']  Actual:  ['Adventure', 'Fantasy', 'Horror', 'Action', 'History', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Fantasy', 'Crime', 'Horror']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Horror', 'Comedy', 'Thriller', 'Crime', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Horror', 'Science Fiction', 'Mystery']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Horror', 'Action', 'History', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Adventure', 'Fantasy', 'Crime']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Horror', 'Action', 'History', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'Science Fiction', 'Crime']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Horror', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Thriller']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Horror', 'Action', 'History', 'Thriller', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Adventure', 'Fantasy', 'Comedy']  Actual:  ['Adventure', 'Fantasy', 'Horror', 'Thriller', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'Science Fiction', 'Horror']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Horror', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['History', 'Science Fiction', 'Mystery']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Horror', 'Action', 'Comedy', 'History', 'Thriller', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['History', 'Science Fiction', 'Mystery']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Horror', 'History', 'Thriller', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'Action', 'History']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Horror', 'Action', 'History', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['History', 'Fantasy', 'Adventure']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Horror', 'Action', 'History', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Animation', 'Comedy', 'Documentary']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Horror', 'Comedy', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Crime', 'History', 'Action']  Actual:  ['Horror', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Adventure', 'Science Fiction', 'Mystery']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Horror', 'Action', 'History', 'Western', 'Thriller', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Horror']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Horror', 'Action', 'History', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Crime']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Horror', 'Comedy', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'Thriller', 'Horror']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Horror', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Drama', 'Mystery', 'Science Fiction']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Horror', 'Action', 'History', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'Science Fiction', 'Crime']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Horror', 'Action', 'Comedy', 'History', 'Western', 'Crime', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Crime']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Horror', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Adventure', 'Fantasy', 'Crime']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Horror', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Horror']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Horror', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Fantasy', 'Adventure', 'Crime']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Horror', 'Action', 'History', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Crime', 'History', 'Action']  Actual:  ['Horror', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Fantasy', 'Science Fiction', 'Mystery']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Horror', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Animation']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Horror', 'Action', 'History', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Action', 'Mystery', 'Science Fiction']  Actual:  ['Horror', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Fantasy', 'Crime', 'Horror']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Horror', 'History', 'Thriller', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Adventure', 'Fantasy', 'Thriller']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Horror', 'Comedy', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Crime', 'Mystery', 'Science Fiction']  Actual:  ['Horror', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Crime']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Horror', 'Action', 'History', 'Thriller', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Drama']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Horror', 'Action', 'Comedy', 'History', 'Western', 'Science Fiction', 'Mystery']
# Predicted:  ['Drama', 'Science Fiction', 'Mystery']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Horror', 'Comedy', 'Thriller', 'Crime', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Action', 'Science Fiction', 'Mystery']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Horror', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Drama']  Actual:  ['Drama', 'Horror', 'Science Fiction', 'Mystery']
# Predicted:  ['Western', 'Fantasy', 'Adventure']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Horror', 'Western', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Fantasy', 'Adventure', 'Comedy']  Actual:  ['Drama', 'Horror', 'Science Fiction', 'Mystery']
# Predicted:  ['Thriller', 'Mystery', 'Science Fiction']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Horror', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Horror']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Horror', 'Action', 'Comedy', 'History', 'Science Fiction', 'Mystery']
# Predicted:  ['Adventure', 'Crime', 'Action']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Horror', 'Action', 'History', 'Science Fiction', 'Mystery']
# Predicted:  ['Thriller', 'Science Fiction', 'Mystery']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Horror', 'Action', 'History', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Documentary', 'Western']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Horror', 'Comedy', 'History', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['Crime', 'Adventure', 'Fantasy']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Horror', 'Thriller', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Thriller']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Horror', 'Action', 'Comedy', 'History', 'Thriller', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'Comedy', 'Documentary']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Horror', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Adventure', 'Fantasy', 'Horror']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Horror', 'Action', 'History', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Horror', 'Science Fiction', 'Mystery']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Comedy', 'History', 'Western', 'Thriller', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Fantasy', 'Science Fiction', 'Mystery']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Action', 'History', 'Western', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['Crime', 'Adventure', 'Fantasy']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Western', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'Drama', 'Western']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'History', 'Western', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['Fantasy', 'Crime', 'Western']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Comedy', 'History', 'Western', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Documentary']  Actual:  ['Drama', 'Western', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'Science Fiction', 'Western']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Action', 'History', 'Western', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['Drama', 'Science Fiction', 'Mystery']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Western', 'Thriller', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Western']  Actual:  ['Drama', 'Western', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'Crime', 'Thriller']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Action', 'History', 'Western', 'Science Fiction', 'Mystery']
# Predicted:  ['Western', 'Documentary', 'Comedy']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Western', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'History', 'Action']  Actual:  ['Drama', 'Western', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Western']  Actual:  ['Drama', 'Western', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Documentary']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Western', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Drama', 'Science Fiction', 'Mystery']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Horror', 'Comedy', 'Western', 'Science Fiction', 'Mystery']
# Predicted:  ['Drama', 'Mystery', 'Science Fiction']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Action', 'Comedy', 'History', 'Western', 'Science Fiction', 'Mystery']
# Predicted:  ['Fantasy', 'Adventure', 'Drama']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Action', 'History', 'Western', 'Science Fiction', 'Mystery']
# Predicted:  ['Western', 'Science Fiction', 'Mystery']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Horror', 'Comedy', 'Western', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Drama']  Actual:  ['Drama', 'Western', 'Science Fiction', 'Mystery']
# Predicted:  ['Adventure', 'History', 'Action']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Action', 'History', 'Western', 'Science Fiction', 'Mystery']
# Predicted:  ['Horror', 'Science Fiction', 'Mystery']  Actual:  ['Drama', 'Western', 'Science Fiction', 'Mystery']
# Predicted:  ['Drama', 'Comedy', 'Western']  Actual:  ['Drama', 'Western', 'Science Fiction', 'Mystery']
# Predicted:  ['Thriller', 'Science Fiction', 'Mystery']  Actual:  ['Drama', 'Western', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Western']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Action', 'History', 'Western', 'Science Fiction', 'Mystery']
# Predicted:  ['Adventure', 'Fantasy', 'History']  Actual:  ['Drama', 'Western', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Action']  Actual:  ['Drama', 'Western', 'Science Fiction', 'Mystery']
# Predicted:  ['Drama', 'Comedy', 'Western']  Actual:  ['Drama', 'Western', 'Science Fiction', 'Mystery']
# Predicted:  ['Horror', 'Science Fiction', 'Mystery']  Actual:  ['Drama', 'Western', 'Science Fiction', 'Mystery']
# Predicted:  ['Fantasy', 'Animation', 'Comedy']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Horror', 'Comedy', 'Western', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Animation', 'Drama', 'Western']  Actual:  ['Drama', 'Western', 'Science Fiction', 'Mystery']
# Predicted:  ['Thriller', 'Drama', 'Animation']  Actual:  ['Drama', 'Western', 'Science Fiction', 'Mystery']
# Predicted:  ['Comedy', 'Science Fiction', 'Mystery']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Horror', 'Action', 'Comedy', 'History', 'Thriller', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Crime', 'History', 'Action']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Action', 'History', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Comedy', 'Animation', 'Drama']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Action', 'Comedy', 'History', 'Science Fiction', 'Mystery']
# Predicted:  ['Action', 'Comedy', 'Documentary']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Action', 'Comedy', 'History', 'Thriller', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'Science Fiction', 'Documentary']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Action', 'Comedy', 'History', 'Thriller', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Fantasy', 'Mystery', 'Science Fiction']  Actual:  ['Action', 'History', 'Science Fiction', 'Mystery']
# Predicted:  ['Adventure', 'Fantasy', 'Animation']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Action', 'History', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Horror', 'Mystery', 'Science Fiction']  Actual:  ['Adventure', 'Fantasy', 'Horror', 'Action', 'History', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Action', 'History']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Action', 'History', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['Adventure', 'Crime', 'Animation']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Action', 'Comedy', 'History', 'Thriller', 'Crime', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Thriller', 'Mystery', 'Science Fiction']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Action', 'History', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'History', 'Action']  Actual:  ['Action', 'History', 'Science Fiction', 'Mystery']
# Predicted:  ['Thriller', 'Science Fiction', 'Mystery']  Actual:  ['Action', 'History', 'Science Fiction', 'Mystery']
# Predicted:  ['Drama', 'History', 'Action']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Action', 'Comedy', 'History', 'Thriller', 'Crime', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Comedy', 'Documentary']  Actual:  ['Action', 'History', 'Science Fiction', 'Mystery']
# Predicted:  ['Horror', 'Science Fiction', 'Mystery']  Actual:  ['Adventure', 'Fantasy', 'Horror', 'Action', 'History', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['Documentary', 'Comedy', 'Animation']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Horror', 'Action', 'Comedy', 'History', 'Thriller', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Action', 'Science Fiction', 'Mystery']  Actual:  ['Action', 'History', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'Science Fiction', 'Horror']  Actual:  ['Adventure', 'Fantasy', 'Horror', 'Action', 'History', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['Fantasy', 'Adventure', 'Crime']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Horror', 'Action', 'History', 'Thriller', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Action', 'Science Fiction', 'Mystery']  Actual:  ['Adventure', 'Fantasy', 'Horror', 'Action', 'Comedy', 'History', 'Western', 'Thriller', 'Crime', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Fantasy', 'Horror', 'Thriller']  Actual:  ['Adventure', 'Fantasy', 'Horror', 'Action', 'History', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'Action', 'History']  Actual:  ['Action', 'History', 'Science Fiction', 'Mystery']
# Predicted:  ['Action', 'Documentary', 'Comedy']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Action', 'Comedy', 'History', 'Thriller', 'Crime', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Animation', 'Comedy', 'Documentary']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Action', 'Comedy', 'History', 'Thriller', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Animation', 'Adventure', 'Fantasy']  Actual:  ['Action', 'History', 'Science Fiction', 'Mystery']
# Predicted:  ['Documentary', 'History', 'Action']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Action', 'History', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Drama', 'Comedy', 'Animation']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Action', 'Comedy', 'History', 'Thriller', 'Crime', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['History', 'Documentary', 'Comedy']  Actual:  ['Action', 'History', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'Science Fiction', 'Documentary']  Actual:  ['Adventure', 'Fantasy', 'Action', 'Comedy', 'History', 'Western', 'Crime', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Western', 'Science Fiction', 'Mystery']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Action', 'History', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Adventure', 'History', 'Action']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Action', 'Comedy', 'History', 'Western', 'Crime', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Thriller', 'History', 'Action']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Action', 'History', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'Science Fiction', 'Crime']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['History', 'Action', 'Western']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Horror', 'Action', 'History', 'Thriller', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Crime', 'Drama', 'Animation']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Action', 'History', 'Thriller', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Crime']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Action', 'History', 'Thriller', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Western']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Action', 'Comedy', 'History', 'Thriller', 'Crime', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Crime', 'History', 'Action']  Actual:  ['Animation', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'Thriller', 'Horror']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Horror', 'Action', 'Comedy', 'History', 'Western', 'Thriller', 'Crime', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Animation', 'Documentary', 'Comedy']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Animation', 'Science Fiction', 'Mystery']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Adventure', 'Fantasy', 'Western']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Crime', 'Science Fiction', 'Mystery']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Action', 'History', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Drama', 'Science Fiction', 'Mystery']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Drama', 'Mystery', 'Science Fiction']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Action', 'Comedy', 'History', 'Western', 'Crime', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'Thriller', 'Action']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Comedy', 'Western', 'Crime', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'History']  Actual:  ['Animation', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'History', 'Action']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Documentary']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Action', 'History', 'Western', 'Crime', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Adventure', 'Fantasy', 'Western']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Action', 'Comedy', 'History', 'Western', 'Crime', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Western', 'History', 'Action']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Horror', 'Western', 'Thriller', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'History', 'Action']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Comedy', 'Western', 'Crime', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Fantasy', 'Adventure', 'Crime']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Horror', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Documentary']  Actual:  ['Adventure', 'Fantasy', 'Action', 'Western', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Adventure', 'Horror', 'Comedy']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Horror', 'Comedy', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Drama', 'Science Fiction', 'Mystery']  Actual:  ['Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'Comedy', 'Documentary']  Actual:  ['Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Documentary']  Actual:  ['Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Documentary', 'Science Fiction', 'Mystery']  Actual:  ['Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'Science Fiction', 'Documentary']  Actual:  ['Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Documentary', 'Mystery', 'Science Fiction']  Actual:  ['Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'Science Fiction', 'Documentary']  Actual:  ['Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'Science Fiction', 'Documentary']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Thriller', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Drama', 'Mystery', 'Science Fiction']  Actual:  ['Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'Science Fiction', 'Documentary']  Actual:  ['Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Adventure', 'Fantasy', 'Horror']  Actual:  ['Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Comedy']  Actual:  ['Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Documentary', 'Science Fiction', 'Mystery']  Actual:  ['Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Thriller', 'Science Fiction', 'Mystery']  Actual:  ['Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'Crime', 'Documentary']  Actual:  ['Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Comedy', 'Horror', 'Animation']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Horror', 'Comedy', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'Science Fiction', 'Animation']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Horror', 'Comedy', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Documentary']  Actual:  ['Adventure', 'Fantasy', 'Action', 'History', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Western']  Actual:  ['Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Drama', 'Science Fiction', 'Mystery']  Actual:  ['Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Western', 'Documentary']  Actual:  ['Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'Science Fiction', 'Documentary']  Actual:  ['Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Documentary', 'Mystery', 'Science Fiction']  Actual:  ['Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Adventure', 'Horror', 'History']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Horror', 'History', 'Thriller', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Adventure', 'Fantasy', 'Documentary']  Actual:  ['Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Documentary', 'Mystery', 'Science Fiction']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Horror', 'Comedy', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Documentary']  Actual:  ['Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Documentary']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Crime', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Western', 'Documentary']  Actual:  ['Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Documentary', 'Mystery', 'Science Fiction']  Actual:  ['Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Documentary', 'Mystery', 'Science Fiction']  Actual:  ['Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Drama', 'Mystery', 'Science Fiction']  Actual:  ['Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Adventure', 'Science Fiction', 'Mystery']  Actual:  ['Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Documentary']  Actual:  ['Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Fantasy', 'Animation', 'Comedy']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Comedy', 'Thriller', 'Crime', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Animation', 'Drama', 'Crime']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Action', 'Western', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'Science Fiction', 'Horror']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Horror', 'Action', 'History', 'Thriller', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Drama', 'Science Fiction', 'Mystery']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Comedy', 'Thriller', 'Crime', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'Science Fiction', 'History']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'History', 'Thriller', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Thriller', 'Mystery', 'Science Fiction']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Horror', 'Thriller', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Horror', 'History', 'Action']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Action', 'History', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'Science Fiction', 'Documentary']  Actual:  ['Drama', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Documentary', 'Mystery', 'Science Fiction']  Actual:  ['Drama', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Fantasy', 'Adventure']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Comedy', 'Thriller', 'Crime', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Fantasy', 'Comedy', 'Thriller']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Comedy', 'History', 'Western', 'Thriller', 'Crime', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Western', 'Adventure', 'Fantasy']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Action', 'History', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Comedy', 'Science Fiction', 'Mystery']  Actual:  ['Drama', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Crime', 'Science Fiction', 'Mystery']  Actual:  ['Drama', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Drama', 'Science Fiction', 'Mystery']  Actual:  ['Drama', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Thriller', 'Mystery', 'Science Fiction']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Action', 'Thriller', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Drama', 'Science Fiction', 'Mystery']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Horror', 'Comedy', 'Thriller', 'Crime', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Crime', 'History', 'Action']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Action', 'History', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Drama', 'Comedy', 'Animation']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Horror', 'Comedy', 'History', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'Fantasy', 'Adventure']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'History', 'Thriller', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Drama', 'Fantasy', 'Adventure']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Action', 'History', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['Fantasy', 'Drama', 'Crime']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Action', 'History', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Action', 'History']  Actual:  ['Animation', 'Drama', 'History', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['Drama', 'Science Fiction', 'Mystery']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Action', 'History', 'Thriller', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Thriller', 'History']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Action', 'History', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['Thriller', 'Animation', 'Documentary']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'History', 'Thriller', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Crime', 'Science Fiction', 'Mystery']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'History', 'Thriller', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Animation', 'Drama', 'Western']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'History', 'Western', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'History', 'Action']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Action', 'History', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Horror']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Horror', 'Action', 'Comedy', 'History', 'Western', 'Thriller', 'Crime', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Fantasy', 'Adventure', 'Crime']  Actual:  ['Drama', 'Comedy', 'Science Fiction', 'Mystery']
# Predicted:  ['Drama', 'Science Fiction', 'Mystery']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Comedy', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'Action', 'History']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Action', 'Comedy', 'History', 'Western', 'Crime', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'Science Fiction', 'History']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Comedy', 'Western', 'Crime', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Adventure', 'Fantasy', 'Thriller']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Comedy', 'Western', 'Crime', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Drama']  Actual:  ['Drama', 'Comedy', 'Science Fiction', 'Mystery']
# Predicted:  ['Drama', 'Mystery', 'Science Fiction']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Horror', 'Comedy', 'Thriller', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Documentary']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Action', 'Comedy', 'Western', 'Thriller', 'Crime', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Documentary', 'Western']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Horror', 'Action', 'History', 'Western', 'Thriller', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Documentary', 'Science Fiction', 'Mystery']  Actual:  ['Adventure', 'Fantasy', 'Action', 'Western', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Horror']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Horror', 'Action', 'Comedy', 'History', 'Western', 'Thriller', 'Crime', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'Documentary', 'Western']  Actual:  ['Adventure', 'Fantasy', 'Action', 'Western', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Adventure', 'Science Fiction', 'Mystery']  Actual:  ['Action', 'Western', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Horror']  Actual:  ['Horror', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'Thriller', 'Horror']  Actual:  ['Horror', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'Science Fiction', 'History']  Actual:  ['Horror', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'Science Fiction', 'Horror']  Actual:  ['Horror', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Action']  Actual:  ['Adventure', 'Fantasy', 'Horror', 'Action', 'Comedy', 'History', 'Western', 'Thriller', 'Crime', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'History', 'Action']  Actual:  ['Adventure', 'Fantasy', 'Horror', 'Action', 'History', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'History', 'Action']  Actual:  ['Adventure', 'Fantasy', 'Horror', 'Action', 'History', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'Science Fiction', 'Crime']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Horror', 'Thriller', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Thriller', 'Science Fiction', 'Mystery']  Actual:  ['Adventure', 'Fantasy', 'Horror', 'Thriller', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Thriller', 'Science Fiction', 'Mystery']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Horror', 'Thriller', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Thriller', 'Horror']  Actual:  ['Horror', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Horror']  Actual:  ['Adventure', 'Fantasy', 'Horror', 'Action', 'History', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['Adventure', 'Mystery', 'Science Fiction']  Actual:  ['Adventure', 'Fantasy', 'Horror', 'Action', 'History', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Horror', 'Thriller']  Actual:  ['Horror', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['Horror', 'Science Fiction', 'Mystery']  Actual:  ['Horror', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['Western', 'Science Fiction', 'Mystery']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Horror', 'Comedy', 'Western', 'Thriller', 'Crime', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'History', 'Action']  Actual:  ['Horror', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['Horror', 'Mystery', 'Science Fiction']  Actual:  ['Horror', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['Adventure', 'Fantasy', 'Thriller']  Actual:  ['Adventure', 'Fantasy', 'Horror', 'Action', 'History', 'Thriller', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Animation', 'Thriller', 'Horror']  Actual:  ['Horror', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['Crime', 'Adventure', 'Fantasy']  Actual:  ['Horror', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Action']  Actual:  ['Adventure', 'Fantasy', 'Horror', 'Action', 'History', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'Horror', 'Thriller']  Actual:  ['Adventure', 'Fantasy', 'Horror', 'Action', 'History', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['Animation', 'Science Fiction', 'Mystery']  Actual:  ['Animation', 'Drama', 'Horror', 'Comedy', 'Science Fiction', 'Mystery']
# Predicted:  ['Drama', 'Horror', 'Animation']  Actual:  ['Animation', 'Drama', 'Horror', 'Comedy', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Documentary', 'Comedy']  Actual:  ['Animation', 'Drama', 'Horror', 'Comedy', 'Science Fiction', 'Mystery']
# Predicted:  ['Adventure', 'Fantasy', 'Drama']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Horror', 'Comedy', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Fantasy', 'Adventure', 'Comedy']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Horror', 'Action', 'Comedy', 'History', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Drama']  Actual:  ['Animation', 'Drama', 'Horror', 'Comedy', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Documentary']  Actual:  ['Animation', 'Drama', 'Horror', 'Comedy', 'Science Fiction', 'Mystery']
# Predicted:  ['Documentary', 'Mystery', 'Science Fiction']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Horror', 'Comedy', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Animation', 'Documentary', 'Comedy']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Horror', 'Comedy', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'Horror', 'Comedy']  Actual:  ['Animation', 'Drama', 'Horror', 'Comedy', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Horror']  Actual:  ['Animation', 'Drama', 'Horror', 'Comedy', 'Science Fiction', 'Mystery']
# Predicted:  ['Horror', 'Animation', 'Comedy']  Actual:  ['Animation', 'Drama', 'Horror', 'Comedy', 'Science Fiction', 'Mystery']
# Predicted:  ['Animation', 'Horror', 'Comedy']  Actual:  ['Animation', 'Drama', 'Horror', 'Comedy', 'Science Fiction', 'Mystery']
# Predicted:  ['Animation', 'Comedy', 'Horror']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Horror', 'Action', 'Comedy', 'History', 'Thriller', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Action', 'Science Fiction', 'Mystery']  Actual:  ['Animation', 'Drama', 'Horror', 'Comedy', 'Science Fiction', 'Mystery']
# Predicted:  ['Documentary', 'Science Fiction', 'Mystery']  Actual:  ['Animation', 'Drama', 'Horror', 'Comedy', 'Science Fiction', 'Mystery']
# Predicted:  ['Animation', 'Drama', 'Comedy']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Horror', 'Action', 'Comedy', 'History', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Horror']  Actual:  ['Animation', 'Drama', 'Horror', 'Comedy', 'Science Fiction', 'Mystery']
# Predicted:  ['Animation', 'Drama', 'Comedy']  Actual:  ['Animation', 'Drama', 'Horror', 'Comedy', 'Science Fiction', 'Mystery']
# Predicted:  ['Animation', 'Drama', 'Comedy']  Actual:  ['Animation', 'Drama', 'Horror', 'Comedy', 'Science Fiction', 'Mystery']
# Predicted:  ['Drama', 'Horror', 'Animation']  Actual:  ['Animation', 'Drama', 'Horror', 'Comedy', 'Science Fiction', 'Mystery']
# Predicted:  ['Animation', 'History', 'Comedy']  Actual:  ['Animation', 'Drama', 'Horror', 'Comedy', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Comedy', 'Documentary']  Actual:  ['Animation', 'Drama', 'Horror', 'Comedy', 'Science Fiction', 'Mystery']
# Predicted:  ['Horror', 'Science Fiction', 'Mystery']  Actual:  ['Animation', 'Drama', 'Horror', 'Comedy', 'Science Fiction', 'Mystery']
# Predicted:  ['Drama', 'Science Fiction', 'Mystery']  Actual:  ['Animation', 'Drama', 'Horror', 'Comedy', 'Science Fiction', 'Mystery']
# Predicted:  ['Thriller', 'Science Fiction', 'Mystery']  Actual:  ['Adventure', 'Fantasy', 'Action', 'Comedy', 'History', 'Western', 'Crime', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Drama', 'Animation', 'Comedy']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Comedy', 'Western', 'Thriller', 'Crime', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['History', 'Action', 'Western']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Comedy', 'Western', 'Thriller', 'Crime', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Thriller', 'Animation', 'Comedy']  Actual:  ['Adventure', 'Fantasy', 'Action', 'Comedy', 'History', 'Western', 'Crime', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Animation', 'Comedy', 'Documentary']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Action', 'Comedy', 'History', 'Western', 'Crime', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Crime', 'Science Fiction', 'Mystery']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Comedy', 'Western', 'Crime', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Crime', 'Drama', 'Comedy']  Actual:  ['Comedy', 'Western', 'Crime', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Thriller', 'Comedy', 'Documentary']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Comedy', 'Thriller', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'Science Fiction', 'History']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Comedy', 'Thriller', 'Crime', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Comedy', 'Animation', 'Documentary']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Comedy', 'Thriller', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'History']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Comedy', 'Thriller', 'Crime', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Animation', 'Horror', 'Comedy']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Action', 'Comedy', 'History', 'Thriller', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Action', 'History', 'Comedy']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Action', 'Comedy', 'History', 'Thriller', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Fantasy', 'Science Fiction', 'Mystery']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Action', 'Comedy', 'History', 'Thriller', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Fantasy', 'Adventure', 'Action']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Action', 'Comedy', 'History', 'Thriller', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Adventure', 'Drama', 'Comedy']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Action', 'Comedy', 'History', 'Thriller', 'Crime', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Fantasy', 'Action', 'History']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Action', 'Comedy', 'History', 'Thriller', 'Crime', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Thriller', 'History', 'Action']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Comedy', 'Thriller', 'Crime', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Action', 'History']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Action', 'Comedy', 'History', 'Thriller', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Drama', 'Animation', 'Comedy']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Comedy', 'Thriller', 'Crime', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Action', 'Mystery', 'Science Fiction']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Action', 'Comedy', 'History', 'Thriller', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Crime', 'Mystery', 'Science Fiction']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Action', 'History', 'Thriller', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'Thriller', 'Horror']  Actual:  ['Adventure', 'Fantasy', 'Action', 'History', 'Thriller', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Crime', 'Science Fiction', 'Mystery']  Actual:  ['Adventure', 'Fantasy', 'Action', 'History', 'Thriller', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Fantasy', 'Mystery', 'Science Fiction']  Actual:  ['Adventure', 'Fantasy', 'Thriller', 'Crime', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Animation', 'Comedy', 'Drama']  Actual:  ['Adventure', 'Fantasy', 'Horror', 'Thriller', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Crime', 'Science Fiction', 'Mystery']  Actual:  ['Adventure', 'Fantasy', 'Horror', 'Thriller', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Comedy', 'Western']  Actual:  ['Thriller', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Thriller', 'Science Fiction', 'Mystery']  Actual:  ['Adventure', 'Fantasy', 'Action', 'History', 'Thriller', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Thriller', 'Mystery', 'Science Fiction']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Action', 'History', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['History', 'Action', 'Western']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Action', 'History', 'Thriller', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Fantasy', 'Adventure', 'History']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Thriller', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Fantasy', 'History', 'Action']  Actual:  ['Animation', 'Drama', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['Documentary', 'Mystery', 'Science Fiction']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Thriller', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'Western', 'Documentary']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Thriller', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Fantasy', 'Science Fiction', 'Mystery']  Actual:  ['Action', 'History', 'Science Fiction', 'Mystery']
# Predicted:  ['History', 'Mystery', 'Science Fiction']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Action', 'History', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'Adventure', 'Fantasy']  Actual:  ['Action', 'History', 'Science Fiction', 'Mystery']
# Predicted:  ['Crime', 'Fantasy', 'Adventure']  Actual:  ['Adventure', 'Fantasy', 'Drama', 'Action', 'History', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Adventure', 'Action', 'History']  Actual:  ['Animation', 'Drama', 'Horror', 'History', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['Adventure', 'Action', 'History']  Actual:  ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Horror', 'History', 'Thriller', 'Crime', 'Science Fiction', 'Mystery']
# Predicted:  ['Adventure', 'Crime', 'Horror']  Actual:  ['Animation', 'Drama', 'Horror', 'History', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['Comedy', 'Animation', 'Thriller']  Actual:  ['Action', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['Crime', 'Science Fiction', 'Mystery']  Actual:  ['Action', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Action']  Actual:  ['Action', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['Drama', 'Science Fiction', 'Mystery']  Actual:  ['Action', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['Science Fiction', 'Mystery', 'Documentary']  Actual:  ['Adventure', 'Fantasy', 'Action', 'Thriller', 'Documentary', 'Science Fiction', 'Mystery']
# Predicted:  ['Adventure', 'Fantasy', 'Action']  Actual:  ['Action', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['Thriller', 'History', 'Action']  Actual:  ['Action', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['Drama', 'Western', 'Action']  Actual:  ['Action', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['Mystery', 'Science Fiction', 'Action']  Actual:  ['Action', 'Thriller', 'Science Fiction', 'Mystery']
# Predicted:  ['Action', 'Science Fiction', 'Mystery']  Actual:  ['Action', 'Thriller', 'Science Fiction', 'Mystery']

# %%
print(np.mean(np.asarray(precs)),np.mean(np.asarray(recs)))
print("avg=",(np.mean(np.asarray(precs))+np.mean(np.asarray(recs)))/2)
# Out:
# 0.8235046778093136 0.3838742835005844
# avg= 0.603689480654949

# %%
from keras.models import model_from_json

model_json = model_textual.to_json()
with open("deep_text.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model_textual.save_weights("deep_text.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
json_file = open('/content/drive/My Drive/deep_text.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)

# load weights into new modelyjrtur
loaded_model.load_weights("/content/drive/My Drive/deep_text.h5")
print("Loaded model from disk")
# Out:
# Loaded model from disk

# %%
loaded_model

# %%
loaded_model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %%
score = loaded_model.evaluate(X_train, Y_train, verbose=0)

# %%
loaded_model.fit(X_train, Y_train, epochs=10, batch_size=500)
# Out:
# Epoch 1/10
# 63383/63383 [==============================] - 1s 12us/step - loss: 1.2512 - accuracy: 0.4659
# Epoch 2/10
# 63383/63383 [==============================] - 1s 11us/step - loss: 1.2506 - accuracy: 0.4659
# Epoch 3/10
# 63383/63383 [==============================] - 1s 11us/step - loss: 1.2506 - accuracy: 0.4659
# Epoch 4/10
# 63383/63383 [==============================] - 1s 11us/step - loss: 1.2506 - accuracy: 0.4659
# Epoch 5/10
# 63383/63383 [==============================] - 1s 10us/step - loss: 1.2507 - accuracy: 0.4659
# Epoch 6/10
# 63383/63383 [==============================] - 1s 10us/step - loss: 1.2506 - accuracy: 0.4659
# Epoch 7/10
# 63383/63383 [==============================] - 1s 10us/step - loss: 1.2506 - accuracy: 0.4659
# Epoch 8/10
# 63383/63383 [==============================] - 1s 11us/step - loss: 1.2507 - accuracy: 0.4659
# Epoch 9/10
# 63383/63383 [==============================] - 1s 11us/step - loss: 1.2506 - accuracy: 0.4659
# Epoch 10/10
# 63383/63383 [==============================] - 1s 11us/step - loss: 1.2506 - accuracy: 0.4659

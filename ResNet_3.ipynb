# %%
from keras.applications.resnet50 import ResNet50
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

model = ResNet50(weights='imagenet')

import pandas as pd
df1 = pd.read_pickle("/content/drive/My Drive/pinky_promise_last.pckl")
# Out:
# Using TensorFlow backend.

# %%
#imnames=poster_movies_1
feature_list1=[]
genre_list1=[]
file_order1=[]
#print("Total images = ",len(imnames))
failed_files1=[]
succesful_files1=[]
i=29999
for mov in range(30000,len(df1)):
    i+=1
    mov_name=df1.title[mov]
    mov_name1=mov_name.replace(':','/')
    poster_name=mov_name.replace(' ','_')+'.jpg'
    img_path=df1.poster_path[mov]
    try:
        img = image.load_img(img_path, target_size=(224, 224))
        succesful_files1.append(poster_name)
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = preprocess_input(x)
        features = model.predict(x)
        file_order1.append(img_path)
        feature_list1.append(features)
        genre_list1.append(df1.genre_ids[mov])
        if np.max(np.asarray(feature_list1))==0.0:
            print('problematic',i)
        if i%50==0 or i==30000:
            print("Working on Image : ",i)
    except:
        failed_files1.append(poster_name)
        continue
        
import pickle
list_pickled=(feature_list1,file_order1,failed_files1,succesful_files1,genre_list1)
f=open('Resnet_features_3.pckl','wb')
pickle.dump(list_pickled,f)
f.close()
print("Features dumped to pickle file")
# Out:
# Working on Image :  30000
# Working on Image :  30050
# Working on Image :  30100
# Working on Image :  30150
# Working on Image :  30200
# Working on Image :  30250
# Working on Image :  30300
# Working on Image :  30350
# Working on Image :  30400
# Working on Image :  30450
# Working on Image :  30500
# Working on Image :  30550
# Working on Image :  30600
# Working on Image :  30650
# Working on Image :  30700
# Working on Image :  30750
# Working on Image :  30800
# Working on Image :  30850
# Working on Image :  30900
# Working on Image :  30950
# Working on Image :  31000
# Working on Image :  31050
# Working on Image :  31100
# Working on Image :  31150
# Working on Image :  31200
# Working on Image :  31250
# Working on Image :  31300
# Working on Image :  31350
# Working on Image :  31400
# Working on Image :  31450
# Working on Image :  31500
# Working on Image :  31550
# Working on Image :  31600
# Working on Image :  31650
# Working on Image :  31700
# Working on Image :  31750
# Working on Image :  31800
# Working on Image :  31850
# Working on Image :  31900
# Working on Image :  31950
# Working on Image :  32000
# Working on Image :  32050
# Working on Image :  32100
# Working on Image :  32150
# Working on Image :  32200
# Working on Image :  32250
# Working on Image :  32300
# Working on Image :  32350
# Working on Image :  32400
# Working on Image :  32450
# Working on Image :  32500
# Working on Image :  32550
# Working on Image :  32600
# Working on Image :  32650
# Working on Image :  32700
# Working on Image :  32750
# Working on Image :  32800
# Working on Image :  32850
# Working on Image :  32900
# Working on Image :  32950
# Working on Image :  33000
# Working on Image :  33050
# Working on Image :  33100
# Working on Image :  33150
# Working on Image :  33200
# Working on Image :  33250
# Working on Image :  33300
# Working on Image :  33350
# Working on Image :  33400
# Working on Image :  33450
# Working on Image :  33500
# Working on Image :  33550
# Working on Image :  33600
# Working on Image :  33650
# Working on Image :  33700
# Working on Image :  33750
# Working on Image :  33800
# Working on Image :  33850
# Working on Image :  33900
# Working on Image :  33950
# Working on Image :  34000
# Working on Image :  34050
# Working on Image :  34100
# Working on Image :  34150
# Working on Image :  34200
# Working on Image :  34250
# Working on Image :  34300
# Working on Image :  34350
# Working on Image :  34400
# Working on Image :  34450
# Working on Image :  34500
# Working on Image :  34550
# Working on Image :  34600
# Working on Image :  34650
# Working on Image :  34700
# Working on Image :  34750
# Working on Image :  34800
# Working on Image :  34850
# Working on Image :  34900
# Working on Image :  34950
# Working on Image :  35000
# Working on Image :  35050
# Working on Image :  35100
# Working on Image :  35150
# Working on Image :  35200
# Working on Image :  35250
# Working on Image :  35300
# Working on Image :  35350
# Working on Image :  35400
# Working on Image :  35450
# Working on Image :  35500
# Working on Image :  35550
# Working on Image :  35600
# Working on Image :  35650
# Working on Image :  35700
# Working on Image :  35750
# Working on Image :  35800
# Working on Image :  35850
# Working on Image :  35900
# Working on Image :  35950
# Working on Image :  36000
# Working on Image :  36050
# Working on Image :  36100
# Working on Image :  36150
# Working on Image :  36200
# Working on Image :  36250
# Working on Image :  36300
# Working on Image :  36350
# Working on Image :  36400
# Working on Image :  36450
# Working on Image :  36500
# Working on Image :  36550
# Working on Image :  36600
# Working on Image :  36650
# Working on Image :  36700
# Working on Image :  36750
# Working on Image :  36800
# Working on Image :  36850
# Working on Image :  36900
# Working on Image :  36950
# Working on Image :  37000
# Working on Image :  37050
# Working on Image :  37100
# Working on Image :  37150
# Working on Image :  37200
# Working on Image :  37250
# Working on Image :  37300
# Working on Image :  37350
# Working on Image :  37400
# Working on Image :  37450
# Working on Image :  37500
# Working on Image :  37550
# Working on Image :  37600
# Working on Image :  37650
# Working on Image :  37700
# Working on Image :  37750
# Working on Image :  37800
# Working on Image :  37850
# Working on Image :  37900
# Working on Image :  37950
# Working on Image :  38000
# Working on Image :  38050
# Working on Image :  38100
# Working on Image :  38150
# Working on Image :  38200
# Working on Image :  38250
# Working on Image :  38300
# Working on Image :  38350
# Working on Image :  38400
# Working on Image :  38450
# Working on Image :  38500
# Working on Image :  38550
# Working on Image :  38600
# Working on Image :  38650
# Working on Image :  38700
# Working on Image :  38750
# Working on Image :  38800
# Working on Image :  38850
# Working on Image :  38900
# Working on Image :  38950
# Working on Image :  39000
# Working on Image :  39050
# Working on Image :  39100
# Working on Image :  39150
# Working on Image :  39200
# Working on Image :  39250
# Working on Image :  39300
# Working on Image :  39350
# Working on Image :  39400
# Working on Image :  39450
# Working on Image :  39500
# Working on Image :  39550
# Working on Image :  39600
# Working on Image :  39650
# Working on Image :  39700
# Working on Image :  39750
# Working on Image :  39800
# Working on Image :  39850
# Working on Image :  39900
# Working on Image :  39950
# Working on Image :  40000
# Working on Image :  40050
# Working on Image :  40100
# Working on Image :  40150
# Working on Image :  40200
# Working on Image :  40250
# Working on Image :  40300
# Working on Image :  40350
# Working on Image :  40400
# Working on Image :  40450
# Working on Image :  40500
# Working on Image :  40550
# Working on Image :  40600
# Working on Image :  40650
# Working on Image :  40700
# Working on Image :  40750
# Working on Image :  40800
# Working on Image :  40850
# Working on Image :  40900
# Working on Image :  40950
# Working on Image :  41000
# Working on Image :  41050
# Working on Image :  41100
# Working on Image :  41150
# Working on Image :  41200
# Working on Image :  41250
# Working on Image :  41300
# Working on Image :  41350
# Working on Image :  41400
# Working on Image :  41450
# Working on Image :  41500
# Working on Image :  41550
# Working on Image :  41600
# Working on Image :  41650
# Working on Image :  41700
# Working on Image :  41750
# Working on Image :  41800
# Working on Image :  41850
# Working on Image :  41900
# Working on Image :  41950
# Working on Image :  42000
# Working on Image :  42050
# Working on Image :  42100
# Working on Image :  42150
# Working on Image :  42200
# Working on Image :  42250
# Working on Image :  42300
# Working on Image :  42350
# Working on Image :  42400
# Working on Image :  42450
# Working on Image :  42500
# Working on Image :  42550
# Working on Image :  42600
# Working on Image :  42650
# Working on Image :  42700
# Working on Image :  42750
# Working on Image :  42800
# Working on Image :  42850
# Working on Image :  42900
# Working on Image :  42950
# Features dumped to pickle file

# %%
len(feature_list1)

# %%
feature_list1[0].shape

# %%
(a,b)=feature_list1[0].shape
feature_size=a*b

np_features=np.zeros((len(feature_list1),feature_size))
for i in range(len(feature_list1)):
    feat=feature_list1[i]
    reshaped_feat=feat.reshape(1,-1)
    np_features[i]=reshaped_feat

# %%
import pickle

f1 = open("/content/drive/My Drive/inputvecs1_1.pckl",'rb')
x1 = pickle.load(f1)

# %%
f2 = open("/content/drive/My Drive/inputvecs1_2.pckl","rb")
x2 = pickle.load(f2)

# %%
x1.shape
# Out:
# (10000, 25388)

# %%
import numpy as np
X = np.concatenate((x1,x2),axis=0)

# %%
X.shape
# Out:
# (21489, 25388)

# %%
f3 = open("/content/drive/My Drive/inputvecs2.pckl","rb")
x3 = pickle.load(f3)

# %%
del f1
del f2
del x1 
del x2
del f3

# %%
X = np.concatenate((X,x3),axis=0)

# %%
del x3

# %%
X.shape
# Out:
# (42978, 25388)

# %%
import pandas as pd
import pickle
df = pd.read_pickle("/content/drive/My Drive/pinky_promise_last.pckl")

# %%
Y = df.genre_ids.to_list()

# %%
Y
# Out:
# ['[28, 12]',
#  '[16, 35, 878]',
#  '[99, 878]',
#  '[80, 12]',
#  '[35, 12]',
#  '[28, 12, 53]',
#  '[18, 35]',
#  '[16]',
#  '[10402, 80]',
#  '[99]',
#  '[27, 53, 35]',
#  '[28, 80]',
#  '[16, 35, 10751]',
#  '[28, 12, 37]',
#  '[16]',
#  '[16]',
#  '[80, 18]',
#  '[18]',
#  '[16]',
#  '[80, 35]',
#  '[28, 35, 80]',
#  '[99, 12]',
#  '[12]',
#  '[28, 35]',
#  '[18, 9648, 53]',
#  '[28, 18, 36, 10752]',
#  '[28, 12, 35, 878]',
#  '[35, 10751, 16]',
#  '[28, 27, 878]',
#  '[16]',
#  '[18, 28, 80, 10749]',
#  '[35]',
#  '[10751, 16, 14]',
#  '[99]',
#  '[99]',
#  '[12, 16, 99]',
#  '[16]',
#  '[16, 18, 14, 27]',
#  '[28, 37]',
#  '[99]',
#  '[18, 35, 10751]',
#  '[35, 18]',
#  '[28, 80, 53]',
#  '[28, 27]',
#  '[99]',
#  '[28, 35, 9648, 53]',
#  '[35, 10749]',
#  '[28, 35, 80]',
#  '[28, 878]',
#  '[28, 12, 80]',
#  '[35, 10751]',
#  '[18, 99, 10770]',
#  '[99, 10751]',
#  '[28, 53]',
#  '[14, 27, 28, 53]',
#  '[10751, 12]',
#  '[28, 12, 18, 10751, 10770]',
#  '[99]',
#  '[53, 27, 18]',
#  '[18, 36]',
#  '[80, 18, 53]',
#  '[28, 27, 878, 53]',
#  '[35, 10749]',
#  '[99]',
#  '[12, 35, 10749]',
#  '[28, 37]',
#  '[10752, 28]',
#  '[36, 99]',
#  '[28, 80, 53, 35, 18, 10749]',
#  '[35]',
#  '[80, 18]',
#  '[18, 9648, 53]',
#  '[53, 80, 18]',
#  '[99]',
#  '[16]',
#  '[28, 878, 53]',
#  '[99]',
#  '[18, 878, 53]',
#  '[80, 18, 9648, 53]',
#  '[16]',
#  '[99]',
#  '[27, 28, 53]',
#  '[18, 10749]',
#  '[10749, 18, 28, 53]',
#  '[99]',
#  '[99, 10770]',
#  '[28, 27]',
#  '[35, 18, 10749]',
#  '[80, 53]',
#  '[35, 27, 37]',
#  '[12, 35]',
#  '[35, 18]',
#  '[28, 878]',
#  '[28, 37]',
#  '[99]',
#  '[28, 12, 53]',
#  '[16, 10751]',
#  '[16, 10751]',
#  '[16, 35]',
#  '[35, 99]',
#  '[16, 18]',
#  '[28, 18, 53]',
#  '[12, 27]',
#  '[18, 28]',
#  '[35, 878]',
#  '[28, 27, 53, 10770]',
#  '[35, 80, 53]',
#  '[9648, 16]',
#  '[80, 53, 10770]',
#  '[16]',
#  '[35, 18, 10749]',
#  '[35, 10402, 10749]',
#  '[16, 18]',
#  '[28, 12, 16]',
#  '[99]',
#  '[16]',
#  '[99]',
#  '[28, 12, 9648, 10770]',
#  '[28, 35, 37]',
#  '[18]',
#  '[35, 10749]',
#  '[80, 18, 53]',
#  '[99]',
#  '[16, 14, 10749]',
#  '[28, 35, 80, 18, 53]',
#  '[18, 10749]',
#  '[12, 18, 878, 10749]',
#  '[16]',
#  '[18, 10752]',
#  '[18, 10749]',
#  '[878, 35]',
#  '[12, 16, 35, 10751]',
#  '[80, 35, 9648]',
#  '[16, 10751]',
#  '[35, 18, 10751]',
#  '[10402, 99, 36]',
#  '[12, 10751]',
#  '[28, 80, 18, 53]',
#  '[99]',
#  '[12, 99]',
#  '[12, 12, 14]',
#  '[12]',
#  '[80, 18, 9648, 53]',
#  '[99]',
#  '[16, 10751]',
#  '[16]',
#  '[28, 12, 18, 10749]',
#  '[16]',
#  '[10751, 16]',
#  '[18, 80]',
#  '[99]',
#  '[28, 80, 18, 9648, 53]',
#  '[12, 16, 35, 14, 9648, 10751]',
#  '[10770, 12, 35, 10751]',
#  '[35, 18, 10749]',
#  '[35, 18]',
#  '[12]',
#  '[12, 28, 80, 9648]',
#  '[28, 35]',
#  '[53, 80, 9648]',
#  '[28, 80, 18]',
#  '[28, 12, 878, 53]',
#  '[53, 28, 12]',
#  '[28, 18, 37]',
#  '[16, 14, 10751]',
#  '[28, 35, 37, 10749]',
#  '[16, 99, 10752]',
#  '[14, 16, 28, 27]',
#  '[12, 35, 80, 10751]',
#  '[10402, 16, 18, 10751]',
#  '[28, 12, 878]',
#  '[80, 18]',
#  '[28, 12, 53]',
#  '[99]',
#  '[80, 18, 10749]',
#  '[16, 35, 10751]',
#  '[99]',
#  '[35, 10770]',
#  '[28, 53]',
#  '[80]',
#  '[16, 35, 27, 53, 10751]',
#  '[99]',
#  '[80, 18, 9648]',
#  '[10402, 99]',
#  '[28, 27, 18, 53]',
#  '[80, 18, 10749]',
#  '[80, 35]',
#  '[99]',
#  '[16]',
#  '[80, 18]',
#  '[35]',
#  '[99]',
#  '[99]',
#  '[99]',
#  '[35, 27]',
#  '[28, 53, 80, 18]',
#  '[80, 18, 10770]',
#  '[35, 10749]',
#  '[12, 10749]',
#  '[35, 10749]',
#  '[35]',
#  '[35, 80, 53]',
#  '[18, 53]',
#  '[35, 28, 12]',
#  '[28, 18]',
#  '[28]',
#  '[80, 53]',
#  '[35]',
#  '[10770, 80, 18, 53]',
#  '[16]',
#  '[35, 99]',
#  '[12, 18, 14]',
#  '[99]',
#  '[35, 10749]',
#  '[12, 14]',
#  '[35]',
#  '[18]',
#  '[99]',
#  '[28, 12, 14]',
#  '[18, 36, 10749]',
#  '[35, 10749, 37]',
#  '[35, 27]',
#  '[18, 10749, 80]',
#  '[16, 35, 9648, 10751]',
#  '[18, 10770, 35]',
#  '[28, 80, 878, 53]',
#  '[18, 16, 27]',
#  '[35, 12]',
#  '[28, 27, 53]',
#  '[28, 80, 27, 53]',
#  '[35, 18]',
#  '[28, 12, 27, 53]',
#  '[80, 18]',
#  '[16]',
#  '[16, 10751]',
#  '[28, 35]',
#  '[99]',
#  '[99]',
#  '[80, 18, 53]',
#  '[16]',
#  '[35, 10402, 10752]',
#  '[99]',
#  '[99]',
#  '[35, 10749]',
#  '[99]',
#  '[18, 28, 53, 80]',
#  '[99]',
#  '[99]',
#  '[35, 18]',
#  '[99, 35, 36]',
#  '[80, 18]',
#  '[99]',
#  '[12]',
#  '[28, 35, 10751]',
#  '[10749, 28]',
#  '[99, 10402, 10770]',
#  '[28, 12, 35, 14, 10751]',
#  '[35]',
#  '[18, 36, 10402]',
#  '[12, 18]',
#  '[99]',
#  '[16, 10751]',
#  '[28, 35, 878]',
#  '[35, 878, 10751]',
#  '[12]',
#  '[35, 10402, 10749]',
#  '[12, 16, 35, 14, 10751]',
#  '[80]',
#  '[80, 18]',
#  '[35, 18]',
#  '[99]',
#  '[35, 14, 27]',
#  '[35, 18, 10749]',
#  '[80, 18, 9648]',
#  '[18, 99]',
#  '[99]',
#  '[28, 14]',
#  '[12, 53]',
#  '[35, 18, 10749]',
#  '[16, 18]',
#  '[99]',
#  '[16]',
#  '[12, 28]',
#  '[99, 36]',
#  '[36, 10749, 10752, 18]',
#  '[99, 10402]',
#  '[28, 12, 878]',
#  '[28, 35, 10749]',
#  '[28, 12, 53]',
#  '[18, 10749]',
#  '[28, 53, 878]',
#  '[10751, 35]',
#  '[99]',
#  '[16, 35, 9648, 10751]',
#  '[99, 18]',
#  '[35, 12]',
#  '[18, 10749]',
#  '[80, 18, 53]',
#  '[99]',
#  '[35, 80, 10402]',
#  '[12, 10751]',
#  '[80, 27, 9648, 10770]',
#  '[28, 12, 18, 10751]',
#  '[28]',
#  '[28, 12, 35]',
#  '[9648, 28, 12, 27]',
#  '[28, 12, 53]',
#  '[35, 18]',
#  '[12, 16, 35, 10751]',
#  '[12]',
#  '[18, 14, 10749]',
#  '[10751, 16]',
#  '[16]',
#  '[28, 18, 37]',
#  '[99]',
#  '[18]',
#  '[16, 10402]',
#  '[99]',
#  '[28, 35, 53]',
#  '[80, 53]',
#  '[36, 18, 28, 37]',
#  '[28, 12, 36, 27]',
#  '[16, 14, 10751]',
#  '[28, 12, 18, 10749, 53]',
#  '[28, 80, 53]',
#  '[28]',
#  '[16, 35, 14, 10751]',
#  '[28, 35]',
#  '[18]',
#  '[99]',
#  '[18, 12]',
#  '[35, 10749, 10770]',
#  '[16]',
#  '[80, 53, 18, 27]',
#  '[35, 27]',
#  '[99, 18, 10751]',
#  '[99]',
#  '[16, 10751]',
#  '[35, 10749]',
#  '[80]',
#  '[16, 36]',
#  '[99]',
#  '[80]',
#  '[28, 12, 878, 53]',
#  '[12, 18, 10749]',
#  '[35]',
#  '[99]',
#  '[12, 18]',
#  '[28, 12, 80, 53]',
#  '[35, 10749]',
#  '[18, 10752]',
#  '[27, 9648, 53, 80]',
#  '[12, 35, 18, 878]',
#  '[18, 53, 9648]',
#  '[14, 10751, 12]',
#  '[35, 18, 10749]',
#  '[18, 10402]',
#  '[35, 27, 878]',
#  '[99]',
#  '[28, 80]',
#  '[16]',
#  '[28, 37]',
#  '[99]',
#  '[35, 18, 10749]',
#  '[80, 35]',
#  '[12, 10751]',
#  '[28, 12, 10751]',
#  '[35, 18, 14, 10749]',
#  '[12, 18, 14]',
#  '[12, 18]',
#  '[28, 16, 878]',
#  '[99]',
#  '[99]',
#  '[28, 35]',
#  '[12, 16, 35, 10751]',
#  '[18, 9648, 53, 80]',
#  '[99]',
#  '[10752, 35]',
#  '[28]',
#  '[18]',
#  '[99]',
#  '[35, 18, 14]',
#  '[18, 53]',
#  '[12]',
#  '[99, 10402]',
#  '[18]',
#  '[99]',
#  '[16, 10751]',
#  '[99]',
#  '[99]',
#  '[28, 12, 35, 10751]',
#  '[28, 12, 14, 10751]',
#  '[12, 16, 10751]',
#  '[28, 16, 878]',
#  '[99]',
#  '[18]',
#  '[18, 53]',
#  '[28, 27]',
#  '[28, 18, 36]',
#  '[99]',
#  '[28, 18, 27, 878, 53]',
#  '[28, 878, 53, 10770]',
#  '[28, 12, 18, 10749]',
#  '[18, 80]',
#  '[12, 18, 10751, 878]',
#  '[18, 35, 10749]',
#  '[35]',
#  '[10770, 9648, 80, 18]',
#  '[99, 10402, 36]',
#  '[35, 27]',
#  '[99]',
#  '[28]',
#  '[37, 28]',
#  '[99]',
#  '[27, 35, 10749]',
#  '[80, 18, 53]',
#  '[28, 37]',
#  '[99]',
#  '[35, 10751, 10770]',
#  '[28, 53]',
#  '[35, 10749, 10770]',
#  '[28, 12, 878, 53]',
#  '[28]',
#  '[12, 35]',
#  '[12, 10752, 28]',
#  '[35]',
#  '[10751, 16]',
#  '[10751, 16, 27, 35]',
#  '[35]',
#  '[27, 28, 53]',
#  '[35]',
#  '[28, 12]',
#  '[35, 10749]',
#  '[80, 9648, 53]',
#  '[28, 27, 878]',
#  '[99]',
#  '[16]',
#  '[35]',
#  '[99]',
#  '[28, 18, 53]',
#  '[10751, 16, 10770, 12, 18]',
#  '[80, 18, 10749]',
#  '[18, 80]',
#  '[80, 18, 53]',
#  '[53, 28]',
#  '[28, 35, 10749]',
#  '[16, 35, 10751]',
#  '[18, 10749]',
#  '[12, 18, 10749]',
#  '[99, 18]',
#  '[12, 16, 10751]',
#  '[35, 10751]',
#  '[35, 16]',
#  '[878, 16, 35]',
#  '[16]',
#  '[18, 878, 53]',
#  '[12, 14]',
#  '[10770, 12, 10402, 14]',
#  '[99, 10770]',
#  '[99]',
#  '[35]',
#  '[35, 18]',
#  '[80, 18, 53]',
#  '[99]',
#  '[28, 12, 16, 35]',
#  '[99]',
#  '[80, 18]',
#  '[28, 35]',
#  '[12, 35, 14, 10751]',
#  '[99, 10402]',
#  '[28, 35]',
#  '[99]',
#  '[99]',
#  '[28, 12, 16, 878]',
#  '[35, 18, 10749]',
#  '[18, 27, 53]',
#  '[9648, 53, 27, 80]',
#  '[28, 35, 37]',
#  '[35, 27]',
#  '[12, 16, 10751]',
#  '[99]',
#  '[878, 28]',
#  '[28, 18, 36, 53]',
#  '[35, 27]',
#  '[28, 18]',
#  '[80, 18, 53]',
#  '[28, 80]',
#  '[12, 16, 14, 10751]',
#  '[80, 18]',
#  '[28, 878, 53]',
#  '[28, 12, 14]',
#  '[35, 80]',
#  '[99]',
#  '[35, 18]',
#  '[28, 12, 99]',
#  '[18, 28, 12]',
#  '[10751, 16]',
#  '[28, 18, 53]',
#  '[35, 27, 10749]',
#  '[99]',
#  '[80, 28]',
#  '[28, 80, 18, 53]',
#  '[99, 10402]',
#  '[12, 35, 878]',
#  '[99]',
#  '[18, 53]',
#  '[35, 878]',
#  '[10770, 18, 28]',
#  '[14, 99]',
#  '[12, 878]',
#  '[80, 27]',
#  '[80, 18, 53]',
#  '[35, 80]',
#  '[12, 35, 18]',
#  '[99, 80, 18]',
#  '[28, 12, 18, 53]',
#  '[28, 12, 878]',
#  '[80, 53]',
#  '[10402, 99]',
#  '[12]',
#  '[18, 36, 10752]',
#  '[28, 80, 10752, 53, 27]',
#  '[99]',
#  '[35, 80, 18, 9648, 53]',
#  '[18, 9648, 10749]',
#  '[80, 18, 9648]',
#  '[80]',
#  '[18, 80]',
#  '[80]',
#  '[12, 16, 18]',
#  '[28, 80, 53]',
#  '[18, 10770, 80, 53]',
#  '[28, 12, 18, 10752]',
#  '[36, 99]',
#  '[80, 9648, 18]',
#  '[35, 10751]',
#  '[28, 80, 53]',
#  '[18, 10751]',
#  '[28, 12, 53]',
#  '[28, 18, 53]',
#  '[35, 10749]',
#  '[80, 18, 27]',
#  '[16, 80, 99]',
#  '[16, 14, 10751]',
#  '[35, 12]',
#  '[80, 27]',
#  '[16]',
#  '[28, 12, 878]',
#  '[18, 10749]',
#  '[80, 18, 27]',
#  '[18, 53, 80]',
#  '[35, 27]',
#  '[28, 12, 35, 18]',
#  '[37, 10402, 28, 12]',
#  '[12, 16, 10751]',
#  '[80, 18, 9648, 53]',
#  '[28, 18, 53]',
#  '[99]',
#  '[18, 16]',
#  '[53, 80]',
#  '[28, 878, 53]',
#  '[99]',
#  '[16]',
#  '[16, 35, 10751]',
#  '[18, 53]',
#  '[80, 28]',
#  '[28, 80, 18, 53]',
#  '[16, 35, 878]',
#  '[99, 10402]',
#  '[35, 10749]',
#  '[12, 28, 53, 878]',
#  '[99]',
#  '[18, 53]',
#  '[28, 37]',
#  '[18]',
#  '[28, 80, 18]',
#  '[99]',
#  '[16, 12, 10751]',
#  '[28, 18]',
#  '[99]',
#  '[28, 35, 53]',
#  '[35]',
#  '[10402, 99, 16]',
#  '[28, 80, 10749]',
#  '[35, 27]',
#  '[53, 18, 80]',
#  '[28, 878]',
#  '[878, 18, 27, 9648]',
#  '[12]',
#  '[28, 35, 80, 18]',
#  '[80, 18, 9648, 10770]',
#  '[18, 80]',
#  '[99]',
#  '[10749, 28, 12, 37, 10402]',
#  '[28, 12, 18, 37]',
#  '[99]',
#  '[16, 27]',
#  '[80, 28, 35]',
#  '[80, 18]',
#  '[35, 18]',
#  '[35, 18, 10749]',
#  '[35]',
#  '[99]',
#  '[35]',
#  '[28, 53, 12]',
#  '[80, 18, 53]',
#  '[16]',
#  '[12, 10751]',
#  '[12, 14]',
#  '[14, 18, 35, 10749]',
#  '[80, 53]',
#  '[80, 18, 53]',
#  '[10770, 16, 12, 10751]',
#  '[99]',
#  '[16, 35]',
#  '[18, 99]',
#  '[35, 18, 10749]',
#  '[10749, 35]',
#  '[99]',
#  '[35, 18]',
#  '[28, 80, 53]',
#  '[99, 36]',
#  '[99]',
#  '[28, 12, 878]',
#  '[99]',
#  '[28, 27, 878, 53]',
#  '[99]',
#  '[16]',
#  '[28, 12, 18, 10751]',
#  '[35]',
#  '[16]',
#  '[16, 35, 10751]',
#  '[16]',
#  '[28, 37]',
#  '[36, 12]',
#  '[35, 10749]',
#  '[18, 28, 53, 878]',
#  '[35, 14]',
#  '[12, 18, 14, 878]',
#  '[28, 35, 80, 16]',
#  '[35, 18, 10402, 10749]',
#  '[12, 10751]',
#  '[99]',
#  '[35]',
#  '[16, 18]',
#  '[99]',
#  '[99]',
#  '[28, 12, 53]',
#  '[80, 53]',
#  '[18, 878, 53]',
#  '[99]',
#  '[35, 16]',
#  '[99]',
#  '[28, 36, 18]',
#  '[10770, 35, 12]',
#  '[18, 10402]',
#  '[28, 12, 878, 53]',
#  '[28, 53, 10752]',
#  '[28, 14, 878]',
#  '[12, 99]',
#  '[35, 18]',
#  '[28, 878, 80]',
#  '[10751, 35, 14, 12]',
#  '[99]',
#  '[35, 10749]',
#  '[35, 18, 10749]',
#  '[28, 27, 878]',
#  '[80]',
#  '[16]',
#  '[18]',
#  '[35, 18]',
#  '[28, 18, 10752]',
#  '[80]',
#  '[16, 35]',
#  '[12, 99, 18, 36]',
#  '[35, 10402]',
#  '[18, 12, 10749]',
#  '[35, 18]',
#  '[27, 16]',
#  '[99]',
#  '[27, 35]',
#  '[28, 35, 9648]',
#  '[35, 99]',
#  '[99]',
#  '[16, 35]',
#  '[28, 35, 80]',
#  '[28, 12]',
#  '[28, 9648, 53]',
#  '[12, 16, 35, 18, 10402, 10751]',
#  '[28, 80, 28]',
#  '[80, 18, 53]',
#  '[99]',
#  '[10402, 35]',
#  '[16]',
#  '[99]',
#  '[35, 80]',
#  '[28, 80, 9648, 53]',
#  '[18, 10749]',
#  '[28, 35]',
#  '[28]',
#  '[80, 27, 9648, 53]',
#  '[35, 10402, 10749]',
#  '[12, 10751]',
#  '[80, 9648]',
#  '[18]',
#  '[99]',
#  '[80]',
#  '[99, 10402]',
#  '[16]',
#  '[18, 35]',
#  '[36, 99]',
#  '[14, 35]',
#  '[53, 28, 18]',
#  '[28]',
#  '[99]',
#  '[878, 16]',
#  '[99]',
#  '[12]',
#  '[99]',
#  '[12, 35, 878, 10751]',
#  '[80, 18, 53]',
#  '[35]',
#  '[99, 10402, 14]',
#  '[99, 12]',
#  '[16, 35, 10751]',
#  '[28, 37, 80, 18]',
#  '[28, 35, 80, 10749]',
#  '[35, 18, 10749]',
#  '[18, 36]',
#  '[12, 28]',
#  '[18, 53]',
#  '[28, 12, 878]',
#  '[18, 36]',
#  '[35, 80, 9648]',
#  '[80, 18, 10749]',
#  '[35, 10749]',
#  '[35, 18]',
#  '[35, 9648, 53, 10749]',
#  '[12, 18, 36]',
#  '[99]',
#  '[28]',
#  '[35, 18, 878, 53, 10749]',
#  '[80]',
#  '[16]',
#  '[28, 80, 18, 53]',
#  '[16, 10751, 10402]',
#  '[35]',
#  '[28, 80, 9648, 53]',
#  '[28, 18, 53]',
#  '[28, 53, 878, 9648]',
#  '[35, 53]',
#  '[35, 27]',
#  '[99]',
#  '[16]',
#  '[99]',
#  '[16, 35]',
#  '[35, 27, 10749]',
#  '[28, 18, 10770]',
#  '[18]',
#  '[28, 12, 16, 14, 10751]',
#  '[80, 18, 9648]',
#  '[35, 80, 18]',
#  '[80, 27]',
#  '[18, 14, 878, 10749]',
#  '[16, 35, 14, 10402]',
#  '[99]',
#  '[80, 35, 28]',
#  '[28, 53]',
#  '[28, 16, 35, 14, 10751]',
#  '[28]',
#  '[35, 27, 9648]',
#  '[18, 28, 37, 36]',
#  '[28, 12, 18, 37]',
#  '[18, 99]',
#  '[28]',
#  '[18, 27, 9648, 53]',
#  '[99]',
#  '[35]',
#  '[99]',
#  '[18, 80, 9648, 35]',
#  '[28]',
#  '[99]',
#  '[12, 35]',
#  '[18, 53]',
#  '[99]',
#  '[28, 35, 18, 10749]',
#  '[35, 80, 9648]',
#  '[27, 16, 878]',
#  '[35, 18, 10749]',
#  '[35]',
#  '[35, 10749, 18]',
#  '[35, 10749]',
#  '[18, 35]',
#  '[18, 10751]',
#  '[16]',
#  '[80, 53]',
#  '[99, 36]',
#  '[28, 35]',
#  '[99]',
#  '[28, 18, 53]',
#  '[99]',
#  '[28, 35, 10751]',
#  '[35, 80, 27]',
#  '[35]',
#  '[28, 35, 18, 10751]',
#  '[14, 28, 12]',
#  '[10402, 99]',
#  '[28, 35, 37]',
#  '[12, 18, 53]',
#  '[16]',
#  '[53, 80, 18]',
#  '[12, 16, 35, 10751]',
#  '[35]',
#  '[35, 10749]',
#  '[99]',
#  '[28, 37]',
#  '[16]',
#  '[28, 53]',
#  '[80, 18, 9648]',
#  '[99]',
#  '[12, 35]',
#  '[10770, 35, 18, 10751]',
#  '[35, 18, 10749]',
#  '[28, 18, 35, 80]',
#  '[99, 36]',
#  '[28, 27, 878]',
#  '[16, 10751]',
#  '[99, 10402]',
#  '[99]',
#  '[28, 53]',
#  '[80, 18]',
#  '[18]',
#  '[18, 35]',
#  '[878, 28, 18]',
#  '[53, 12, 27]',
#  '[80]',
#  '[28, 12, 53]',
#  '[16, 10751]',
#  '[80]',
#  '[18, 36, 53]',
#  '[28, 12, 35, 80, 53]',
#  '[27, 35, 18, 53, 14]',
#  '[28, 53]',
#  '[99]',
#  '[80, 9648]',
#  '[28]',
#  '[12, 16, 10751]',
#  '[80, 18]',
#  '[35, 10402]',
#  '[18, 12, 35, 10751]',
#  '[99]',
#  '[18, 27]',
#  '[80, 27, 53]',
#  '[16, 35, 14]',
#  '[18, 35, 80]',
#  '[99]',
#  '[35]',
#  '[35, 10749, 10402]',
#  '[28, 12, 18, 10751]',
#  '[80, 18]',
#  '[18, 27, 9648, 878, 53]',
#  '[35, 80]',
#  '[28, 80]',
#  '[16]',
#  '[99]',
#  '[28, 16, 878, 10751]',
#  '[35, 80]',
#  '[28, 12, 878, 53]',
#  '[18, 80, 10770]',
#  '[28, 80, 53]',
#  '[35, 80, 18, 14, 9648, 53]',
#  '[10751, 16]',
#  '[99, 10402]',
#  '[99]',
#  '[99, 12]',
#  '[28, 12, 35, 14, 10751]',
#  '[35, 18, 10749]',
#  '[18, 28]',
#  '[14, 35, 10402, 27, 878]',
#  '[99]',
#  '[99]',
#  '[18, 36, 10752]',
#  '[35, 18, 10749]',
#  '[28, 12]',
#  '[12, 14]',
#  '[35, 27, 878]',
#  '[28, 80]',
#  '[28, 18, 9648]',
#  '[18, 9648, 878]',
#  '[35, 80, 18]',
#  '[99, 80, 16]',
#  '[16]',
#  '[99]',
#  '[9648, 80, 53, 878, 27]',
#  '[28]',
#  '[10749, 9648, 16]',
#  '[28, 12, 10749]',
#  '[99]',
#  '[16]',
#  '[35, 10749, 53]',
#  '[28, 37]',
#  '[35, 28, 18]',
#  '[16]',
#  '[12, 18, 37]',
#  '[80, 18]',
#  '[28, 12, 35]',
#  '[80]',
#  '[80, 878]',
#  '[28]',
#  '[12, 18]',
#  '[10751, 12, 14]',
#  '[99]',
#  '[80]',
#  '[35, 18]',
#  '[18, 9648, 80]',
#  '[28, 18]',
#  '[16, 10751]',
#  '[99]',
#  '[18, 10749]',
#  '[35]',
#  '[99]',
#  '[35, 27, 878]',
#  '[12, 14, 878]',
#  '[12, 10749]',
#  '[35, 18, 10749]',
#  '[10402, 99]',
#  '[80, 28, 35]',
#  '[99]',
#  '[28, 12, 35]',
#  '[35]',
#  '[28, 12, 878]',
#  '[99]',
#  '[80, 18, 9648, 53, 10770]',
#  '[99]',
#  '[28, 80, 35, 53]',
#  '[53, 10770, 80, 9648]',
#  '[10751, 16]',
#  '[35, 14, 27]',
#  '[12, 18, 10749]',
#  '[35, 18, 10749]',
#  '[99]',
#  '[99, 16]',
#  '[80]',
#  '[16]',
#  '[28, 53]',
#  '[99]',
#  '[35, 10402, 10749]',
#  '[35, 18]',
#  '[28, 12, 53]',
#  '[10402, 99]',
#  '[80]',
#  '[16, 35]',
#  '[35]',
#  '[12, 16, 10751]',
#  '[36, 28, 12, 18]',
#  '[12, 99]',
#  '[28, 12, 878]',
#  '[18]',
#  '[35, 80, 18, 53]',
#  '[12, 16, 35, 10751]',
#  '[12, 10751]',
#  '[99]',
#  '[16, 10770, 35]',
#  '[28]',
#  '[28, 37]',
#  '[99]',
#  '[12, 16, 35, 10751]',
#  '[28, 18]',
#  '[28, 18, 36, 37]',
#  '[35]',
#  '[28, 12, 14]',
#  '[10402, 16]',
#  '[99]',
#  '[16, 35, 878]',
#  '[28, 12, 14]',
#  '[28, 12, 35, 14, 878]',
#  '[99]',
#  '[12]',
#  '[28, 53]',
#  '[35, 18, 10751, 10770]',
#  '[80, 18, 12]',
#  '[10749, 35, 18]',
#  '[16]',
#  '[16]',
#  '[28, 27, 878]',
#  '[80, 18, 9648]',
#  '[80, 53]',
#  '[35, 27]',
#  '[99]',
#  '[28, 12, 18]',
#  '[28, 80]',
#  '[35, 18]',
#  '[80, 53]',
#  '[16]',
#  '[28, 12, 16, 35, 878]',
#  '[18]',
#  '[99]',
#  '[35, 16]',
#  '[16]',
#  '[99]',
#  ...]

# %%
import numpy as np
mask = np.random.rand(len(X)) < 0.8

# %%
from sklearn.preprocessing import MultiLabelBinarizer
mlb=MultiLabelBinarizer()
Y=mlb.fit_transform(Y)

Y.shape
# Out:
# (42978, 14)

# %%
X_train=X[mask]
X_test=X[~mask]
Y_train=Y[mask]
Y_test=Y[~mask]

# %%
dir()
# Out:
# ['In',
#  'MultiLabelBinarizer',
#  'Out',
#  'X',
#  'X_test',
#  'X_train',
#  'Y',
#  'Y_test',
#  'Y_train',
#  '_',
#  '_11',
#  '_14',
#  '_16',
#  '_4',
#  '_6',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  '_sh',
#  'df',
#  'exit',
#  'get_ipython',
#  'mask',
#  'mlb',
#  'np',
#  'pd',
#  'pickle',
#  'quit']

# %%
del df
del mlb
del Y
del pickle
del np 
del pd
del X
del MultiLabelBinarizer

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras import optimizers
model_visual = Sequential([
    Dense(1024, input_shape=(25388,)),
    Activation('relu'),
    Dense(256),
    Activation('relu'),
    Dense(14),
    Activation('sigmoid'),
])
opt = optimizers.rmsprop(lr=0.0001, decay=1e-6)

#sgd = optimizers.SGD(lr=0.05, decay=1e-6, momentum=0.4, nesterov=False)
model_visual.compile(optimizer=opt,
              loss='binary_crossentropy',
              metrics=['accuracy'])
# Out:
# Using TensorFlow backend.

# %%
model_visual.fit(X_train, Y_train, epochs=200, batch_size=64,verbose=1)
# Out:
# Epoch 1/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 1.1640 - accuracy: 0.6253
# Epoch 2/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.6202 - accuracy: 0.6480
# Epoch 3/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5818 - accuracy: 0.6601
# Epoch 4/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5713 - accuracy: 0.6641
# Epoch 5/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5651 - accuracy: 0.6685
# Epoch 6/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5615 - accuracy: 0.6714
# Epoch 7/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5590 - accuracy: 0.6742
# Epoch 8/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5572 - accuracy: 0.6766
# Epoch 9/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5554 - accuracy: 0.6775
# Epoch 10/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5545 - accuracy: 0.6787
# Epoch 11/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5538 - accuracy: 0.6786
# Epoch 12/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5530 - accuracy: 0.6801
# Epoch 13/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5526 - accuracy: 0.6792
# Epoch 14/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5522 - accuracy: 0.6805
# Epoch 15/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5517 - accuracy: 0.6817
# Epoch 16/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5515 - accuracy: 0.6813
# Epoch 17/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5510 - accuracy: 0.6812
# Epoch 18/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5511 - accuracy: 0.6814
# Epoch 19/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5506 - accuracy: 0.6829
# Epoch 20/200
# 34391/34391 [==============================] - 87s 3ms/step - loss: 0.5507 - accuracy: 0.6825
# Epoch 21/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5504 - accuracy: 0.6829
# Epoch 22/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5502 - accuracy: 0.6830
# Epoch 23/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5501 - accuracy: 0.6834
# Epoch 24/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5497 - accuracy: 0.6830
# Epoch 25/200
# 34391/34391 [==============================] - 91s 3ms/step - loss: 0.5497 - accuracy: 0.6835
# Epoch 26/200
# 34391/34391 [==============================] - 90s 3ms/step - loss: 0.5494 - accuracy: 0.6841
# Epoch 27/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5495 - accuracy: 0.6844
# Epoch 28/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5492 - accuracy: 0.6845
# Epoch 29/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5489 - accuracy: 0.6845
# Epoch 30/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5488 - accuracy: 0.6846
# Epoch 31/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5485 - accuracy: 0.6848
# Epoch 32/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5484 - accuracy: 0.6857
# Epoch 33/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5482 - accuracy: 0.6860
# Epoch 34/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5479 - accuracy: 0.6867
# Epoch 35/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5476 - accuracy: 0.6867
# Epoch 36/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5475 - accuracy: 0.6873
# Epoch 37/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5471 - accuracy: 0.6875
# Epoch 38/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5467 - accuracy: 0.6883
# Epoch 39/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5465 - accuracy: 0.6886
# Epoch 40/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5459 - accuracy: 0.6893
# Epoch 41/200
# 34391/34391 [==============================] - 90s 3ms/step - loss: 0.5455 - accuracy: 0.6893
# Epoch 42/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5454 - accuracy: 0.6894
# Epoch 43/200
# 34391/34391 [==============================] - 90s 3ms/step - loss: 0.5448 - accuracy: 0.6907
# Epoch 44/200
# 34391/34391 [==============================] - 91s 3ms/step - loss: 0.5445 - accuracy: 0.6915
# Epoch 45/200
# 34391/34391 [==============================] - 90s 3ms/step - loss: 0.5440 - accuracy: 0.6914
# Epoch 46/200
# 34391/34391 [==============================] - 90s 3ms/step - loss: 0.5434 - accuracy: 0.6924
# Epoch 47/200
# 34391/34391 [==============================] - 91s 3ms/step - loss: 0.5431 - accuracy: 0.6928
# Epoch 48/200
# 34391/34391 [==============================] - 92s 3ms/step - loss: 0.5427 - accuracy: 0.6928
# Epoch 49/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5418 - accuracy: 0.6945
# Epoch 50/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5416 - accuracy: 0.6944
# Epoch 51/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5413 - accuracy: 0.6948
# Epoch 52/200
# 34391/34391 [==============================] - 90s 3ms/step - loss: 0.5408 - accuracy: 0.6957
# Epoch 53/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5402 - accuracy: 0.6966
# Epoch 54/200
# 34391/34391 [==============================] - 90s 3ms/step - loss: 0.5398 - accuracy: 0.6961
# Epoch 55/200
# 34391/34391 [==============================] - 90s 3ms/step - loss: 0.5397 - accuracy: 0.6970
# Epoch 56/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5396 - accuracy: 0.6964
# Epoch 57/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5382 - accuracy: 0.6979
# Epoch 58/200
# 34391/34391 [==============================] - 90s 3ms/step - loss: 0.5384 - accuracy: 0.6984
# Epoch 59/200
# 34391/34391 [==============================] - 90s 3ms/step - loss: 0.5378 - accuracy: 0.6987
# Epoch 60/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5375 - accuracy: 0.6995
# Epoch 61/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5367 - accuracy: 0.7003
# Epoch 62/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5378 - accuracy: 0.6984
# Epoch 63/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5372 - accuracy: 0.6993
# Epoch 64/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5374 - accuracy: 0.6990
# Epoch 65/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5369 - accuracy: 0.6997
# Epoch 66/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5369 - accuracy: 0.6994
# Epoch 67/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5367 - accuracy: 0.7004
# Epoch 68/200
# 34391/34391 [==============================] - 91s 3ms/step - loss: 0.5367 - accuracy: 0.6994
# Epoch 69/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5363 - accuracy: 0.7006
# Epoch 70/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5361 - accuracy: 0.7016
# Epoch 71/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5355 - accuracy: 0.7013
# Epoch 72/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5353 - accuracy: 0.7011
# Epoch 73/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5352 - accuracy: 0.7017
# Epoch 74/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5340 - accuracy: 0.7029
# Epoch 75/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5349 - accuracy: 0.7019
# Epoch 76/200
# 34391/34391 [==============================] - 90s 3ms/step - loss: 0.5340 - accuracy: 0.7024
# Epoch 77/200
# 34391/34391 [==============================] - 90s 3ms/step - loss: 0.5335 - accuracy: 0.7033
# Epoch 78/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5335 - accuracy: 0.7034
# Epoch 79/200
# 34391/34391 [==============================] - 93s 3ms/step - loss: 0.5333 - accuracy: 0.7036
# Epoch 80/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5335 - accuracy: 0.7038
# Epoch 81/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5326 - accuracy: 0.7044
# Epoch 82/200
# 34391/34391 [==============================] - 90s 3ms/step - loss: 0.5322 - accuracy: 0.7044
# Epoch 83/200
# 34391/34391 [==============================] - 90s 3ms/step - loss: 0.5324 - accuracy: 0.7044
# Epoch 84/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5321 - accuracy: 0.7049
# Epoch 85/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5319 - accuracy: 0.7054
# Epoch 86/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5315 - accuracy: 0.7057
# Epoch 87/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5312 - accuracy: 0.7059
# Epoch 88/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5310 - accuracy: 0.7058
# Epoch 89/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5304 - accuracy: 0.7066
# Epoch 90/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5297 - accuracy: 0.7068
# Epoch 91/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5291 - accuracy: 0.7084
# Epoch 92/200
# 34391/34391 [==============================] - 90s 3ms/step - loss: 0.5291 - accuracy: 0.7078
# Epoch 93/200
# 34391/34391 [==============================] - 90s 3ms/step - loss: 0.5291 - accuracy: 0.7077
# Epoch 94/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5289 - accuracy: 0.7084
# Epoch 95/200
# 34391/34391 [==============================] - 90s 3ms/step - loss: 0.5288 - accuracy: 0.7079
# Epoch 96/200
# 34391/34391 [==============================] - 90s 3ms/step - loss: 0.5279 - accuracy: 0.7085
# Epoch 97/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5283 - accuracy: 0.7089
# Epoch 98/200
# 34391/34391 [==============================] - 90s 3ms/step - loss: 0.5278 - accuracy: 0.7087
# Epoch 99/200
# 34391/34391 [==============================] - 90s 3ms/step - loss: 0.5268 - accuracy: 0.7098
# Epoch 100/200
# 34391/34391 [==============================] - 90s 3ms/step - loss: 0.5266 - accuracy: 0.7104
# Epoch 101/200
# 34391/34391 [==============================] - 90s 3ms/step - loss: 0.5266 - accuracy: 0.7104
# Epoch 102/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5265 - accuracy: 0.7114
# Epoch 103/200
# 34391/34391 [==============================] - 90s 3ms/step - loss: 0.5263 - accuracy: 0.7102
# Epoch 104/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5259 - accuracy: 0.7110
# Epoch 105/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5258 - accuracy: 0.7111
# Epoch 106/200
# 34391/34391 [==============================] - 91s 3ms/step - loss: 0.5248 - accuracy: 0.7112
# Epoch 107/200
# 34391/34391 [==============================] - 90s 3ms/step - loss: 0.5244 - accuracy: 0.7126
# Epoch 108/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5247 - accuracy: 0.7122
# Epoch 109/200
# 34391/34391 [==============================] - 91s 3ms/step - loss: 0.5248 - accuracy: 0.7121
# Epoch 110/200
# 34391/34391 [==============================] - 90s 3ms/step - loss: 0.5245 - accuracy: 0.7119
# Epoch 111/200
# 34391/34391 [==============================] - 90s 3ms/step - loss: 0.5233 - accuracy: 0.7129
# Epoch 112/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5235 - accuracy: 0.7129
# Epoch 113/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5235 - accuracy: 0.7137
# Epoch 114/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5228 - accuracy: 0.7139
# Epoch 115/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5227 - accuracy: 0.7139
# Epoch 116/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5234 - accuracy: 0.7137
# Epoch 117/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5221 - accuracy: 0.7149
# Epoch 118/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5224 - accuracy: 0.7141
# Epoch 119/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5219 - accuracy: 0.7147
# Epoch 120/200
# 34391/34391 [==============================] - 90s 3ms/step - loss: 0.5216 - accuracy: 0.7146
# Epoch 121/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5219 - accuracy: 0.7148
# Epoch 122/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5216 - accuracy: 0.7151
# Epoch 123/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5210 - accuracy: 0.7152
# Epoch 124/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5209 - accuracy: 0.7158
# Epoch 125/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5202 - accuracy: 0.7152
# Epoch 126/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5208 - accuracy: 0.7156
# Epoch 127/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5203 - accuracy: 0.7166
# Epoch 128/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5206 - accuracy: 0.7161
# Epoch 129/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5209 - accuracy: 0.7157
# Epoch 130/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5205 - accuracy: 0.7159
# Epoch 131/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5202 - accuracy: 0.7163
# Epoch 132/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5196 - accuracy: 0.7172
# Epoch 133/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5195 - accuracy: 0.7176
# Epoch 134/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5189 - accuracy: 0.7169
# Epoch 135/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5191 - accuracy: 0.7173
# Epoch 136/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5192 - accuracy: 0.7171
# Epoch 137/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5184 - accuracy: 0.7183
# Epoch 138/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5193 - accuracy: 0.7171
# Epoch 139/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5180 - accuracy: 0.7181
# Epoch 140/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5182 - accuracy: 0.7180
# Epoch 141/200
# 34391/34391 [==============================] - 90s 3ms/step - loss: 0.5183 - accuracy: 0.7178
# Epoch 142/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5189 - accuracy: 0.7176
# Epoch 143/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5175 - accuracy: 0.7194
# Epoch 144/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5169 - accuracy: 0.7198
# Epoch 145/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5163 - accuracy: 0.7201
# Epoch 146/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5164 - accuracy: 0.7201
# Epoch 147/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5168 - accuracy: 0.7201
# Epoch 148/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5165 - accuracy: 0.7196
# Epoch 149/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5160 - accuracy: 0.7203
# Epoch 150/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5159 - accuracy: 0.7202
# Epoch 151/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5151 - accuracy: 0.7214
# Epoch 152/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5154 - accuracy: 0.7214
# Epoch 153/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5154 - accuracy: 0.7210
# Epoch 154/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5154 - accuracy: 0.7203
# Epoch 155/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5142 - accuracy: 0.7222
# Epoch 156/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5141 - accuracy: 0.7212
# Epoch 157/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5140 - accuracy: 0.7224
# Epoch 158/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5148 - accuracy: 0.7217
# Epoch 159/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5140 - accuracy: 0.7219
# Epoch 160/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5139 - accuracy: 0.7220
# Epoch 161/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5136 - accuracy: 0.7225
# Epoch 162/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5131 - accuracy: 0.7228
# Epoch 163/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5135 - accuracy: 0.7223
# Epoch 164/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5142 - accuracy: 0.7219
# Epoch 165/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5138 - accuracy: 0.7223
# Epoch 166/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5125 - accuracy: 0.7230
# Epoch 167/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5125 - accuracy: 0.7234
# Epoch 168/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5133 - accuracy: 0.7217
# Epoch 169/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5122 - accuracy: 0.7237
# Epoch 170/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5130 - accuracy: 0.7230
# Epoch 171/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5125 - accuracy: 0.7232
# Epoch 172/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5130 - accuracy: 0.7231
# Epoch 173/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5117 - accuracy: 0.7241
# Epoch 174/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5124 - accuracy: 0.7234
# Epoch 175/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5123 - accuracy: 0.7228
# Epoch 176/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5123 - accuracy: 0.7231
# Epoch 177/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5122 - accuracy: 0.7241
# Epoch 178/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5115 - accuracy: 0.7235
# Epoch 179/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5122 - accuracy: 0.7235
# Epoch 180/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5122 - accuracy: 0.7237
# Epoch 181/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5116 - accuracy: 0.7236
# Epoch 182/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5120 - accuracy: 0.7239
# Epoch 183/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5114 - accuracy: 0.7245
# Epoch 184/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5117 - accuracy: 0.7240
# Epoch 185/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5114 - accuracy: 0.7247
# Epoch 186/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5115 - accuracy: 0.7245
# Epoch 187/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5120 - accuracy: 0.7240
# Epoch 188/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5103 - accuracy: 0.7250
# Epoch 189/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5116 - accuracy: 0.7237
# Epoch 190/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5113 - accuracy: 0.7240
# Epoch 191/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5104 - accuracy: 0.7254
# Epoch 192/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5096 - accuracy: 0.7256
# Epoch 193/200
# 34391/34391 [==============================] - 90s 3ms/step - loss: 0.5100 - accuracy: 0.7247
# Epoch 194/200
# 34391/34391 [==============================] - 94s 3ms/step - loss: 0.5105 - accuracy: 0.7250
# Epoch 195/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5108 - accuracy: 0.7252
# Epoch 196/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5103 - accuracy: 0.7241
# Epoch 197/200
# 34391/34391 [==============================] - 88s 3ms/step - loss: 0.5105 - accuracy: 0.7249
# Epoch 198/200
# 34391/34391 [==============================] - 89s 3ms/step - loss: 0.5102 - accuracy: 0.7261
# Epoch 199/200
# 34391/34391 [==============================] - 90s 3ms/step - loss: 0.5101 - accuracy: 0.7258
# Epoch 200/200
# 34391/34391 [==============================] - 91s 3ms/step - loss: 0.5106 - accuracy: 0.7258

# %%
def precision_recall(gt,preds):
    TP=0
    FP=0
    FN=0
    for t in gt:
        if t in preds:
            TP+=1
        else:
            FN+=1
    for p in preds:
        if p not in gt:
            FP+=1
    if TP+FP==0:
        precision=0
    else:
        precision=TP/float(TP+FP)
    if TP+FN==0:
        recall=0
    else:
        recall=TP/float(TP+FN)
    return precision,recall

# %%
Y_preds=model_visual.predict(X_test)

# %%
import pickle
f6=open('/content/drive/My Drive/Genredict.pckl','rb')
Genre_ID_to_name=pickle.load(f6)
f6.close()

# %%
genre_list=sorted(list(Genre_ID_to_name.keys()))

# %%
del f6 
del pickle

# %%
sum(sum(Y_preds))
# Out:
# 67604.72143554688

# %%
import pandas as pd
df = pd.read_pickle("/content/drive/My Drive/pinky_promise_last.pckl")

# %%
import numpy as np
positions=range(len(df))
# print positions
test_movies=np.asarray(positions)[~mask]
# test_movies

# %%
import numpy as np

precs=[]
recs=[]
for i in range(len(Y_preds)):
    row=Y_preds[i]
    gt_genres=Y_test[i]
    gt_genre_names=[]
    for j in range(14):
        if gt_genres[j]==1:
            gt_genre_names.append(Genre_ID_to_name[genre_list[j]])
    top_3=np.argsort(row)[-4:]
    predicted_genres=[]
    for genre in top_3:
        predicted_genres.append(Genre_ID_to_name[genre_list[genre]])
    (precision,recall)=precision_recall(gt_genre_names,predicted_genres)
    precs.append(precision)
    recs.append(recall)
    print("Predicted: ",','.join(predicted_genres)," Actual: ",','.join(gt_genre_names))
# Out:
# Streaming output truncated to the last 5000 lines.
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Action,Western,Science Fiction,Mystery
# Predicted:  Thriller,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Animation,Drama,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Action,Western,Science Fiction,Mystery
# Predicted:  Crime,Adventure,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Action,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,Comedy,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Crime,Adventure,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Animation,Drama,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Crime,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Western,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Drama,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Animation,Drama,History,Thriller,Science Fiction,Mystery
# Predicted:  Thriller,Crime,Science Fiction,Mystery  Actual:  Drama,Horror,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Action,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,Comedy,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Crime,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Western,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Western,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,Western,Documentary,Science Fiction,Mystery
# Predicted:  Action,Crime,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Crime,Thriller,Science Fiction,Mystery  Actual:  Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Comedy,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,Comedy,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Action,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Western,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Adventure,Science Fiction,Mystery  Actual:  Animation,Drama,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Drama,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Western,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Animation,Drama,History,Thriller,Science Fiction,Mystery
# Predicted:  Drama,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Action,Thriller,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Action,Western,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Comedy,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Comedy,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Crime,Action,Science Fiction,Mystery  Actual:  Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Drama,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Horror,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Action,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Thriller,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,Western,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Action,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Western,Documentary,Science Fiction,Mystery
# Predicted:  Action,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Western,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Animation,Drama,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Drama,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Comedy,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Animation,Drama,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Drama,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Fantasy,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Action,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Drama,Comedy,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Thriller,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Drama,Adventure,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Crime,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Thriller,Action,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Crime,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Western,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Action,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Adventure,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# ...
# Predicted:  Drama,Fantasy,Science Fiction,Mystery  Actual:  Drama,Western,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Drama,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Western,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Horror,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  History,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Drama,Western,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Drama,Western,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Western,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,Western,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,Comedy,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Drama,Documentary,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Drama,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,History,Thriller,Science Fiction,Mystery
# Predicted:  Drama,Fantasy,Science Fiction,Mystery  Actual:  Drama,Western,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Documentary,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Drama,Documentary,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Horror,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Western,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,Comedy,History,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Western,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Crime,Science Fiction,Mystery
# Predicted:  Drama,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Western,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Drama,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Western,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Drama,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Western,Thriller,Science Fiction,Mystery
# Predicted:  Drama,Documentary,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Crime,Science Fiction,Mystery
# Predicted:  Drama,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Documentary,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  History,Fantasy,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Horror,Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Science Fiction,Mystery
# Predicted:  History,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Western,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,History,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Documentary,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Western,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Documentary,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Horror,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Western,Science Fiction,Mystery
# Predicted:  Drama,Fantasy,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  History,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  History,Drama,Science Fiction,Mystery  Actual:  Drama,Western,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Crime,Science Fiction,Mystery
# Predicted:  Documentary,Drama,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Drama,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,History,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Horror,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Drama,Horror,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Horror,Crime,Science Fiction,Mystery

# %%
print(np.mean(np.asarray(precs)),np.mean(np.asarray(recs)))
print("avg=",(np.mean(np.asarray(precs))+np.mean(np.asarray(recs)))/2)
# Out:
# 0.8701525561895889 0.5006249527939292
# avg= 0.685388754491759

# %%
print("f1-score", (2*(np.mean(np.asarray(precs)) * np.mean(np.asarray(recs)))) / (np.mean(np.asarray(precs)) + np.mean(np.asarray(recs))))
# Out:
# f1-score 0.6355810180879873

# %%
import pickle

f1=open('/content/drive/My Drive/posters_new_features1.pckl','rb')
#f2=open('/content/drive/My Drive/posters_new_features2.pckl','rb')
#f3=open('/content/drive/My Drive/posters_new_features3.pckl','rb')


list_pickled1=pickle.load(f1)
#list_pickled2=pickle.load(f2)
#list_pickled3=pickle.load(f3)

f1.close()
#f2.close()
#f3.close()

# %%
list_pickled1[4]
# Out:
# ['[28, 878]',
#  '[28, 18, 36, 10752]',
#  '[28, 12, 878]',
#  '[28, 878]',
#  '[28, 35, 80]',
#  '[28, 12, 878]',
#  '[28, 18, 53]',
#  '[28, 12, 14]',
#  '[28, 12, 14]',
#  '[28, 12, 878]',
#  '[28, 53, 878]',
#  '[14, 12, 878, 28]',
#  '[28, 12, 35, 14]',
#  '[28, 12, 878, 53]',
#  '[28, 12, 14, 878]',
#  '[28, 12, 878]',
#  '[28, 12, 16, 35, 878]',
#  '[80, 28, 53]',
#  '[28, 80, 53]',
#  '[28, 53, 878]',
#  '[28, 878]',
#  '[28, 12, 14, 10749, 10751]',
#  '[28, 80, 18, 53]',
#  '[28, 18, 878]',
#  '[28, 9648, 878, 53]',
#  '[28, 12, 14]',
#  '[28, 35, 10751]',
#  '[28, 12, 14]',
#  '[28, 12, 14]',
#  '[28, 12, 80]',
#  '[28, 12, 35, 878]',
#  '[28, 35, 14]',
#  '[28, 12, 14]',
#  '[28, 80, 53]',
#  '[28, 12, 35, 878]',
#  '[28, 12, 14, 878]',
#  '[28, 12, 14]',
#  '[28, 12, 14, 878]',
#  '[28, 80, 18, 53]',
#  '[28, 12, 14, 878, 53]',
#  '[28, 12, 80, 53]',
#  '[28, 80, 53]',
#  '[28, 12, 80, 14, 878]',
#  '[28, 12]',
#  '[28, 14]',
#  '[28, 12, 14]',
#  '[28, 80, 18, 53]',
#  '[28, 53]',
#  '[28, 12, 53]',
#  '[28, 18, 9648]',
#  '[28, 12, 878]',
#  '[28, 53]',
#  '[28, 12, 80, 53]',
#  '[28, 12]',
#  '[28, 12, 18, 53]',
#  '[28, 12, 16, 10751]',
#  '[28, 12, 878]',
#  '[28, 12, 16, 35]',
#  '[28, 35, 80, 53]',
#  '[28, 18, 53]',
#  '[28, 12, 14, 878]',
#  '[28, 12, 14, 878]',
#  '[28, 35]',
#  '[28, 878, 53]',
#  '[28, 12, 14]',
#  '[28, 12, 878]',
#  '[28, 878, 53]',
#  '[28, 14, 878, 53]',
#  '[28, 12, 35, 14, 878]',
#  '[28, 12, 878]',
#  '[28, 53, 878]',
#  '[28, 53]',
#  '[28, 12, 53]',
#  '[28, 12, 878]',
#  '[28, 12, 35, 27, 878, 53]',
#  '[53, 28]',
#  '[28, 12, 878]',
#  '[28, 12, 35, 14, 10751]',
#  '[28, 12, 878]',
#  '[28, 27, 878, 53]',
#  '[28, 12, 878]',
#  '[28, 12, 35, 14]',
#  '[28, 35, 878]',
#  '[28, 18, 53]',
#  '[28, 12, 53]',
#  '[28, 12, 14]',
#  '[28, 12, 14]',
#  '[28, 12, 14, 878]',
#  '[28, 12, 878]',
#  '[28, 53, 12]',
#  '[28, 878]',
#  '[28, 12, 80]',
#  '[28, 14, 53]',
#  '[28, 12, 878]',
#  '[28, 12, 53, 10752]',
#  '[28, 9648, 878]',
#  '[28, 12, 878]',
#  '[12, 28, 878]',
#  '[28, 12, 878, 53]',
#  '[28, 35, 10751]',
#  '[53, 28, 18, 878]',
#  '[28, 12, 14]',
#  '[28, 80, 53]',
#  '[878, 28, 12]',
#  '[28, 12, 53]',
#  '[28, 80, 53]',
#  '[28, 878]',
#  '[28, 12, 878, 53]',
#  '[12, 28, 53, 878]',
#  '[53, 878, 28, 12]',
#  '[28, 53, 878, 27]',
#  '[53, 28, 80]',
#  '[28, 12, 14]',
#  '[28, 12, 53]',
#  '[28, 80, 53]',
#  '[28, 35]',
#  '[28, 18, 36, 10752]',
#  '[12, 28, 53]',
#  '[28, 18, 27, 878, 53]',
#  '[28, 12, 18, 36, 10749]',
#  '[28, 53]',
#  '[28, 18, 53]',
#  '[28, 12, 878]',
#  '[28, 18, 9648, 53]',
#  '[28, 27, 878]',
#  '[28, 12]',
#  '[28, 27, 53]',
#  '[28, 12, 14]',
#  '[28, 12, 35, 878, 37]',
#  '[28, 12, 14]',
#  '[28, 12, 18, 27, 878, 53, 37]',
#  '[28, 9648, 878, 53]',
#  '[28, 18]',
#  '[28, 18, 9648, 53]',
#  '[28]',
#  '[28, 35, 878]',
#  '[28, 18]',
#  '[28, 12, 53]',
#  '[28, 12, 18, 36]',
#  '[28, 878, 10752]',
#  '[28, 53]',
#  '[28, 16, 35, 14, 10751]',
#  '[28, 12, 53, 10752]',
#  '[28, 12, 18]',
#  '[28, 12, 878, 53, 10749]',
#  '[28, 12, 16, 35, 14, 10751]',
#  '[878, 12, 18, 28]',
#  '[28, 12, 878, 53]',
#  '[12, 28, 53]',
#  '[28, 12, 18, 14, 9648, 10749]',
#  '[28, 12, 14]',
#  '[28, 12, 878]',
#  '[28, 12, 14]',
#  '[28, 12, 878]',
#  '[28, 12, 80, 9648]',
#  '[28, 878]',
#  '[12, 28, 80, 9648]',
#  '[28, 53]',
#  '[28, 80, 18, 53]',
#  '[28, 12, 35, 10752]',
#  '[28, 12, 53]',
#  '[28, 12, 53, 9648]',
#  '[28, 53]',
#  '[28, 80, 18, 9648, 53]',
#  '[12, 28, 53]',
#  '[28, 12, 53]',
#  '[28, 80, 53]',
#  '[28, 80, 53]',
#  '[28, 12, 878]',
#  '[28, 12, 53]',
#  '[28, 53]',
#  '[28, 12, 878, 53]',
#  '[28, 16, 35, 10751]',
#  '[28, 80, 53]',
#  '[28, 35]',
#  '[28, 16, 35, 878, 10751]',
#  '[28, 53]',
#  '[28, 80, 18]',
#  '[53, 28, 80, 9648]',
#  '[28, 53]',
#  '[9648, 878, 28]',
#  '[28, 12, 53]',
#  '[28, 12, 9648, 878]',
#  '[28, 12, 878]',
#  '[28, 12]',
#  '[28, 12, 14, 878]',
#  '[28, 35, 53]',
#  '[28, 35, 80]',
#  '[28, 80]',
#  '[28, 878, 53]',
#  '[28, 12, 16, 35, 10751, 878, 14]',
#  '[28, 12, 53]',
#  '[18, 28]',
#  '[28, 12, 14]',
#  '[28, 35, 80]',
#  '[28, 80, 18, 53]',
#  '[28]',
#  '[28, 53]',
#  '[28, 16]',
#  '[28, 35, 14]',
#  '[28, 12, 878, 53]',
#  '[10402, 35, 28, 80]',
#  '[28, 12, 878, 53]',
#  '[28, 18, 878]',
#  '[28, 12, 37]',
#  '[28, 18, 878, 53]',
#  '[28, 16, 35, 878]',
#  '[28, 35, 80, 9648]',
#  '[28, 12, 36]',
#  '[28, 53]',
#  '[28, 9648, 53]',
#  '[28, 12, 878]',
#  '[28, 12, 878, 53]',
#  '[28]',
#  '[28, 14, 27, 9648, 53]',
#  '[28, 18]',
#  '[12, 28, 53, 80, 9648]',
#  '[878, 28, 12]',
#  '[28, 80, 53]',
#  '[18, 28]',
#  '[28, 18, 10752]',
#  '[28, 12, 80]',
#  '[28, 12, 9648, 53]',
#  '[28]',
#  '[28, 18, 14, 27]',
#  '[28, 27, 878]',
#  '[28, 878, 53]',
#  '[28, 18, 36, 53]',
#  '[28, 53]',
#  '[28, 12, 14, 878]',
#  '[28, 12, 53]',
#  '[28, 12, 35, 14, 10751]',
#  '[28, 80, 18, 53]',
#  '[28, 53]',
#  '[28, 18, 10402, 53, 10749]',
#  '[28, 80, 53]',
#  '[28, 12, 18, 36, 10749, 10752]',
#  '[28, 12, 10752]',
#  '[28, 12, 878]',
#  '[28, 53, 878]',
#  '[28, 12, 53]',
#  '[28, 9648, 53]',
#  '[28, 35, 80, 53]',
#  '[28, 35, 80]',
#  '[28, 12, 9648, 53]',
#  '[28, 12, 14]',
#  '[28]',
#  '[28, 53, 80]',
#  '[28, 878, 53]',
#  '[28, 12, 14]',
#  '[28, 12, 878, 53]',
#  '[28, 53]',
#  '[28, 12, 18, 53]',
#  '[28, 12, 53]',
#  '[28, 12, 37]',
#  '[28, 18, 10752]',
#  '[28, 12, 16, 14, 10751]',
#  '[28, 80, 53]',
#  '[28, 14, 878, 53]',
#  '[28, 35, 80, 18]',
#  '[28, 53, 10749]',
#  '[28, 12, 80, 53]',
#  '[28, 14, 12]',
#  '[18, 10752, 28]',
#  '[28, 12, 16, 878]',
#  '[28, 12, 878]',
#  '[28, 12, 80, 53]',
#  '[28, 12]',
#  '[28, 80, 53]',
#  '[28, 12, 53]',
#  '[28, 12, 35]',
#  '[28, 18, 53]',
#  '[28, 80, 53]',
#  '[28, 80]',
#  '[28, 18, 53]',
#  '[28, 12, 16, 35, 10751]',
#  '[28, 18, 36]',
#  '[28, 12, 878]',
#  '[28, 12, 878]',
#  '[28, 12, 18]',
#  '[28, 12, 35, 80, 53]',
#  '[28, 12, 53]',
#  '[28, 18, 53]',
#  '[28, 12, 16, 10751]',
#  '[878, 27, 28, 35]',
#  '[28, 878, 12, 53]',
#  '[28, 53]',
#  '[28, 80]',
#  '[28, 12, 53]',
#  '[28, 12, 80, 53]',
#  '[28, 53]',
#  '[28, 35]',
#  '[28, 18, 53]',
#  '[28, 12, 14, 10752]',
#  '[28, 35, 18, 37, 10751]',
#  '[28, 12, 878]',
#  '[28, 12, 16, 10751]',
#  '[28, 35]',
#  '[28, 18]',
#  '[28, 12, 878, 53]',
#  '[28, 12]',
#  '[28, 12, 878]',
#  '[28, 12, 80, 18, 9648, 53]',
#  '[28, 80, 18]',
#  '[28, 878, 53]',
#  '[28, 12, 9648, 878, 53]',
#  '[28, 12, 14, 10751]',
#  '[28, 12, 35, 10749]',
#  '[28, 35]',
#  '[28, 27, 53]',
#  '[28, 53]',
#  '[28, 12, 80, 53]',
#  '[28, 12, 9648, 878, 53]',
#  '[28, 35, 10749]',
#  '[28, 18, 53]',
#  '[28, 12, 878]',
#  '[28, 18, 53]',
#  '[28, 12, 18]',
#  '[28, 12, 16, 35, 14, 10751]',
#  '[28, 80, 18]',
#  '[28, 80]',
#  '[28, 80, 53]',
#  '[28, 12, 878, 53]',
#  '[28, 53]',
#  '[28, 53]',
#  '[28, 35, 80]',
#  '[14, 28, 878]',
#  '[28, 80, 53]',
#  '[28, 878, 53]',
#  '[10752, 28, 53, 878]',
#  '[28, 12, 14, 10749]',
#  '[28, 12, 36, 10749, 18]',
#  '[28, 35, 18]',
#  '[28, 80, 18, 53]',
#  '[28, 12, 35]',
#  '[28, 16, 878, 10751]',
#  '[28, 80, 53]',
#  '[12, 28, 18, 53]',
#  '[28, 12, 14]',
#  '[28, 18]',
#  '[28, 12, 35, 878, 10751]',
#  '[28, 35, 80]',
#  '[28, 35, 878]',
#  '[28, 80, 53]',
#  '[18, 36, 10752, 28]',
#  '[28, 80, 53]',
#  '[28, 80, 53]',
#  '[35, 878, 28, 12]',
#  '[28, 18]',
#  '[28, 12]',
#  '[28]',
#  '[14, 28, 53]',
#  '[28, 12]',
#  '[28, 12, 14, 878, 10751]',
#  '[28, 35, 80]',
#  '[28, 35, 9648, 10749]',
#  '[28, 35, 80]',
#  '[28]',
#  '[28, 12, 14, 878, 53]',
#  '[28, 18, 10752]',
#  '[28, 80, 53]',
#  '[28, 12, 35, 14, 878, 10751]',
#  '[28, 12, 14]',
#  '[53, 80, 28]',
#  '[28, 12, 18, 53]',
#  '[28, 9648, 53]',
#  '[28, 80, 18]',
#  '[28, 80, 53]',
#  '[28, 12, 35]',
#  '[28, 27, 9648]',
#  '[28, 12, 35, 878, 10751]',
#  '[12, 28, 53, 878]',
#  '[28, 9648, 53]',
#  '[28, 36, 10752]',
#  '[28, 12]',
#  '[28, 12, 878, 53]',
#  '[28, 12, 80, 878, 53]',
#  '[28, 80, 18, 53]',
#  '[28, 18, 53]',
#  '[37, 28]',
#  '[28, 27, 878, 53]',
#  '[28, 80]',
#  '[28, 18, 9648, 53]',
#  '[28, 80, 878, 53]',
#  '[28, 12]',
#  '[28, 12, 14]',
#  '[28, 12, 80, 878, 53]',
#  '[28, 12, 53]',
#  '[28]',
#  '[28, 14, 10402, 10751]',
#  '[28, 35]',
#  '[28, 53]',
#  '[28, 80, 53]',
#  '[28, 12, 878]',
#  '[28, 80, 53]',
#  '[28, 80, 878, 53]',
#  '[28, 35, 80]',
#  '[28, 80, 18, 53]',
#  '[28, 27, 53]',
#  '[28, 14, 53]',
#  '[28, 18, 53, 10752]',
#  '[28, 12, 80, 18, 53]',
#  '[28, 12, 10751, 10770]',
#  '[28, 14, 53]',
#  '[28, 12, 18, 53, 10770]',
#  '[18, 28]',
#  '[28, 35, 80, 10749]',
#  '[28, 16, 35, 10751]',
#  '[28, 18, 9648]',
#  '[28, 12, 18, 36, 10752]',
#  '[28, 12, 53]',
#  '[28, 80, 18, 9648, 53]',
#  '[28, 878, 53]',
#  '[28, 12, 16, 878]',
#  '[28, 35, 80]',
#  '[28, 53]',
#  '[53, 18, 28]',
#  '[28, 35, 53]',
#  '[28, 18, 9648, 53]',
#  '[28, 12, 14, 878]',
#  '[28, 10752]',
#  '[878, 28, 27]',
#  '[28, 12, 14]',
#  '[28, 12, 878]',
#  '[18, 28, 53, 80]',
#  '[28, 80, 18, 9648, 53]',
#  '[10752, 28, 18, 36]',
#  '[28, 27, 53]',
#  '[28, 16, 18, 878]',
#  '[28, 35, 878, 53]',
#  '[28, 53]',
#  '[28, 12, 35]',
#  '[28, 12, 878, 53, 10749]',
#  '[28, 80, 53]',
#  '[28, 80, 18, 53]',
#  '[28, 27, 878]',
#  '[28, 27, 878]',
#  '[28, 878, 53]',
#  '[28, 18, 36, 53]',
#  '[28, 12, 80, 18, 9648, 53]',
#  '[28]',
#  '[28, 878]',
#  '[28, 80, 53]',
#  '[28, 12, 18]',
#  '[28, 18, 37]',
#  '[28, 18, 53]',
#  '[28, 10752]',
#  '[28, 80, 53]',
#  '[28, 12, 18, 10749]',
#  '[28, 12, 878, 10751]',
#  '[28, 12, 27, 53]',
#  '[28, 80]',
#  '[28, 80, 878, 53]',
#  '[28, 12, 14, 878, 53, 10751]',
#  '[28, 35, 80, 53]',
#  '[28, 12, 35, 14, 878]',
#  '[28, 12, 53]',
#  '[28, 18, 27, 9648, 53]',
#  '[28, 35, 10749]',
#  '[28, 12, 35, 10751]',
#  '[28, 878, 53]',
#  '[28, 80, 53]',
#  '[28, 80, 18, 53]',
#  '[28, 12, 18, 878]',
#  '[28, 35]',
#  '[28, 80, 53]',
#  '[28, 18, 53]',
#  '[28, 12, 16, 14, 878]',
#  '[28, 12, 80, 53]',
#  '[28, 80, 18, 53]',
#  '[28, 35, 9648, 53]',
#  '[28, 80, 53]',
#  '[28, 12, 35, 53]',
#  '[28, 36, 53, 10752]',
#  '[878, 28, 12, 53]',
#  '[28, 878, 27]',
#  '[28, 18, 53]',
#  '[878, 28, 12, 53]',
#  '[28, 12, 14]',
#  '[28, 10752]',
#  '[28, 80, 18]',
#  '[28, 27, 9648, 878, 53]',
#  '[28, 12, 35, 14, 878]',
#  '[28, 27, 878]',
#  '[28, 80, 53]',
#  '[28, 53]',
#  '[28, 12, 35, 14, 53]',
#  '[28, 80, 18, 53]',
#  '[28, 35, 80]',
#  '[28, 80, 53]',
#  '[28, 18, 36, 10752]',
#  '[28, 35, 80, 18, 14, 878]',
#  '[28, 53]',
#  '[28, 18, 53]',
#  '[28, 35, 80]',
#  '[28, 12, 80, 9648, 53]',
#  '[28, 12, 18, 53]',
#  '[28, 12, 14]',
#  '[18, 28, 12, 36, 10752]',
#  '[28, 12, 878]',
#  '[28, 80, 53, 10749]',
#  '[28, 80, 53]',
#  '[28, 35]',
#  '[28, 80, 18, 9648, 53]',
#  '[10752, 28, 53, 18]',
#  '[28]',
#  '[28]',
#  '[28, 35, 80]',
#  '[28, 12, 27, 53]',
#  '[28, 53]',
#  '[28, 18, 27, 53]',
#  '[28, 18, 37]',
#  '[28, 12, 878]',
#  '[28, 12, 27, 878]',
#  '[28, 27, 878, 53]',
#  '[28]',
#  '[28, 35, 27, 878, 53, 10770]',
#  '[28, 35, 878]',
#  '[28, 80]',
#  '[28, 12, 35, 10402, 10751]',
#  '[28, 12, 18, 10749, 53]',
#  '[28, 878]',
#  '[28, 80, 18, 9648, 53]',
#  '[28, 80, 53]',
#  '[28, 12, 18, 36, 10752]',
#  '[28, 12, 878, 14]',
#  '[28, 12, 14]',
#  '[28, 12, 35, 10749]',
#  '[28, 878, 53]',
#  '[28, 16, 10751]',
#  '[28, 12, 18, 36]',
#  '[28, 12, 18, 14]',
#  '[28, 12, 35, 37]',
#  '[28, 12, 16, 10751]',
#  '[28, 16, 878]',
#  '[28]',
#  '[28, 12, 27, 53]',
#  '[28, 16, 35, 10751]',
#  '[28, 27, 878]',
#  '[28, 12, 53, 18, 878]',
#  '[28, 14, 878]',
#  '[28, 80, 9648, 53]',
#  '[12, 28, 53, 878]',
#  '[28, 12, 18]',
#  '[28, 12, 53]',
#  '[28, 18]',
#  '[28]',
#  '[28, 80, 18, 53]',
#  '[28, 18, 53]',
#  '[28, 80, 18, 53]',
#  '[28, 35, 18, 10749]',
#  '[28, 80]',
#  '[28, 80, 18, 53]',
#  '[28, 53]',
#  '[28, 18, 14, 27, 53, 37]',
#  '[28, 12, 53]',
#  '[28, 12, 35, 37]',
#  '[28, 80, 18, 53]',
#  '[28, 12, 18, 14]',
#  '[28, 80, 9648, 53]',
#  '[28, 12, 35, 18, 14, 53, 10749]',
#  '[28, 35, 80, 53]',
#  '[28, 12, 53]',
#  '[28, 12, 35, 10749]',
#  '[28, 27, 53]',
#  '[28, 18, 878, 53]',
#  '[28, 35]',
#  '[28, 12, 878, 53]',
#  '[28, 53]',
#  '[28, 35, 80, 53]',
#  '[28, 9648, 53]',
#  '[28, 10752]',
#  '[28, 12, 37]',
#  '[28]',
#  '[28, 53]',
#  '[28, 35, 10751]',
#  '[28, 878, 53]',
#  '[28, 80, 18, 53]',
#  '[28, 12, 35, 10402, 10751]',
#  '[28, 35]',
#  '[28, 80, 18, 878, 53]',
#  '[28, 53]',
#  '[28, 12, 35, 878, 10751]',
#  '[28, 35, 18]',
#  '[28, 12, 35]',
#  '[28, 16, 878]',
#  '[28, 53]',
#  '[28, 12, 27, 53]',
#  '[28, 14, 27]',
#  '[28, 35]',
#  '[28, 53]',
#  '[28, 12, 16]',
#  '[28]',
#  '[28, 12, 878, 53]',
#  '[28, 80, 18, 36, 53]',
#  '[27, 28, 53]',
#  '[28, 35, 10751]',
#  '[28, 12, 80, 18, 53, 37]',
#  '[28, 35]',
#  '[28, 80, 53]',
#  '[28, 53, 27]',
#  '[28, 12, 35, 80, 18, 53]',
#  '[28, 16, 18, 14, 27, 9648, 878, 53, 10751]',
#  '[37, 28, 18]',
#  '[28, 16, 878]',
#  '[28, 80, 53]',
#  '[28, 12, 18, 53]',
#  '[28, 18, 53]',
#  '[12, 28, 35]',
#  '[12, 28, 35]',
#  '[28, 12, 35, 18, 9648]',
#  '[28, 16, 878, 10751, 10770]',
#  '[28, 16, 14, 27]',
#  '[28, 53]',
#  '[28, 12, 10751, 14, 878, 53]',
#  '[28, 12, 35, 878, 10770]',
#  '[28, 12, 35, 27]',
#  '[28, 53]',
#  '[28, 53]',
#  '[12, 18, 28, 53, 10752]',
#  '[28, 878, 53]',
#  '[28, 12, 18]',
#  '[28, 27, 878, 53]',
#  '[28]',
#  '[28, 80, 18, 53]',
#  '[28]',
#  '[28, 12, 35, 80, 9648, 53, 10751]',
#  '[28, 18, 53]',
#  '[28, 53]',
#  '[28, 35, 80, 18, 53]',
#  '[28, 12, 18, 36]',
#  '[28, 12, 14, 878, 10751]',
#  '[28, 12, 27]',
#  '[28]',
#  '[28, 16, 35, 10751]',
#  '[28, 16]',
#  '[28, 12, 16, 35, 14, 878, 53, 10751]',
#  '[28, 12, 80, 18]',
#  '[28, 16, 878]',
#  '[28, 14]',
#  '[28, 80, 18, 9648, 53]',
#  '[28, 12, 35, 53]',
#  '[28, 14, 878]',
#  '[28, 27, 53]',
#  '[28, 27, 878]',
#  '[28, 12, 53]',
#  '[28, 14, 53]',
#  '[28, 53]',
#  '[28, 80, 9648, 53]',
#  '[28, 35, 27, 878]',
#  '[28, 18, 878]',
#  '[28, 80, 53]',
#  '[28, 878]',
#  '[28, 12, 35, 10751]',
#  '[28, 12, 80, 37]',
#  '[28, 12, 878]',
#  '[28, 14, 878, 53]',
#  '[18, 28]',
#  '[28, 12, 18, 36]',
#  '[28, 12, 35, 14, 878]',
#  '[28, 18, 36, 10752]',
#  '[28, 18, 53, 37, 10749]',
#  '[28, 35, 10749]',
#  '[28, 35, 53]',
#  '[28, 12, 18, 36]',
#  '[28, 80, 18, 53]',
#  '[28, 12, 35]',
#  '[28]',
#  '[28, 80, 14, 9648, 53]',
#  '[28, 80, 18, 9648, 53]',
#  '[28, 18]',
#  '[28, 27, 53]',
#  '[28]',
#  '[28, 12, 80, 18, 53]',
#  '[28]',
#  '[28, 35, 80, 878, 53]',
#  '[28, 35]',
#  '[28, 16, 878]',
#  '[28, 35, 80, 10749]',
#  '[28, 80, 53]',
#  '[28, 12, 14, 878]',
#  '[28, 12, 37]',
#  '[28, 80, 53]',
#  '[28]',
#  '[28, 12, 35, 53]',
#  '[878, 28]',
#  '[28, 12]',
#  '[28, 18, 53]',
#  '[10752, 28]',
#  '[28, 12, 53, 18]',
#  '[28, 12, 14, 27, 878, 53]',
#  '[28, 18, 36, 53, 10752]',
#  '[28, 18, 80]',
#  '[28, 80, 9648, 53]',
#  '[28, 80, 18, 53]',
#  '[28, 27, 878]',
#  '[28]',
#  '[28, 12, 18]',
#  '[28, 35, 37]',
#  '[28, 12, 878, 10751]',
#  '[28, 12, 80, 18, 37]',
#  '[28, 35]',
#  '[28, 12, 18, 27, 53]',
#  '[28, 36, 10752]',
#  '[28, 12, 35, 14]',
#  '[28, 878]',
#  '[28, 12, 35, 878, 10751]',
#  '[28, 12, 878]',
#  '[28, 35, 878]',
#  '[28]',
#  '[28, 80, 18, 27, 9648, 53]',
#  '[28, 80, 53]',
#  '[28, 12, 35, 27]',
#  '[28, 12, 53, 10752]',
#  '[28, 12, 18]',
#  '[28, 12, 18, 36]',
#  '[28, 35, 80, 53]',
#  '[878, 28]',
#  '[28, 35, 80]',
#  '[28, 53]',
#  '[28, 35, 80, 9648, 53]',
#  '[28, 12, 878, 53]',
#  '[28, 27]',
#  '[28, 35, 27, 37]',
#  '[28, 12, 14]',
#  '[28, 878, 10752]',
#  '[28, 12, 16, 35, 10751]',
#  '[28, 12, 35, 18, 10751, 10749]',
#  '[28, 12, 10751]',
#  '[28]',
#  '[28, 53]',
#  '[28, 80, 9648]',
#  '[28, 12, 878, 53]',
#  '[28, 12, 35, 14, 10751]',
#  '[28, 12, 10751]',
#  '[28, 37, 80]',
#  '[28, 12, 27, 878]',
#  '[28, 37]',
#  '[28, 80, 53]',
#  '[28, 12, 14, 10751]',
#  '[28, 35]',
#  '[28, 27]',
#  '[28, 12, 14]',
#  '[28, 80, 18, 53]',
#  '[28, 12, 35]',
#  '[28, 80, 53]',
#  '[80, 28, 53]',
#  '[18, 28, 53, 80]',
#  '[28, 35, 80]',
#  '[28, 12, 80, 53]',
#  '[28, 53, 12]',
#  '[28, 35, 14, 53]',
#  '[28, 18, 36, 10752]',
#  '[28, 37]',
#  '[28, 12, 35]',
#  '[27, 878, 28, 9648]',
#  '[28, 35, 10751, 878]',
#  '[37, 28]',
#  '[28, 12, 35]',
#  '[28, 80, 53]',
#  '[28, 80, 18, 53]',
#  '[28, 12, 53]',
#  '[28, 12, 35, 10751]',
#  '[12, 14, 28, 878]',
#  '[28, 35]',
#  '[28, 12]',
#  '[28, 12, 878]',
#  '[28, 35, 80, 53]',
#  '[35, 80, 28]',
#  '[28, 12, 16, 878]',
#  '[28, 12, 18, 10749, 10751]',
#  '[28, 35]',
#  '[28, 53]',
#  '[28, 878, 10770]',
#  '[28, 12, 18]',
#  '[28, 18, 27, 878]',
#  '[28, 18, 36, 10752]',
#  '[28, 37, 10749]',
#  '[28, 18, 53, 10752]',
#  '[28, 18, 14, 27]',
#  '[28, 18, 53]',
#  '[28, 80, 18, 9648, 53]',
#  '[28]',
#  '[28, 9648, 53]',
#  '[28, 12, 878]',
#  '[12, 28]',
#  '[28, 80, 18, 9648]',
#  '[28, 12, 53]',
#  '[28, 35, 80, 53]',
#  '[28]',
#  '[28, 53]',
#  '[28, 10752]',
#  '[28, 35, 27, 878]',
#  '[28, 12, 27, 878]',
#  '[28, 12, 14, 878, 53]',
#  '[28, 878, 53]',
#  '[28, 18]',
#  '[28, 12, 80]',
#  '[28]',
#  '[28, 35, 9648, 53]',
#  '[28, 27, 878, 10770]',
#  '[28, 53]',
#  '[28, 80, 53]',
#  '[28, 18]',
#  '[18, 28, 35, 80]',
#  '[28, 35, 14, 878, 10751]',
#  '[28, 12, 18, 37, 10749]',
#  '[28, 12, 53]',
#  '[28, 12, 18, 53, 10752]',
#  '[28, 27]',
#  '[28, 80, 18, 53]',
#  '[28, 12, 35]',
#  '[28, 12, 18, 36, 10752]',
#  '[28, 80, 18, 53]',
#  '[28, 12, 878]',
#  '[28]',
#  '[28, 12, 35]',
#  '[28, 80, 18, 53]',
#  '[28, 80, 18, 37]',
#  '[28, 53]',
#  '[27, 53, 28]',
#  '[28, 80, 18, 53]',
#  '[28, 18, 37, 10749]',
#  '[28, 12, 14, 10751]',
#  '[28, 12, 53]',
#  '[28, 80, 27, 53]',
#  '[28, 80, 18, 53]',
#  '[28, 80, 53]',
#  '[28, 35, 14, 878]',
#  '[28, 18, 36]',
#  '[99, 28, 12]',
#  '[28, 35, 10751]',
#  '[28, 12, 53, 37]',
#  '[28, 27]',
#  '[28, 12, 878]',
#  '[28, 12, 35, 10751]',
#  '[28, 35]',
#  '[35, 28, 14]',
#  '[28, 16, 878]',
#  '[28, 35]',
#  '[28, 80, 53]',
#  '[28, 878]',
#  '[28, 27, 878, 53]',
#  '[28, 12, 18, 10752]',
#  '[28, 12, 35, 14, 9648]',
#  '[28, 35, 10749]',
#  '[28, 53]',
#  '[28, 12, 10751]',
#  '[28, 80, 18, 53]',
#  '[28, 27, 37]',
#  '[28, 12, 18, 36]',
#  '[28, 18]',
#  '[28, 12, 878, 53]',
#  '[28, 80, 18, 53]',
#  '[28, 35, 27]',
#  '[28, 53]',
#  '[28, 16, 14]',
#  '[28, 12, 18, 37]',
#  '[28, 35, 80]',
#  '[28, 35, 80]',
#  '[28, 80, 18, 53]',
#  '[28, 80, 9648, 53]',
#  '[28, 53]',
#  '[28, 18, 53]',
#  '[28, 12, 35, 18, 37]',
#  '[28, 12, 16, 35, 14, 878]',
#  '[28, 53]',
#  '[28, 12, 80, 18]',
#  '[28, 12, 10752]',
#  '[28, 12, 35, 10749]',
#  '[12, 18, 28, 10751]',
#  '[28, 35, 80, 9648, 10751]',
#  '[28, 35, 80]',
#  '[28, 35, 14, 878]',
#  '[28, 80, 53]',
#  '[28]',
#  '[28, 12, 35, 14, 878, 10751]',
#  '[28, 18, 53]',
#  '[27, 28, 35]',
#  '[28, 12, 35, 14, 878, 53]',
#  '[28, 53]',
#  '[28, 53, 80]',
#  '[28, 12, 53]',
#  '[28, 35]',
#  '[28]',
#  '[28, 12, 16, 35, 10751]',
#  '[28, 18, 53]',
#  '[28, 80, 53]',
#  '[28, 12, 16]',
#  '[28, 53, 80, 18]',
#  '[28, 35, 27, 878, 53]',
#  '[28, 18, 878, 37]',
#  '[35, 53, 80, 28]',
#  '[28, 35, 10751]',
#  '[28, 27, 53]',
#  '[28, 35, 27, 878]',
#  '[28, 27, 53]',
#  '[28, 53]',
#  '[28, 12, 35, 878, 10770]',
#  '[28, 12, 18, 37]',
#  '[53, 28, 80, 18, 9648]',
#  '[28, 80]',
#  '[28]',
#  '[28, 18, 10749, 10752]',
#  '[28, 80, 18, 53]',
#  '[28, 9648, 53]',
#  '[28, 35]',
#  '[28, 18, 53]',
#  '[28, 37]',
#  '[28, 12, 18, 10751]',
#  '[18, 28, 53, 10749]',
#  '[28, 35, 10749]',
#  '[28, 80, 18, 9648, 53]',
#  '[28, 12, 35, 878]',
#  '[28, 18, 10752]',
#  '[28, 53]',
#  '[28, 80, 18]',
#  '[28, 18, 80, 53, 9648]',
#  '[28, 53, 878]',
#  '[28, 18, 53]',
#  '[18, 28, 80]',
#  '[28, 18, 10752]',
#  '[28]',
#  '[28, 12, 80, 53, 10749]',
#  '[28, 12, 18, 10751]',
#  '[28, 35, 18]',
#  '[28, 12, 80, 18, 9648, 53]',
#  '[28, 27, 878, 53]',
#  '[28, 878, 53]',
#  '[28, 37]',
#  '[28, 878, 53]',
#  '[28, 12, 35, 10402, 10751]',
#  '[28, 27, 878]',
#  '[28, 12, 16, 878, 10751]',
#  '[28, 18, 878, 53]',
#  '[28, 12, 10749]',
#  '[28, 12, 18]',
#  '[16, 28, 53, 878]',
#  '[28, 12, 18, 36]',
#  '[28, 80, 18, 53]',
#  '[28, 80, 53]',
#  '[28, 35]',
#  '[28, 12, 18, 10749]',
#  '[28, 80, 18, 53]',
#  '[28, 36, 27]',
#  '[28, 18, 10752]',
#  '[28, 35, 878]',
#  '[28, 12, 53]',
#  '[28, 80, 18, 53]',
#  '[28, 35, 9648]',
#  '[28, 12, 18, 10749]',
#  '[28, 12, 35, 14, 10751]',
#  '[28, 18]',
#  '[28, 12, 35, 18]',
#  '[28, 53, 80]',
#  '[28, 35]',
#  '[28, 53, 27]',
#  '[80, 28, 12]',
#  '[28, 35]',
#  '[28, 80, 18]',
#  '[28, 35]',
#  '[28, 18, 10749]',
#  '[28, 37]',
#  '[28, 12, 53, 18]',
#  '[28, 18]',
#  '[28, 18, 53]',
#  '[28, 35, 80, 18]',
#  '[28, 53]',
#  '[28, 35]',
#  '[37, 28]',
#  '[28, 35, 27]',
#  '[28, 35]',
#  '[28, 80, 18, 53]',
#  '[28, 18, 10749]',
#  '[28, 12, 878]',
#  '[28, 53]',
#  '[28, 80, 53]',
#  '[28, 27, 878]',
#  '[28, 16, 878]',
#  '[28, 878]',
#  '[28, 35]',
#  '[28, 27, 878]',
#  '[28, 35, 80]',
#  '[14, 28, 12, 878]',
#  '[28, 36, 18, 10749, 53, 10752]',
#  '[28]',
#  '[28, 53]',
#  '[28, 80, 53]',
#  '[35, 28, 18]',
#  '[28, 27]',
#  '[28]',
#  '[28, 27, 878, 53]',
#  '[28, 12, 18, 27, 10752]',
#  '[28, 12, 35, 18, 10749]',
#  '[18, 28, 53]',
#  '[28, 35, 80, 18, 53]',
#  '[28, 12, 14, 878, 53]',
#  '[28, 18, 53]',
#  '[28, 80, 53]',
#  '[28, 18, 36]',
#  ...]

# %%
del list_pickled1
del list_pickled2
del list_pickled3

# %%
del f1
del f2
del f3

# %%
type(list_pickled1)
# Out:
# tuple

# %%
def find_length(p):
  for i in p:
    print(len(i))

# %%
find_length(list_pickled1)
# Out:
# 14114
# 14114
# 0
# 14114
# 14114

# %% [markdown]
# 39133 Results

# %%
final_feature_list = list_pickled1[0] + list_pickled2[0] + list_pickled3[0] 
final_files = list_pickled1[1] + list_pickled2[1] + list_pickled3[1]
final_failed = list_pickled1[2] + list_pickled2[2] + list_pickled3[2]
final_succesful = list_pickled1[3] + list_pickled2[3] + list_pickled3[3]
final_genre_list = list_pickled1[4] + list_pickled2[4] + list_pickled3[4]

# %%
del final_files
del final_failed
del final_succesful
del final_genre_list

# %%
import pickle
list_pickled=(final_feature_list,final_files,final_failed,final_succesful,final_genre_list)
f=open('posters_final.pckl','wb')
pickle.dump(list_pickled,f)
f.close()

# %%
f7=open('posters_new_features.pckl','rb')
list_pickled=pickle.load(f7)
f7.close()

# %%
import numpy as np

(a,b,c,d)=final_feature_list[0].shape
feature_size=a*b*c*d

np_features=np.zeros((len(final_feature_list),feature_size))
for i in range(len(final_feature_list)):
    feat=final_feature_list[i]
    reshaped_feat=feat.reshape(1,-1)
    np_features[i]=reshaped_feat

X=np_features

from sklearn.preprocessing import MultiLabelBinarizer
mlb=MultiLabelBinarizer()
Y=mlb.fit_transform(final_genre_list)

Y.shape
# Out:
# (39133, 14)

# %%
visual_problem_data=(X,Y)
#f8=open('visual_problem_data_clean.pckl','wb')
#pickle.dump(visual_problem_data,f8)
#f8.close()

# %%
#import pickle
#f8=open('visual_problem_data_clean.pckl','rb')
visual_features=visual_problem_data
#f8.close()

# %%
(X,Y)=visual_features

# %%
X.shape
# Out:
# (39133, 25088)

# %%
mask = np.random.rand(len(X)) < 0.8

# %%
X_train=X[mask]
X_test=X[~mask]
Y_train=Y[mask]
Y_test=Y[~mask]

# %%
X_test.shape
# Out:
# (7843, 25088)

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras import optimizers
model_visual = Sequential([
    Dense(1024, input_shape=(25088,)),
    Activation('relu'),
    Dense(256),
    Activation('relu'),
    Dense(14),
    Activation('sigmoid'),
])
opt = optimizers.rmsprop(lr=0.0001, decay=1e-6)

#sgd = optimizers.SGD(lr=0.05, decay=1e-6, momentum=0.4, nesterov=False)
model_visual.compile(optimizer=opt,
              loss='binary_crossentropy',
              metrics=['accuracy'])
# Out:
# Using TensorFlow backend.

# %%
model_visual.fit(X_train, Y_train, epochs=10, batch_size=64,verbose=1)
# Out:
# Epoch 1/10
# 31290/31290 [==============================] - 9s 294us/step - loss: 0.7484 - accuracy: 0.6523
# Epoch 2/10
# 31290/31290 [==============================] - 8s 240us/step - loss: 0.5193 - accuracy: 0.7192
# Epoch 3/10
# 31290/31290 [==============================] - 8s 242us/step - loss: 0.4348 - accuracy: 0.7775
# Epoch 4/10
# 31290/31290 [==============================] - 8s 240us/step - loss: 0.3454 - accuracy: 0.8342
# Epoch 5/10
# 31290/31290 [==============================] - 7s 239us/step - loss: 0.2701 - accuracy: 0.8769
# Epoch 6/10
# 31290/31290 [==============================] - 8s 241us/step - loss: 0.2156 - accuracy: 0.9061
# Epoch 7/10
# 31290/31290 [==============================] - 8s 242us/step - loss: 0.1759 - accuracy: 0.9254
# Epoch 8/10
# 31290/31290 [==============================] - 8s 240us/step - loss: 0.1467 - accuracy: 0.9407
# Epoch 9/10
# 31290/31290 [==============================] - 8s 240us/step - loss: 0.1226 - accuracy: 0.9514
# Epoch 10/10
# 31290/31290 [==============================] - 8s 240us/step - loss: 0.1042 - accuracy: 0.9597

# %%
model_visual.fit(X_train, Y_train, epochs=50, batch_size=64,verbose=1)
# Out:
# Epoch 1/50
# 31290/31290 [==============================] - 7s 239us/step - loss: 0.0887 - accuracy: 0.9668
# Epoch 2/50
# 31290/31290 [==============================] - 7s 238us/step - loss: 0.0761 - accuracy: 0.9723
# Epoch 3/50
# 31290/31290 [==============================] - 7s 240us/step - loss: 0.0656 - accuracy: 0.9766
# Epoch 4/50
# 31290/31290 [==============================] - 8s 241us/step - loss: 0.0568 - accuracy: 0.9801
# Epoch 5/50
# 31290/31290 [==============================] - 7s 238us/step - loss: 0.0502 - accuracy: 0.9829
# Epoch 6/50
# 31290/31290 [==============================] - 7s 239us/step - loss: 0.0439 - accuracy: 0.9852
# Epoch 7/50
# 31290/31290 [==============================] - 7s 239us/step - loss: 0.0385 - accuracy: 0.9872
# Epoch 8/50
# 31290/31290 [==============================] - 7s 238us/step - loss: 0.0343 - accuracy: 0.9891
# Epoch 9/50
# 31290/31290 [==============================] - 7s 239us/step - loss: 0.0306 - accuracy: 0.9906
# Epoch 10/50
# 31290/31290 [==============================] - 7s 240us/step - loss: 0.0265 - accuracy: 0.9918
# Epoch 11/50
# 31290/31290 [==============================] - 7s 238us/step - loss: 0.0246 - accuracy: 0.9926
# Epoch 12/50
# 31290/31290 [==============================] - 7s 240us/step - loss: 0.0222 - accuracy: 0.9935
# Epoch 13/50
# 31290/31290 [==============================] - 7s 238us/step - loss: 0.0201 - accuracy: 0.9942
# Epoch 14/50
# 31290/31290 [==============================] - 7s 239us/step - loss: 0.0185 - accuracy: 0.9946
# Epoch 15/50
# 31290/31290 [==============================] - 7s 239us/step - loss: 0.0175 - accuracy: 0.9951
# Epoch 16/50
# 31290/31290 [==============================] - 7s 238us/step - loss: 0.0161 - accuracy: 0.9956
# Epoch 17/50
# 31290/31290 [==============================] - 7s 237us/step - loss: 0.0153 - accuracy: 0.9959
# Epoch 18/50
# 31290/31290 [==============================] - 7s 237us/step - loss: 0.0136 - accuracy: 0.9963
# Epoch 19/50
# 31290/31290 [==============================] - 7s 237us/step - loss: 0.0130 - accuracy: 0.9965
# Epoch 20/50
# 31290/31290 [==============================] - 7s 238us/step - loss: 0.0123 - accuracy: 0.9968
# Epoch 21/50
# 31290/31290 [==============================] - 7s 238us/step - loss: 0.0109 - accuracy: 0.9971
# Epoch 22/50
# 31290/31290 [==============================] - 7s 238us/step - loss: 0.0119 - accuracy: 0.9970
# Epoch 23/50
# 31290/31290 [==============================] - 7s 238us/step - loss: 0.0097 - accuracy: 0.9975
# Epoch 24/50
# 31290/31290 [==============================] - 8s 243us/step - loss: 0.0099 - accuracy: 0.9975
# Epoch 25/50
# 31290/31290 [==============================] - 8s 244us/step - loss: 0.0093 - accuracy: 0.9977
# Epoch 26/50
# 31290/31290 [==============================] - 7s 239us/step - loss: 0.0095 - accuracy: 0.9977
# Epoch 27/50
# 31290/31290 [==============================] - 7s 237us/step - loss: 0.0092 - accuracy: 0.9979
# Epoch 28/50
# 31290/31290 [==============================] - 7s 239us/step - loss: 0.0080 - accuracy: 0.9980
# Epoch 29/50
# 31290/31290 [==============================] - 7s 238us/step - loss: 0.0090 - accuracy: 0.9980
# Epoch 30/50
# 31290/31290 [==============================] - 7s 239us/step - loss: 0.0085 - accuracy: 0.9982
# Epoch 31/50
# 31290/31290 [==============================] - 7s 238us/step - loss: 0.0076 - accuracy: 0.9983
# Epoch 32/50
# 31290/31290 [==============================] - 7s 237us/step - loss: 0.0070 - accuracy: 0.9983
# Epoch 33/50
# 31290/31290 [==============================] - 7s 239us/step - loss: 0.0072 - accuracy: 0.9984
# Epoch 34/50
# 31290/31290 [==============================] - 7s 239us/step - loss: 0.0074 - accuracy: 0.9984
# Epoch 35/50
# 31290/31290 [==============================] - 7s 237us/step - loss: 0.0082 - accuracy: 0.9985
# Epoch 36/50
# 31290/31290 [==============================] - 7s 239us/step - loss: 0.0073 - accuracy: 0.9986
# Epoch 37/50
# 31290/31290 [==============================] - 7s 238us/step - loss: 0.0062 - accuracy: 0.9985
# Epoch 38/50
# 31290/31290 [==============================] - 7s 238us/step - loss: 0.0067 - accuracy: 0.9986
# Epoch 39/50
# 31290/31290 [==============================] - 7s 237us/step - loss: 0.0076 - accuracy: 0.9985
# Epoch 40/50
# 31290/31290 [==============================] - 7s 237us/step - loss: 0.0061 - accuracy: 0.9986
# Epoch 41/50
# 31290/31290 [==============================] - 7s 237us/step - loss: 0.0080 - accuracy: 0.9988
# Epoch 42/50
# 31290/31290 [==============================] - 7s 237us/step - loss: 0.0057 - accuracy: 0.9988
# Epoch 43/50
# 31290/31290 [==============================] - 7s 237us/step - loss: 0.0062 - accuracy: 0.9988
# Epoch 44/50
# 31290/31290 [==============================] - 7s 238us/step - loss: 0.0063 - accuracy: 0.9988
# Epoch 45/50
# 31290/31290 [==============================] - 7s 239us/step - loss: 0.0062 - accuracy: 0.9988
# Epoch 46/50
# 31290/31290 [==============================] - 7s 239us/step - loss: 0.0055 - accuracy: 0.9989
# Epoch 47/50
# 31290/31290 [==============================] - 7s 239us/step - loss: 0.0050 - accuracy: 0.9989
# Epoch 48/50
# 31290/31290 [==============================] - 7s 237us/step - loss: 0.0051 - accuracy: 0.9990
# Epoch 49/50
# 31290/31290 [==============================] - 7s 238us/step - loss: 0.0048 - accuracy: 0.9991
# Epoch 50/50
# 31290/31290 [==============================] - 8s 240us/step - loss: 0.0052 - accuracy: 0.9990

# %%
Y_preds=model_visual.predict(X_test)

# %%
sum(sum(Y_preds))
# Out:
# 59855.181884765625

# %%
f6=open('/content/drive/My Drive/Genredict.pckl','rb')
Genre_ID_to_name=pickle.load(f6)
f6.close()

# %%
sum(Y_preds[1])
# Out:
# 8.726197378122896

# %%
sum(Y_preds[2])
# Out:
# 5.136950107156521

# %%
genre_list=sorted(list(Genre_ID_to_name.keys()))

# %%
def precision_recall(gt,preds):
    TP=0
    FP=0
    FN=0
    for t in gt:
        if t in preds:
            TP+=1
        else:
            FN+=1
    for p in preds:
        if p not in gt:
            FP+=1
    if TP+FP==0:
        precision=0
    else:
        precision=TP/float(TP+FP)
    if TP+FN==0:
        recall=0
    else:
        recall=TP/float(TP+FN)
    return precision,recall

# %%
precs=[]
recs=[]
for i in range(len(Y_preds)):
    row=Y_preds[i]
    gt_genres=Y_test[i]
    gt_genre_names=[]
    for j in range(14):
        if gt_genres[j]==1:
            gt_genre_names.append(Genre_ID_to_name[genre_list[j]])
    top_3=np.argsort(row)[-4:]
    predicted_genres=[]
    for genre in top_3:
        predicted_genres.append(Genre_ID_to_name[genre_list[genre]])
    (precision,recall)=precision_recall(gt_genre_names,predicted_genres)
    precs.append(precision)
    recs.append(recall)
    print("Predicted: ",','.join(predicted_genres)," Actual: ",','.join(gt_genre_names))
# Out:
# Streaming output truncated to the last 5000 lines.
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Horror,Crime,Science Fiction,Mystery  Actual:  Horror,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  History,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Horror,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Crime,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  History,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,Comedy,History,Crime,Science Fiction,Mystery
# Predicted:  History,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Horror,Crime,Science Fiction,Mystery  Actual:  Horror,Crime,Science Fiction,Mystery
# Predicted:  Horror,Crime,Science Fiction,Mystery  Actual:  Horror,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Horror,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Western,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Crime,Horror,Science Fiction,Mystery  Actual:  Horror,Crime,Science Fiction,Mystery
# Predicted:  Horror,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Horror,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  History,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  History,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Horror,Crime,Science Fiction,Mystery  Actual:  Horror,Crime,Science Fiction,Mystery
# Predicted:  Western,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Western,Thriller,Science Fiction,Mystery
# Predicted:  Western,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Western,Thriller,Science Fiction,Mystery
# Predicted:  History,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Thriller,Science Fiction,Mystery
# Predicted:  Horror,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,Thriller,Science Fiction,Mystery
# Predicted:  Thriller,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Western,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Western,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,History,Western,Thriller,Science Fiction,Mystery
# Predicted:  Horror,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Science Fiction,Mystery
# Predicted:  Thriller,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Crime,Science Fiction,Mystery
# Predicted:  Drama,Western,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,History,Western,Thriller,Science Fiction,Mystery
# Predicted:  Thriller,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Science Fiction,Mystery
# Predicted:  Crime,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Thriller,Science Fiction,Mystery  Actual:  Drama,Horror,Science Fiction,Mystery
# Predicted:  History,Crime,Science Fiction,Mystery  Actual:  Drama,Horror,Science Fiction,Mystery
# Predicted:  History,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Thriller,Science Fiction,Mystery
# Predicted:  Western,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Western,Thriller,Science Fiction,Mystery
# Predicted:  Western,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Western,Thriller,Science Fiction,Mystery
# Predicted:  Thriller,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Western,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  History,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Western,Thriller,Science Fiction,Mystery
# Predicted:  History,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Western,Thriller,Science Fiction,Mystery
# Predicted:  Thriller,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Thriller,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  History,Thriller,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Comedy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  History,Action,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Crime,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Crime,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  History,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  History,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Science Fiction,Mystery
# Predicted:  Thriller,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  History,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Western,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Western,Crime,Science Fiction,Mystery
# Predicted:  History,Action,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Thriller,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  History,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  History,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  History,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  History,Action,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  History,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  History,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Western,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Thriller,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Crime,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  History,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Action,History,Crime,Science Fiction,Mystery
# Predicted:  History,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Action,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Comedy,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Drama,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Action,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Action,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Crime,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  History,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Western,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Comedy,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Western,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Crime,Science Fiction,Mystery
# Predicted:  History,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Crime,Science Fiction,Mystery
# Predicted:  History,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Documentary,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Western,Documentary,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Documentary,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Western,Documentary,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Western,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Comedy,Documentary,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Comedy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Western,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Horror,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Animation,Comedy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Crime,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Comedy,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Western,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Documentary,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Horror,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  History,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Documentary,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Western,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Western,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Western,Crime,Science Fiction,Mystery
# Predicted:  Drama,Comedy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  History,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Animation,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  History,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Drama,Animation,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,Western,Crime,Science Fiction,Mystery
# Predicted:  Animation,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  History,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Horror,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Action,Documentary,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Animation,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Action,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  History,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Documentary,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  History,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Animation,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Drama,Thriller,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Horror,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  History,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Horror,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Comedy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Documentary,Action,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Drama,Western,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Documentary,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Animation,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Action,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Drama,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Comedy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Drama,History,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Drama,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Documentary,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Animation,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,Western,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Animation,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Animation,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Documentary,History,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  History,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Drama,Thriller,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Animation,History,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Comedy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Western,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Action,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Animation,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  History,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  History,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Action,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Horror,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Drama,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Drama,Comedy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Crime,Documentary,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Drama,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Comedy,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Drama,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Drama,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Horror,Comedy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Animation,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  History,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Documentary,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Documentary,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Comedy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Action,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# ...
# Predicted:  Thriller,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  History,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Documentary,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Action,Western,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,Western,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Drama,Comedy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Documentary,Comedy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Comedy,Documentary,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Action,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  History,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Crime,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Comedy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Horror,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Action,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Horror,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  History,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Animation,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Drama,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,Comedy,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Documentary,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Drama,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Drama,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Action,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Action,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Western,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Crime,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Comedy,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  History,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Western,Crime,Science Fiction,Mystery
# Predicted:  Drama,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Thriller,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Western,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Documentary,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Comedy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Western,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  History,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Action,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  History,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Thriller,Horror,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Crime,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Comedy,Documentary,Science Fiction,Mystery  Actual:  Animation,Drama,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  History,Action,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Action,Thriller,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Thriller,Action,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery

# %%
print(np.mean(np.asarray(precs)),np.mean(np.asarray(recs)))
print("avg=",(np.mean(np.asarray(precs))+np.mean(np.asarray(recs)))/2)
# Out:
# 0.8440328955756726 0.4846602881442866
# avg= 0.6643465918599796

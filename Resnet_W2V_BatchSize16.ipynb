# %%
import pandas as pd
df = pd.read_pickle("/content/drive/My Drive/pinky_promise_last.pckl")

# %%
df
# Out:
#                                             title  ...                                          image_vec
# 0                     Travis and the Nitro Circus  ...  [[[[ 0.          0.          0.          0.   ...
# 1                        Robot Chicken: Star Wars  ...  [[[[ 0.          0.          0.          0.   ...
# 2                      Sense8: Creating the World  ...  [[[[ 0.          0.          0.          0.   ...
# 3                                   North of Nome  ...  [[[[ 0.          0.          0.          0.   ...
# 4      SPIT: The Story of a Caveman and a Chicken  ...  [[[[ 0.          0.          0.          0.   ...
# ...                                           ...  ...                                                ...
# 42973                                   Get Lucky  ...  [[[[0.00000000e+00 0.00000000e+00 0.00000000e+...
# 42974                      Four Frightened People  ...  [[[[0.00000000e+00 0.00000000e+00 0.00000000e+...
# 42975                                   Iron Will  ...  [[[[0.00000000e+00 0.00000000e+00 0.00000000e+...
# 42976                                Bran Nue Dae  ...  [[[[0.00000000e+00 0.00000000e+00 0.00000000e+...
# 42977                            Bhowani Junction  ...  [[[[0.00000000e+00 0.00000000e+00 0.00000000e+...
#
# [42978 rows x 6 columns]

# %%
import pickle

f1 = open("/content/drive/My Drive/Resnet_features_1.pckl","rb")
x1 = pickle.load(f1)
f2 = open("/content/drive/My Drive/Resnet_features_2.pckl","rb")
x2 = pickle.load(f2)
f3 = open("/content/drive/My Drive/Resnet_features_3.pckl","rb")
x3 = pickle.load(f3)

# %%
X = x1[0]
X.extend(x2[0])
X.extend(x3[0])

# %%
import numpy as np
feature_size=1000

np_features=np.zeros((len(X),feature_size))
for i in range(len(X)):
    feat=X[i]
    reshaped_feat=feat.reshape(1,-1)
    np_features[i]=reshaped_feat

X=np_features

# %%
X.shape
# Out:
# (42978, 1000)

# %%
resnet_w2v = np.zeros((42978, 1300))

# %%
import numpy as np

for i in range(len(df)):
  x1 = df.text_vec[i].flatten()
  x2 = X[i].flatten()
  x3 = np.concatenate((x1,x2),axis=0)
  resnet_w2v[i] = x3
  if i%5000 == 0:
    print("count is ", i)
# Out:
# count is  0
# count is  5000
# count is  10000
# count is  15000
# count is  20000
# count is  25000
# count is  30000
# count is  35000
# count is  40000

# %%
resnet_w2v[0].shape
# Out:
# (1300,)

# %%
Y = df.genre_ids.to_list()

# %%
mask = np.random.rand(len(X)) < 0.8

# %%
from sklearn.preprocessing import MultiLabelBinarizer
mlb=MultiLabelBinarizer()
Y=mlb.fit_transform(Y)

Y.shape
# Out:
# (42978, 14)

# %%
X_train=resnet_w2v[mask]
X_test=resnet_w2v[~mask]
Y_train=Y[mask]
Y_test=Y[~mask]

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras import optimizers
model_visual = Sequential([
    Dense(1024, input_shape=(1300,)),
    Activation('relu'),
    Dense(256),
    Activation('relu'),
    Dense(14),
    Activation('sigmoid'),
])
opt = optimizers.rmsprop(lr=0.0001, decay=1e-6)

#sgd = optimizers.SGD(lr=0.05, decay=1e-6, momentum=0.4, nesterov=False)
model_visual.compile(optimizer=opt,
              loss='binary_crossentropy',
              metrics=['accuracy'])
# Out:
# Using TensorFlow backend.

# %%
model_visual.fit(X_train, Y_train, epochs=100, batch_size=16,verbose=1)
# Out:
# Epoch 1/100
# 34349/34349 [==============================] - 21s 625us/step - loss: 0.4322 - accuracy: 0.7876
# Epoch 2/100
# 34349/34349 [==============================] - 21s 621us/step - loss: 0.4283 - accuracy: 0.7897
# Epoch 3/100
# 34349/34349 [==============================] - 21s 622us/step - loss: 0.4246 - accuracy: 0.7927
# Epoch 4/100
# 34349/34349 [==============================] - 21s 619us/step - loss: 0.4208 - accuracy: 0.7949
# Epoch 5/100
# 34349/34349 [==============================] - 21s 619us/step - loss: 0.4170 - accuracy: 0.7976
# Epoch 6/100
# 34349/34349 [==============================] - 21s 625us/step - loss: 0.4132 - accuracy: 0.8003
# Epoch 7/100
# 34349/34349 [==============================] - 22s 636us/step - loss: 0.4093 - accuracy: 0.8029
# Epoch 8/100
# 34349/34349 [==============================] - 22s 637us/step - loss: 0.4053 - accuracy: 0.8057
# Epoch 9/100
# 34349/34349 [==============================] - 22s 649us/step - loss: 0.4015 - accuracy: 0.8082
# Epoch 10/100
# 34349/34349 [==============================] - 21s 618us/step - loss: 0.3975 - accuracy: 0.8109
# Epoch 11/100
# 34349/34349 [==============================] - 21s 619us/step - loss: 0.3933 - accuracy: 0.8134
# Epoch 12/100
# 34349/34349 [==============================] - 21s 617us/step - loss: 0.3890 - accuracy: 0.8163
# Epoch 13/100
# 34349/34349 [==============================] - 21s 620us/step - loss: 0.3846 - accuracy: 0.8195
# Epoch 14/100
# 34349/34349 [==============================] - 21s 618us/step - loss: 0.3796 - accuracy: 0.8227
# Epoch 15/100
# 34349/34349 [==============================] - 21s 620us/step - loss: 0.3749 - accuracy: 0.8257
# Epoch 16/100
# 34349/34349 [==============================] - 21s 622us/step - loss: 0
# Epoch 80/100
# 34349/34349 [==============================] - 23s 667us/step - loss: 0.0845 - accuracy: 0.9733
# Epoch 81/100
# 34349/34349 [==============================] - 22s 628us/step - loss: 0.0822 - accuracy: 0.9745
# Epoch 82/100
# 34349/34349 [==============================] - 22s 631us/step - loss: 0.0799 - accuracy: 0.9754
# Epoch 83/100
# 34349/34349 [==============================] - 22s 629us/step - loss: 0.0777 - accuracy: 0.9761
# Epoch 84/100
# 34349/34349 [==============================] - 22s 626us/step - loss: 0.0754 - accuracy: 0.9772
# Epoch 85/100
# 34349/34349 [==============================] - 22s 638us/step - loss: 0.0732 - accuracy: 0.9780
# Epoch 86/100
# 34349/34349 [==============================] - 22s 640us/step - loss: 0.0709 - accuracy: 0.9787
# Epoch 87/100
# 34349/34349 [==============================] - 22s 636us/step - loss: 0.0690 - accuracy: 0.9796
# Epoch 88/100
# 34349/34349 [==============================] - 22s 641us/step - loss: 0.0670 - accuracy: 0.9804
# Epoch 89/100
# 34349/34349 [==============================] - 22s 641us/step - loss: 0.0650 - accuracy: 0.9811
# Epoch 90/100
# 34349/34349 [==============================] - 22s 639us/step - loss: 0.0632 - accuracy: 0.9819
# Epoch 91/100
# 34349/34349 [==============================] - 22s 651us/step - loss: 0.0611 - accuracy: 0.9826
# Epoch 92/100
# 34349/34349 [==============================] - 22s 635us/step - loss: 0.0596 - accuracy: 0.9832
# Epoch 93/100
# 34349/34349 [==============================] - 22s 631us/step - loss: 0.0577 - accuracy: 0.9839
# Epoch 94/100
# 34349/34349 [==============================] - 22s 655us/step - loss: 0.0558 - accuracy: 0.9848
# Epoch 95/100
# 34349/34349 [==============================] - 22s 640us/step - loss: 0.0541 - accuracy: 0.9853
# Epoch 96/100
# 34349/34349 [==============================] - 22s 649us/step - loss: 0.0526 - accuracy: 0.9857
# Epoch 97/100
# 34349/34349 [==============================] - 22s 652us/step - loss: 0.0511 - accuracy: 0.9862
# Epoch 98/100
# 34349/34349 [==============================] - 23s 663us/step - loss: 0.0495 - accuracy: 0.9869
# Epoch 99/100
# 34349/34349 [==============================] - 23s 666us/step - loss: 0.0479 - accuracy: 0.9875
# Epoch 100/100
# 34349/34349 [==============================] - 23s 662us/step - loss: 0.0464 - accuracy: 0.9881

# %%
def precision_recall(gt,preds):
    TP=0
    FP=0
    FN=0
    for t in gt:
        if t in preds:
            TP+=1
        else:
            FN+=1
    for p in preds:
        if p not in gt:
            FP+=1
    if TP+FP==0:
        precision=0
    else:
        precision=TP/float(TP+FP)
    if TP+FN==0:
        recall=0
    else:
        recall=TP/float(TP+FN)
    return precision,recall

# %%
Y_preds=model_visual.predict(X_test)

# %%
import pickle
f6=open('/content/drive/My Drive/Genredict.pckl','rb')
Genre_ID_to_name=pickle.load(f6)
f6.close()

# %%
genre_list=sorted(list(Genre_ID_to_name.keys()))

# %%
sum(sum(Y_preds))
# Out:
# 65059.09826660156

# %%
import numpy as np
positions=range(len(df))
# print positions
test_movies=np.asarray(positions)[~mask]
# test_movies

# %%
import numpy as np

precs=[]
recs=[]
for i in range(len(Y_preds)):
    row=Y_preds[i]
    gt_genres=Y_test[i]
    gt_genre_names=[]
    for j in range(14):
        if gt_genres[j]==1:
            gt_genre_names.append(Genre_ID_to_name[genre_list[j]])
    top_3=np.argsort(row)[-4:]
    predicted_genres=[]
    for genre in top_3:
        predicted_genres.append(Genre_ID_to_name[genre_list[genre]])
    (precision,recall)=precision_recall(gt_genre_names,predicted_genres)
    precs.append(precision)
    recs.append(recall)
    print("Predicted: ",','.join(predicted_genres)," Actual: ",','.join(gt_genre_names))
# Out:
# Streaming output truncated to the last 5000 lines.
# Predicted:  Thriller,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  History,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,History,Thriller,Science Fiction,Mystery
# Predicted:  Animation,Thriller,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Documentary,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,History,Western,Thriller,Science Fiction,Mystery
# Predicted:  Drama,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Crime,Action,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Comedy,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Science Fiction,Mystery
# Predicted:  History,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Action,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Drama,Animation,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Crime,Comedy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Animation,Drama,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Comedy,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Drama,Comedy,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,Comedy,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  History,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,History,Western,Science Fiction,Mystery
# Predicted:  Thriller,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,History,Thriller,Science Fiction,Mystery
# Predicted:  Drama,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,History,Thriller,Science Fiction,Mystery
# Predicted:  Action,Thriller,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Crime,Science Fiction,Mystery
# Predicted:  Drama,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Western,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Western,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Western,Documentary,Science Fiction,Mystery
# Predicted:  History,Action,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,History,Thriller,Science Fiction,Mystery
# Predicted:  Drama,Comedy,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Comedy,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Action,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Drama,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  History,Action,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  History,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Documentary,Animation,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Western,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Action,Thriller,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Horror,Comedy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Thriller,Horror,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Comedy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Western,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Drama,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Action,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  History,Action,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Horror,Comedy,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Drama,Comedy,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Comedy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  History,Thriller,Science Fiction,Mystery  Actual:  Animation,Drama,History,Thriller,Science Fiction,Mystery
# Predicted:  Drama,Comedy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Comedy,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Action,Thriller,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Crime,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Action,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Action,Crime,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Horror,Comedy,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Comedy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Drama,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Western,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Drama,Comedy,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Documentary,Comedy,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Comedy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Animation,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,History,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Action,Thriller,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Action,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  History,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Crime,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,History,Science Fiction,Mystery  Actual:  Animation,Drama,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Animation,Drama,History,Thriller,Science Fiction,Mystery
# Predicted:  History,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Drama,Horror,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Action,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Drama,Comedy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  History,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Comedy,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Comedy,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Horror,Crime,Science Fiction,Mystery  Actual:  Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,History,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Thriller,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Animation,Drama,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Crime,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Horror,Comedy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Science Fiction,Mystery
# Predicted:  Drama,Animation,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Drama,Western,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Drama,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Documentary,Comedy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Animation,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Horror,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Action,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Horror,Comedy,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Animation,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Western,Thriller,Crime,Science Fiction,Mystery
# Predicted:  History,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,History,Thriller,Science Fiction,Mystery
# Predicted:  Documentary,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  History,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  History,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Thriller,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  History,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Comedy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Western,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Comedy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Documentary,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Comedy,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Western,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Thriller,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,Western,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Comedy,Animation,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Drama,Thriller,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Action,Horror,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Comedy,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Comedy,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Crime,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  History,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  History,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Horror,History,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Comedy,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Western,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  History,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  History,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  History,Crime,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Drama,Comedy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Action,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  History,Thriller,Science Fiction,Mystery  Actual:  Animation,Drama,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Comedy,Animation,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Comedy,Science Fiction,Mystery  Actual:  Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Action,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Comedy,Science Fiction,Mystery
# Predicted:  Thriller,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Drama,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Science Fiction,Mystery
# Predicted:  Drama,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,Western,Science Fiction,Mystery
# Predicted:  History,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  History,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Drama,Comedy,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Action,Thriller,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Crime,Action,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Horror,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Horror,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Animation,Drama,History,Thriller,Science Fiction,Mystery
# Predicted:  Crime,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Action,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  History,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Drama,Comedy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  History,Action,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Animation,Comedy,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Animation,Drama,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Comedy,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Animation,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Horror,Comedy,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,History,Thriller,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  History,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Drama,Comedy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Comedy,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Documentary,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Western,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Documentary,Science Fiction,Mystery  Actual:  Animation,Drama,History,Thriller,Science Fiction,Mystery
# Predicted:  Crime,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Comedy,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  History,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Horror,Comedy,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Documentary,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  History,Action,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Comedy,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Comedy,Documentary,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  History,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Horror,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Comedy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,Comedy,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Horror,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,Western,Science Fiction,Mystery
# Predicted:  Drama,Animation,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Animation,Comedy,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Thriller,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Comedy,Documentary,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Comedy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Documentary,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,History,Thriller,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Comedy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Comedy,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Comedy,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Thriller,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Drama,History,Science Fiction,Mystery  Actual:  Animation,Drama,History,Thriller,Science Fiction,Mystery
# Predicted:  Crime,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Horror,Comedy,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Crime,Action,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Horror,Comedy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Drama,Animation,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Crime,Science Fiction,Mystery
# Predicted:  Animation,Documentary,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Western,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Comedy,Science Fiction,Mystery  Actual:  Animation,Drama,Comedy,Thriller,Documentary,Science Fiction,Mystery
# ...
# Predicted:  Documentary,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Animation,Crime,Science Fiction,Mystery
# Predicted:  Comedy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Comedy,Science Fiction,Mystery  Actual:  Drama,Western,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Documentary,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Documentary,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  History,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Action,Documentary,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Action,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,Thriller,Crime,Science Fiction,Mystery
# Predicted:  History,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Crime,Documentary,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Western,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Drama,Documentary,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Animation,Crime,Science Fiction,Mystery
# Predicted:  Crime,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  History,Comedy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Drama,Comedy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,History,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,History,Thriller,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Western,Crime,Science Fiction,Mystery
# Predicted:  History,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  History,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Crime,Documentary,Science Fiction,Mystery
# Predicted:  History,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Action,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Documentary,Comedy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Comedy,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,Western,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Animation,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Western,Documentary,Science Fiction,Mystery
# Predicted:  History,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Documentary,Comedy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Science Fiction,Mystery
# Predicted:  Crime,Western,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Western,Crime,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Crime,Science Fiction,Mystery
# Predicted:  Horror,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Comedy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Western,Documentary,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Documentary,Comedy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Documentary,Comedy,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Horror,History,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Thriller,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Crime,Science Fiction,Mystery
# Predicted:  Drama,Documentary,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Crime,Documentary,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Horror,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  History,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Thriller,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Western,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Western,Thriller,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Horror,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Animation,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Documentary,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  History,Action,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Drama,Documentary,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Western,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Horror,Documentary,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Drama,Documentary,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Drama,Western,Science Fiction,Mystery  Actual:  Drama,Western,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Horror,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Science Fiction,Mystery
# Predicted:  Comedy,Drama,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Drama,Western,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Action,Documentary,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Drama,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Western,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Western,Crime,Science Fiction,Mystery
# Predicted:  Action,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Horror,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Comedy,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Animation,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Crime,Science Fiction,Mystery
# Predicted:  Documentary,Drama,Science Fiction,Mystery  Actual:  Drama,Horror,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Horror,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery

# %%
print(np.mean(np.asarray(precs)),np.mean(np.asarray(recs)))
print("avg=",(np.mean(np.asarray(precs))+np.mean(np.asarray(recs)))/2)
# Out:
# 0.878520106617221 0.5197123008717631
# avg= 0.699116203744492

# %%
print("f1-score", (2*(np.mean(np.asarray(precs)) * np.mean(np.asarray(recs)))) / (np.mean(np.asarray(precs)) + np.mean(np.asarray(recs))))
# Out:
# f1-score 0.6530784203351255

# %%
def f1(a,b):
  f = (2*(a*b))/(a+b)
  print(f)

# %%
f1(0.459292, 0.538371)

# %%
# !pip install tmdbsimple
# Out:
# Collecting tmdbsimple
#   Downloading https://files.pythonhosted.org/packages/19/fa/1138b078293d1c0bb415f7ca795550415805e4538302b4eb9133d924b5c3/tmdbsimple-2.2.20-py2.py3-none-any.whl
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from tmdbsimple) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->tmdbsimple) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->tmdbsimple) (2020.4.5.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->tmdbsimple) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->tmdbsimple) (3.0.4)
# Installing collected packages: tmdbsimple
# Successfully installed tmdbsimple-2.2.20

# %%
# !pip install scikit-multilearn
# Out:
# Collecting scikit-multilearn
#   Downloading https://files.pythonhosted.org/packages/bb/1f/e6ff649c72a1cdf2c7a1d31eb21705110ce1c5d3e7e26b2cc300e1637272/scikit_multilearn-0.2.0-py3-none-any.whl (89kB)
#      |████████████████████████████████| 92kB 2.3MB/s
# Installing collected packages: scikit-multilearn
# Successfully installed scikit-multilearn-0.2.0

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import pickle
import tmdbsimple as tmdb

df = pd.DataFrame()
df=pd.read_csv("/content/drive/My Drive/last.csv", engine="python")
 
from ast import literal_eval
df.genre_ids=df.genre_ids.apply(literal_eval)

api_key = "d0ccc864ded48afb6a7e28b2d32001ed"
tmdb.API_KEY = api_key
#search = tmdb.Search()

genres=tmdb.Genres()
list_of_genres=genres.movie_list()['genres']
Genre_ID_to_name={}
for i in range(len(list_of_genres)):
    genre_id=list_of_genres[i]['id']
    genre_name=list_of_genres[i]['name']
    Genre_ID_to_name[genre_id]=genre_name

# genres=np.zeros((len(top1000_movies),3))
genres=[]
all_ids=[]
for i in range(len(df)):
    id=df.id[i]
    genre_ids=df.genre_ids[i]
    genres.append(genre_ids)
    all_ids.extend(genre_ids)

print(all_ids)

from sklearn.preprocessing import MultiLabelBinarizer
mlb=MultiLabelBinarizer()
Y=mlb.fit_transform(genres)

print(Y.shape)
print(np.sum(Y, axis=0))

sample_overview=df.overview[5]
sample_title=df.title[5]
print("The overview for the movie",sample_title," is - \n\n")
print(sample_overview)

from sklearn.feature_extraction.text import CountVectorizer
import re

content=[]
for i in range(len(df)):
    id=df.id[i]
    overview=df.overview[i]
    overview=overview.replace(',','')
    overview=overview.replace('.','')
    content.append(overview)

vectorize=CountVectorizer(max_df=0.95, min_df=0.005)
X=vectorize.fit_transform(content)

print(X.shape)

import pickle
f4=open('X.pckl','wb')
f5=open('Y.pckl','wb')
pickle.dump(X,f4)
pickle.dump(Y,f5)
f6=open('Genredict.pckl','wb')
pickle.dump(Genre_ID_to_name,f6)
f4.close()
f5.close()
f6.close()

from sklearn.feature_extraction.text import TfidfTransformer
tfidf_transformer = TfidfTransformer()
X_tfidf = tfidf_transformer.fit_transform(X)
print("After",X_tfidf.shape)

msk = np.random.rand(X_tfidf.shape[0]) < 0.8

X_train_tfidf=X_tfidf[msk]
X_test_tfidf=X_tfidf[~msk]
Y_train=Y[msk]
Y_test=Y[~msk]
positions=range(len(df))
# print positions
test_movies=np.asarray(positions)[~msk]
# test_movies

from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score
from sklearn.metrics import make_scorer
from sklearn.metrics import classification_report
from skmultilearn.adapt import MLkNN

classifier = MLkNN(k=3)

# train
classifier.fit(X_train_tfidf, Y_train)

#classifier.fit(X[msk].toarray(), Y_train)
#predstfidf=classifier.predict(X[~msk].toarray())

#New code for the next review

genre_names = []
for id in df.genre_ids:
  for i in id:
    genre_name=Genre_ID_to_name[i]
    genre_names.append(genre_name)
genre_names = set(genre_names)

genre_list=sorted(list(Genre_ID_to_name.keys()))
print(genre_list)

# import pickle
# f2=open('classifer_knn','wb')
# pickle.dump(classifier,f2)
# f2.close()

predstfidf = classifier.predict(X_test_tfidf)

print(classification_report(Y_test, predstfidf, target_names=genre_names))
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# [28, 35, 80, 28, 12, 35, 14, 10751, 28, 80, 53, 28, 18, 10752, 28, 878, 28, 18, 28, 18, 36, 10752, 28, 80, 18, 28, 35, 28, 53, 28, 12, 878, 28, 12, 878, 28, 28, 12, 35, 14, 28, 12, 35, 14, 878, 10751, 28, 878, 28, 35, 80, 28, 12, 878, 28, 12, 35, 28, 18, 53, 28, 12, 14, 28, 80, 18, 878, 53, 28, 12, 14, 28, 12, 16, 35, 10751, 28, 12, 14, 28, 12, 14, 28, 12, 878, 28, 12, 878, 28, 12,
#         Western       0.26      0.08      0.12      1889
#        Thriller       0.22      0.11      0.15      1402
#     Documentary       0.29      0.15      0.19       418
#         Fantasy       0.12      0.05      0.08       956
#
#       micro avg       0.23      0.32      0.27     32241
#       macro avg       0.26      0.23      0.19     32241
#    weighted avg       0.27      0.32      0.22     32241
#     samples avg       0.25      0.32      0.26     32241

# %%
predstfidf = predstfidf.toarray()

# %%
predictionsknn=[]
for i in range(X_test_tfidf.shape[0]):
    pred_genres=[]
    movie_label_scores=predstfidf[i]
    for j in range(19):
        if movie_label_scores[j]!=0:
            genre=Genre_ID_to_name[genre_list[j]]
            pred_genres.append(genre)
    predictionsknn.append(pred_genres)

# %%
for i in range(X_test_tfidf.shape[0]):
    if i%50==0 and i!=0:
        print('MOVIE: ',df.title[test_movies[i]],'\tPREDICTION: ',','.join(predictionsknn[i]))
# Out:
# MOVIE:  The Incredible Hulk 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Johnny English 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Jack Reacher: Never Go Back 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Final Score 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Turbo: A Power Rangers Movie 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Stormbreaker 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Batman: Assault on Arkham 	PREDICTION:  Adventure,Drama,Action,Thriller,Science Fiction
# MOVIE:  Ned Kelly 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Streets of Fire 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  A Warrior's Heart 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  In Full Bloom 	PREDICTION:  Drama,Documentary,Science Fiction,TV Movie
# MOVIE:  Timebomb 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Reclaiming the Blade 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Showdown In Manila 	PREDICTION:  Animation,Comedy,Music,TV Movie
# MOVIE:  Kolpaçino 	PREDICTION:  Comedy,Documentary,Music,Romance
# MOVIE:  Harrigan 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Surviving Evil 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Lady Death 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Painkillers 	PREDICTION:  Horror,Action,Thriller
# MOVIE:  Tetra Vaal 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Kill Kapone 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Hunter's Blood 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  The Code 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Air Rage 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  No Exit 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Headroom 2 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Vatos Locos 2 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  The Prey 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Legends from the Sky 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Deadly Rivals 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Shootfighter Tekken 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Stoney 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Forever Night 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Firehouse 	PREDICTION:  Animation,Drama
# MOVIE:  Out of Time 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  A Doctor's Job 	PREDICTION:  Drama,Music,Romance,TV Movie
# MOVIE:  Swagatam 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Rope a Dope 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  The Little Prince 	PREDICTION:  Documentary
# MOVIE:  An American Tail: Fievel Goes West 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Carry On Up the Khyber 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Alien from L.A. 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Frog Dreaming 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Denver and Rio Grande 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  The Silver Whip 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  The Mississippi Gambler 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Wizard 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Hold on, Cossack! 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  A Tale of Egypt 	PREDICTION:  Animation,Family
# MOVIE:  Children of the Wild 	PREDICTION:  Comedy,Romance
# MOVIE:  Seven Hundred Miles 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Kald Krig og Røde Flasker 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Bari 	PREDICTION:  Drama,Music,Romance
# MOVIE:  Man On The Spying Trapeze 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  The Swan Princess: Escape from Castle Mountain 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Tom and Jerry: The Movie 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Gay Purr-ee 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Lambert the Sheepish Lion 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  The Pixar Shorts: A Short History 	PREDICTION:  Animation
# MOVIE:  Angelina Ballerina: Twirling Tales 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Zoo Wars 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  My Little Pony: Dancing in the Clouds 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Little Johnny The Movie 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Trader Mickey 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Magos y Gigantes 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  The A-Tom-inable Snowman 	PREDICTION:  Animation,Comedy,Family
# MOVIE:  Holly Hobbie and Friends: Best Friends Forever 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  The Overture to 'William Tell' 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  The Star of Bethlehem 	PREDICTION:  Horror,Action,Science Fiction
# MOVIE:  The Christmas Story Keepers 	PREDICTION:  Adventure,Fantasy,Documentary,Family
# MOVIE:  That Long & Lonesome Road to Grandma's 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  
	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Snoop Dogg Puff Puff Pass Tour 	PREDICTION:  Music
# MOVIE:  Juliette And The Licks - Four On The Floor 	PREDICTION:  Music
# MOVIE:  Some Kind of Spark 	PREDICTION:  Horror
# MOVIE:  Hiram Bullock: Live At Indigo Blues 	PREDICTION:  Music
# MOVIE:  Jon Lord: Concerto for Group & Orchestra 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  New Order: Brixton Academy 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  The Rhythmatist 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Agony 	PREDICTION:  Fantasy,Horror,Comedy,Thriller,Science Fiction,Mystery,Romance
# MOVIE:  Linkin Park Live in Moscow 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Night Club Girl 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Cast a Dark Shadow 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  The Last Lullaby 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Apricot 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Love Among Thieves 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Murder in Times Square 	PREDICTION:  Thriller,TV Movie
# MOVIE:  Girls Named Pinky 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Alias the Lone Wolf 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Mysteries From Beyond Earth 	PREDICTION:  History,Documentary
# MOVIE:  ToY 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  The Heart of Me 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  So Big! 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  The Christmas Choir 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  After Tonight 	PREDICTION:  Drama,History,Romance,War
# MOVIE:  Semerah Cinta Stilleto 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  How to Lose Weight in 4 Easy Steps! 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Thiruttu VCD 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Like Normal People 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Lovemakers 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  American Fusion 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Shattered Vows 	PREDICTION:  Drama,Romance,TV Movie
# MOVIE:  Leaving Circadia 	PREDICTION:  Comedy,History,Documentary,Music
# MOVIE:  The Pretend One 	PREDICTION:  Animation,Drama,Comedy,Romance
# MOVIE:  Street Girl 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Eve of Destruction 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Creators: The Past 	PREDICTION:  Animation,Documentary
# MOVIE:  Towers Open Fire 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  In Search Of... 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Phobe: The Xenophobic Experiments 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Was It Only A Paper Moon? 	PREDICTION:  Drama,Science Fiction
# MOVIE:  El extraño visitante 	PREDICTION:  Drama,War
# MOVIE:  My Mind, Your Body 	PREDICTION:  Music
# MOVIE:  Hattie 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Amelia Earhart: The Final Flight 	PREDICTION:  Comedy,Documentary,Science Fiction,TV Movie
# MOVIE:  Tales from Hollywood 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  The Night America Trembled 	PREDICTION:  Drama,Documentary,Music,War,TV Movie
# MOVIE:  Fascism and Football 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Dynasty 	PREDICTION:  Animation
# MOVIE:  The Last Showing 	PREDICTION:  Fantasy,Thriller,Mystery
# MOVIE:  Psycho BFF 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Dream House Nightmare 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  The 11th Patient 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  The Red Ball Express 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Enemy of Women 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Inflation 	PREDICTION:  Adventure,History,Documentary,War
# MOVIE:  Apache Rifles 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Colorado Kid 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  The Vigilantes Ride 	PREDICTION:  Western
# MOVIE:  Bandits of El Dorado 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Roarin' Lead 	PREDICTION:  Adventure,Comedy,Western
# MOVIE:  The Westward Trail 	PREDICTION:  Drama,Action,Thriller
# MOVIE:  Bonanza Town 	PREDICTION:  Western,Thriller,Science Fiction,TV Movie
# MOVIE:  Marie Ann 	PREDICTION:  Fantasy,Comedy,Science Fiction,Romance
# MOVIE:  One Man's Law 	PREDICTION:  Drama,Comedy,Thriller,Family

# %%
def precision_recall(gt,preds):
    TP=0
    FP=0
    FN=0
    for t in gt:
        if t in preds:
            TP+=1
        else:
            FN+=1
    for p in preds:
        if p not in gt:
            FP+=1
    if TP+FP==0:
        precision=0
    else:
        precision=TP/float(TP+FP)
    if TP+FN==0:
        recall=0
    else:
        recall=TP/float(TP+FN)
    return precision,recall

# %%
precs=[]
recs=[]
for i in range(len(test_movies)):
    if i%1==0:
        pos=test_movies[i]
        #test_movie=movies_with_overviews[pos]
        gtids=df.genre_ids[pos]
        gt=[]
        for g in gtids:
            g_name=Genre_ID_to_name[g]
            gt.append(g_name)
#         print predictions[i],movies_with_overviews[i]['title'],gt
        a,b=precision_recall(gt,predictionsknn[i])
        precs.append(a)
        recs.append(b)

print(np.mean(np.asarray(precs)),np.mean(np.asarray(recs)))
print("Average = ",(np.mean(np.asarray(precs))+np.mean(np.asarray(recs)))/2)
# Out:
# 0.2465507981389225 0.31564030638959945
# Average =  0.281095552264261

# %%
print("f1-score", (2*(np.mean(np.asarray(precs)) * np.mean(np.asarray(recs)))) / (np.mean(np.asarray(precs)) + np.mean(np.asarray(recs))))
# Out:
# f1-score 0.2768502341581309

# %%
print(np.mean(np.asarray(precs)),np.mean(np.asarray(recs)))
print("avg= ",(np.mean(np.asarray(precs))+np.mean(np.asarray(recs)))/2)
# Out:
# 0.2085507981389225 0.36764030638959944
# avg=  0.288095552264261

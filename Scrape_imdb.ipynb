# %%
# !pip install imdbpy
import imdb
# Out:
# Collecting imdbpy
#   Downloading https://files.pythonhosted.org/packages/70/87/928f9b8752dfafe8093488e03bd5d04b5dc260902f409303b0891cec86ef/IMDbPY-6.8-py3-none-any.whl (295kB)
#      |████████████████████████████████| 296kB 2.5MB/s
# Requirement already satisfied: SQLAlchemy in /usr/local/lib/python3.6/dist-packages (from imdbpy) (1.3.12)
# Requirement already satisfied: lxml in /usr/local/lib/python3.6/dist-packages (from imdbpy) (4.2.6)
# Installing collected packages: imdbpy
# Successfully installed imdbpy-6.8

# %%
imbd_object = imdb.IMDb()
results = imbd_object.search_movie('Spider-man: Far from home')
movie = results[0]
imbd_object.update(movie)
print("All the information we can get about this movie from IMDB-")
print(movie['genres'])
# Out:
# All the information we can get about this movie from IMDB-
# ['Action', 'Adventure', 'Sci-Fi']

# %%
x = []
l = [{'id': 10752, 'name': 'War'}, {'id': 18, 'name': 'Drama'}, {'id': 36, 'name': 'History'}, {'id': 28, 'name': 'Action'}]
for i in l:
  x.append(i['name'])
x
# Out:
# ['War', 'Drama', 'History', 'Action']

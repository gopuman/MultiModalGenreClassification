# %%
import pandas as pd
df = pd.read_pickle("/content/drive/My Drive/pinky_promise_last.pckl")

# !pip install h5py
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (2.10.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py) (1.12.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from h5py) (1.18.4)

# %%
df
# Out:
#                                             title  ...                                          image_vec
# 0                     Travis and the Nitro Circus  ...  [[[[ 0.          0.          0.          0.   ...
# 1                        Robot Chicken: Star Wars  ...  [[[[ 0.          0.          0.          0.   ...
# 2                      Sense8: Creating the World  ...  [[[[ 0.          0.          0.          0.   ...
# 3                                   North of Nome  ...  [[[[ 0.          0.          0.          0.   ...
# 4      SPIT: The Story of a Caveman and a Chicken  ...  [[[[ 0.          0.          0.          0.   ...
# ...                                           ...  ...                                                ...
# 42973                                   Get Lucky  ...  [[[[0.00000000e+00 0.00000000e+00 0.00000000e+...
# 42974                      Four Frightened People  ...  [[[[0.00000000e+00 0.00000000e+00 0.00000000e+...
# 42975                                   Iron Will  ...  [[[[0.00000000e+00 0.00000000e+00 0.00000000e+...
# 42976                                Bran Nue Dae  ...  [[[[0.00000000e+00 0.00000000e+00 0.00000000e+...
# 42977                            Bhowani Junction  ...  [[[[0.00000000e+00 0.00000000e+00 0.00000000e+...
#
# [42978 rows x 6 columns]

# %%
import pickle

f1 = open("/content/drive/My Drive/Resnet_features_1.pckl","rb")
x1 = pickle.load(f1)
f2 = open("/content/drive/My Drive/Resnet_features_2.pckl","rb")
x2 = pickle.load(f2)
f3 = open("/content/drive/My Drive/Resnet_features_3.pckl","rb")
x3 = pickle.load(f3)

# %%
X = x1[0]
X.extend(x2[0])
X.extend(x3[0])

# %%
import numpy as np
feature_size=1000

np_features=np.zeros((len(X),feature_size))
for i in range(len(X)):
    feat=X[i]
    reshaped_feat=feat.reshape(1,-1)
    np_features[i]=reshaped_feat

X=np_features

# %%
X.shape
# Out:
# (42978, 1000)

# %%
f4 = open("/content/drive/My Drive/glove_features.pckl","rb")
glove = pickle.load(f4)
g = []
for i in range(len(glove[0])):
  g.append(glove[0][i])

# %%
resnet_glove = np.zeros((42978, 1300))

# %%
import numpy as np

for i in range(len(df)):
  x1 = g[i].flatten()
  x2 = X[i].flatten()
  x3 = np.concatenate((x1,x2),axis=0)
  resnet_glove[i] = x3
  if i%5000 == 0:
    print("count is ", i)
# Out:
# count is  0
# count is  5000
# count is  10000
# count is  15000
# count is  20000
# count is  25000
# count is  30000
# count is  35000
# count is  40000

# %%
resnet_glove[0].shape
# Out:
# (1300,)

# %%
Y = df.genre_ids.to_list()

# %%
mask = np.random.rand(len(X)) < 0.8

# %%
from sklearn.preprocessing import MultiLabelBinarizer
mlb=MultiLabelBinarizer()
Y=mlb.fit_transform(Y)

Y.shape
# Out:
# (42978, 14)

# %%
X_train=resnet_glove[mask]
X_test=resnet_glove[~mask]
Y_train=Y[mask]
Y_test=Y[~mask]

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras import optimizers
model_visual = Sequential([
    Dense(1024, input_shape=(1300,)),
    Activation('relu'),
    Dense(256),
    Activation('relu'),
    Dense(14),
    Activation('sigmoid'),
])
opt = optimizers.rmsprop(lr=0.0001, decay=1e-6)

#sgd = optimizers.SGD(lr=0.05, decay=1e-6, momentum=0.4, nesterov=False)
model_visual.compile(optimizer=opt,
              loss='binary_crossentropy',
              metrics=['accuracy'])
# Out:
# Using TensorFlow backend.

# %%
model_visual.fit(X_train, Y_train, epochs=20, batch_size=64,verbose=1)
# Out:
# Epoch 1/20
# 34295/34295 [==============================] - 8s 234us/step - loss: 0.5175 - accuracy: 0.7250
# Epoch 2/20
# 34295/34295 [==============================] - 8s 224us/step - loss: 0.4759 - accuracy: 0.7562
# Epoch 3/20
# 34295/34295 [==============================] - 8s 225us/step - loss: 0.4633 - accuracy: 0.7656
# Epoch 4/20
# 34295/34295 [==============================] - 8s 224us/step - loss: 0.4557 - accuracy: 0.7714
# Epoch 5/20
# 34295/34295 [==============================] - 8s 225us/step - loss: 0.4499 - accuracy: 0.7749
# Epoch 6/20
# 34295/34295 [==============================] - 8s 224us/step - loss: 0.4451 - accuracy: 0.7780
# Epoch 7/20
# 34295/34295 [==============================] - 8s 227us/step - loss: 0.4407 - accuracy: 0.7821
# Epoch 8/20
# 34295/34295 [==============================] - 8s 228us/step - loss: 0.4369 - accuracy: 0.7847
# Epoch 9/20
# 34295/34295 [==============================] - 8s 225us/step - loss: 0.4330 - accuracy: 0.7867
# Epoch 10/20
# 34295/34295 [==============================] - 8s 227us/step - loss: 0.4294 - accuracy: 0.7896
# Epoch 11/20
# 34295/34295 [==============================] - 8s 226us/step - loss: 0.4259 - accuracy: 0.7914
# Epoch 12/20
# 34295/34295 [==============================] - 8s 225us/step - loss: 0.4225 - accuracy: 0.7936
# Epoch 13/20
# 34295/34295 [==============================] - 8s 228us/step - loss: 0.4190 - accuracy: 0.7962
# Epoch 14/20
# 34295/34295 [==============================] - 8s 226us/step - loss: 0.4157 - accuracy: 0.7987
# Epoch 15/20
# 34295/34295 [==============================] - 8s 225us/step - loss: 0.4124 - accuracy: 0.8007
# Epoch 16/20
# 34295/34295 [==============================] - 8s 225us/step - loss: 0.4092 - accuracy: 0.8025
# Epoch 17/20
# 34295/34295 [==============================] - 8s 223us/step - loss: 0.4057 - accuracy: 0.8051
# Epoch 18/20
# 34295/34295 [==============================] - 8s 223us/step - loss: 0.4021 - accuracy: 0.8074
# Epoch 19/20
# 34295/34295 [==============================] - 8s 222us/step - loss: 0.3988 - accuracy: 0.8093
# Epoch 20/20
# 34295/34295 [==============================] - 8s 222us/step - loss: 0.3952 - accuracy: 0.8120

# %%
def precision_recall(gt,preds):
    TP=0
    FP=0
    FN=0
    for t in gt:
        if t in preds:
            TP+=1
        else:
            FN+=1
    for p in preds:
        if p not in gt:
            FP+=1
    if TP+FP==0:
        precision=0
    else:
        precision=TP/float(TP+FP)
    if TP+FN==0:
        recall=0
    else:
        recall=TP/float(TP+FN)
    return precision,recall

# %%
Y_preds=model_visual.predict(X_test)

# %%
import pickle
f6=open('/content/drive/My Drive/Genredict.pckl','rb')
Genre_ID_to_name=pickle.load(f6)
f6.close()

# %%
genre_list=sorted(list(Genre_ID_to_name.keys()))

# %%
sum(sum(Y_preds))
# Out:
# 66936.46423339844

# %%
import numpy as np
positions=range(len(df))
# print positions
test_movies=np.asarray(positions)[~mask]
# test_movies

# %%
import numpy as np

precs=[]
recs=[]
for i in range(len(Y_preds)):
    row=Y_preds[i]
    gt_genres=Y_test[i]
    gt_genre_names=[]
    for j in range(14):
        if gt_genres[j]==1:
            gt_genre_names.append(Genre_ID_to_name[genre_list[j]])
    top_3=np.argsort(row)[-4:]
    predicted_genres=[]
    for genre in top_3:
        predicted_genres.append(Genre_ID_to_name[genre_list[genre]])
    (precision,recall)=precision_recall(gt_genre_names,predicted_genres)
    precs.append(precision)
    recs.append(recall)
    print("Predicted: ",','.join(predicted_genres)," Actual: ",','.join(gt_genre_names))
# Out:
# Streaming output truncated to the last 5000 lines.
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Comedy,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Mystery,Science Fiction  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Drama,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,History,Western,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Drama,Horror,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Action,Thriller,Mystery,Science Fiction  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Thriller,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Western,Thriller,Science Fiction,Mystery
# Predicted:  Thriller,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Crime,Science Fiction,Mystery
# Predicted:  Horror,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Western,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Comedy,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Mystery,Science Fiction  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Drama,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,Western,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Mystery,Science Fiction  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Drama,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Mystery,Science Fiction  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Horror,Crime,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Horror,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Comedy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Western,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Comedy,Horror,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Thriller,Drama,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  History,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Drama,Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Comedy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Action,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Science Fiction,Mystery
# Predicted:  Animation,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Thriller,Horror,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Drama,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Horror,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Drama,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Western,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Drama,Thriller,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Thriller,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Horror,Documentary,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Mystery,Science Fiction  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Comedy,Horror,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  History,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Horror,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Crime,Thriller,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  History,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Action,Thriller,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Action,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Western,Documentary,Science Fiction,Mystery
# Predicted:  Action,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Western,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Horror,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,History,Thriller,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Thriller,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Horror,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Science Fiction,Mystery
# Predicted:  Comedy,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Thriller,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Mystery,Science Fiction  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Animation,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Action,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Thriller,Horror,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  History,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Western,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Thriller,Crime,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Drama,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Horror,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Action,Thriller,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Western,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Comedy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  History,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Western,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Western,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Science Fiction,Mystery
# Predicted:  History,Animation,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Animation,Drama,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Crime,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Comedy,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Fantasy,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Western,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Drama,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Drama,Horror,Comedy,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Mystery,Science Fiction  Actual:  Animation,Drama,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Comedy,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Drama,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Documentary,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  History,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,History,Thriller,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Action,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Action,Western,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Drama,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Western,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Action,Thriller,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Animation,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Comedy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Adventure,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,History,Thriller,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Action,Thriller,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Horror,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Comedy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Action,Thriller,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Drama,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Documentary,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Comedy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Animation,Mystery,Science Fiction  Actual:  Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Drama,Horror,Comedy,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Drama,Thriller,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Comedy,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Drama,Animation,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,History,Thriller,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Crime,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Thriller,Horror,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Horror,Crime,Mystery,Science Fiction  Actual:  Animation,Drama,Horror,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Crime,Science Fiction,Mystery
# Predicted:  Horror,Comedy,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Horror,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Drama,Comedy,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Drama,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Comedy,Horror,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Horror,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Documentary,Mystery,Science Fiction  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,History,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Western,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Western,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Comedy,Horror,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Crime,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Mystery,Science Fiction  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  History,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Western,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  History,Action,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Crime,Action,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Drama,Animation,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Drama,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Western,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Comedy,Thriller,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Drama,Horror,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Horror,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Action,Thriller,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Mystery,Science Fiction  Actual:  Animation,Drama,Horror,History,Thriller,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Action,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Drama,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Comedy,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Action,Thriller,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Action,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Action,Thriller,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# ...
# Predicted:  Fantasy,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Thriller,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Animation,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,History,Western,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Documentary,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Western,Crime,Science Fiction,Mystery
# Predicted:  Western,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Western,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Mystery,Science Fiction  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Drama,Thriller,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Documentary,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Drama,Thriller,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Western,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Comedy,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Western,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Western,Science Fiction,Mystery
# Predicted:  Drama,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Horror,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Drama,Science Fiction,Mystery  Actual:  Drama,Western,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Horror,Crime,Science Fiction,Mystery
# Predicted:  Western,Drama,Science Fiction,Mystery  Actual:  Drama,Western,Science Fiction,Mystery
# Predicted:  Adventure,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Western,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Animation,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Animation,Action,History,Crime,Science Fiction,Mystery
# Predicted:  History,Action,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Animation,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Mystery,Science Fiction  Actual:  Horror,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Crime,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Documentary,Mystery,Science Fiction  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Documentary,Drama,Science Fiction,Mystery  Actual:  Drama,Western,Science Fiction,Mystery
# Predicted:  Fantasy,Documentary,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Crime,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Western,Crime,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  History,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Western,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Western,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Drama,Horror,Comedy,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Animation,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Crime,Science Fiction,Mystery
# Predicted:  Western,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Western,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Animation,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Animation,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Documentary,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Crime,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Horror,Animation,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Mystery,Science Fiction  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Crime,Science Fiction,Mystery
# Predicted:  Drama,Adventure,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  History,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,Comedy,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Western,Documentary,Science Fiction,Mystery
# Predicted:  Action,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Western,Thriller,Science Fiction,Mystery
# Predicted:  Drama,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Western,Science Fiction,Mystery
# Predicted:  Fantasy,Documentary,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Crime,Animation,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Crime,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Mystery,Science Fiction  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  History,Action,Mystery,Science Fiction  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Fantasy,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Crime,Science Fiction,Mystery
# Predicted:  Crime,Adventure,Science Fiction,Mystery  Actual:  Horror,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Mystery,Science Fiction  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Crime,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Documentary,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Western,Thriller,Science Fiction,Mystery
# Predicted:  Action,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Crime,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Drama,Mystery,Science Fiction  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Documentary,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Animation,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Documentary,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Adventure,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Documentary,Drama,Mystery,Science Fiction  Actual:  Drama,Western,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Drama,Horror,Science Fiction,Mystery
# Predicted:  Thriller,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery

# %%
print(np.mean(np.asarray(precs)),np.mean(np.asarray(recs)))
print("avg=",(np.mean(np.asarray(precs))+np.mean(np.asarray(recs)))/2)
# Out:
# 0.9044109178855234 0.5317856574305959
# avg= 0.7180982876580597

# %%
print("f1-score", (2*(np.mean(np.asarray(precs)) * np.mean(np.asarray(recs)))) / (np.mean(np.asarray(precs)) + np.mean(np.asarray(recs))))
# Out:
# f1-score 0.6697589491874396

# %%
from keras.models import model_from_json

model_json = model_visual.to_json()
with open("Resnet_Glove.json", "w") as json_file:
    json_file.write(model_json)
model_visual.save_weights("Resnet_Glove.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
img = image.load_img('/content/drive/My Drive/storage3/Iron_Man.jpg',target_size=(224,224))
img = image.img_to_array(img)
img = img/255

# %%
print(np.mean(np.asarray(precs)),np.mean(np.asarray(recs)))
print("avg=",(np.mean(np.asarray(precs))+np.mean(np.asarray(recs)))/2)
# Out:
# 0.9034109178855234 0.5387856574305959
# avg= 0.7210982876580596

# %%
from keras.applications.resnet50 import ResNet50
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

model = ResNet50(weights='imagenet')
# Out:
# Using TensorFlow backend.

# %%
import pandas as pd
df1 = pd.read_pickle("/content/drive/My Drive/pinky_promise_last.pckl")

# %%
#imnames=poster_movies_1
feature_list1=[]
genre_list1=[]
file_order1=[]
#print("Total images = ",len(imnames))
failed_files1=[]
succesful_files1=[]
i=14999
for mov in range(15000,30000):
    i+=1
    mov_name=df1.title[mov]
    mov_name1=mov_name.replace(':','/')
    poster_name=mov_name.replace(' ','_')+'.jpg'
    img_path=df1.poster_path[mov]
    try:
        img = image.load_img(img_path, target_size=(224, 224))
        succesful_files1.append(poster_name)
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = preprocess_input(x)
        features = model.predict(x)
        file_order1.append(img_path)
        feature_list1.append(features)
        genre_list1.append(df1.genre_ids[mov])
        if np.max(np.asarray(feature_list1))==0.0:
            print('problematic',i)
        if i%50==0 or i==15000:
            print("Working on Image : ",i)
    except:
        failed_files1.append(poster_name)
        continue
        
import pickle
list_pickled=(feature_list1,file_order1,failed_files1,succesful_files1,genre_list1)
f=open('Resnet_features_2.pckl','wb')
pickle.dump(list_pickled,f)
f.close()
print("Features dumped to pickle file")
# Out:
# Working on Image :  15000
# Working on Image :  15050
# Working on Image :  15100
# Working on Image :  15150
# Working on Image :  15200
# Working on Image :  15250
# Working on Image :  15300
# Working on Image :  15350
# Working on Image :  15400
# Working on Image :  15450
# Working on Image :  15500
# Working on Image :  15550
# Working on Image :  15600
# Working on Image :  15650
# Working on Image :  15700
# Working on Image :  15750
# Working on Image :  15800
# Working on Image :  15850
# Working on Image :  15900
# Working on Image :  15950
# Working on Image :  16000
# Working on Image :  16050
# Working on Image :  16100
# Working on Image :  16150
# Working on Image :  16200
# Working on Image :  16250
# Working on Image :  16300
# Working on Image :  16350
# Working on Image :  16400
# Working on Image :  16450
# Working on Image :  16500
# Working on Image :  16550
# Working on Image :  16600
# Working on Image :  16650
# Working on Image :  16700
# Working on Image :  16750
# Working on Image :  16800
# Working on Image :  16850
# Working on Image :  16900
# Working on Image :  16950
# Working on Image :  17000
# Working on Image :  17050
# Working on Image :  17100
# Working on Image :  17150
# Working on Image :  17200
# Working on Image :  17250
# Working on Image :  17300
# Working on Image :  17350
# Working on Image :  17400
# Working on Image :  17450
# Working on Image :  17500
# Working on Image :  17550
# Working on Image :  17600
# Working on Image :  17650
# Working on Image :  17700
# Working on Image :  17750
# Working on Image :  17800
# Working on Image :  17850
# Working on Image :  17900
# Working on Image :  17950
# Working on Image :  18000
# Working on Image :  18050
# Working on Image :  18100
# Working on Image :  18150
# Working on Image :  18200
# Working on Image :  18250
# Working on Image :  18300
# Working on Image :  18350
# Working on Image :  18400
# Working on Image :  18450
# Working on Image :  18500
# Working on Image :  18550
# Working on Image :  18600
# Working on Image :  18650
# Working on Image :  18700
# Working on Image :  18750
# Working on Image :  18800
# Working on Image :  18850
# Working on Image :  18900
# Working on Image :  18950
# Working on Image :  19000
# Working on Image :  19050
# Working on Image :  19100
# Working on Image :  19150
# Working on Image :  19200
# Working on Image :  19250
# Working on Image :  19300
# Working on Image :  19350
# Working on Image :  19400
# Working on Image :  19450
# Working on Image :  19500
# Working on Image :  19550
# Working on Image :  19600
# Working on Image :  19650
# Working on Image :  19700
# Working on Image :  19750
# Working on Image :  19800
# Working on Image :  19850
# Working on Image :  19900
# Working on Image :  19950
# Working on Image :  20000
# Working on Image :  20050
# Working on Image :  20100
# Working on Image :  20150
# Working on Image :  20200
# Working on Image :  20250
# Working on Image :  20300
# Working on Image :  20350
# Working on Image :  20400
# Working on Image :  20450
# Working on Image :  20500
# Working on Image :  20550
# Working on Image :  20600
# Working on Image :  20650
# Working on Image :  20700
# Working on Image :  20750
# Working on Image :  20800
# Working on Image :  20850
# Working on Image :  20900
# Working on Image :  20950
# Working on Image :  21000
# Working on Image :  21050
# Working on Image :  21100
# Working on Image :  21150
# Working on Image :  21200
# Working on Image :  21250
# Working on Image :  21300
# Working on Image :  21350
# Working on Image :  21400
# Working on Image :  21450
# Working on Image :  21500
# Working on Image :  21550
# Working on Image :  21600
# Working on Image :  21650
# Working on Image :  21700
# Working on Image :  21750
# Working on Image :  21800
# Working on Image :  21850
# Working on Image :  21900
# Working on Image :  21950
# Working on Image :  22000
# Working on Image :  22050
# Working on Image :  22100
# Working on Image :  22150
# Working on Image :  22200
# Working on Image :  22250
# Working on Image :  22300
# Working on Image :  22350
# Working on Image :  22400
# Working on Image :  22450
# Working on Image :  22500
# Working on Image :  22550
# Working on Image :  22600
# Working on Image :  22650
# Working on Image :  22700
# Working on Image :  22750
# Working on Image :  22800
# Working on Image :  22850
# Working on Image :  22900
# Working on Image :  22950
# Working on Image :  23000
# Working on Image :  23050
# Working on Image :  23100
# Working on Image :  23150
# Working on Image :  23200
# Working on Image :  23250
# Working on Image :  23300
# Working on Image :  23350
# Working on Image :  23400
# Working on Image :  23450
# Working on Image :  23500
# Working on Image :  23550
# Working on Image :  23600
# Working on Image :  23650
# Working on Image :  23700
# Working on Image :  23750
# Working on Image :  23800
# Working on Image :  23850
# Working on Image :  23900
# Working on Image :  23950
# Working on Image :  24000
# Working on Image :  24050
# Working on Image :  24100
# Working on Image :  24150
# Working on Image :  24200
# Working on Image :  24250
# Working on Image :  24300
# Working on Image :  24350
# Working on Image :  24400
# Working on Image :  24450
# Working on Image :  24500
# Working on Image :  24550
# Working on Image :  24600
# Working on Image :  24650
# Working on Image :  24700
# Working on Image :  24750
# Working on Image :  24800
# Working on Image :  24850
# Working on Image :  24900
# Working on Image :  24950
# Working on Image :  25000
# Working on Image :  25050
# Working on Image :  25100
# Working on Image :  25150
# Working on Image :  25200
# Working on Image :  25250
# Working on Image :  25300
# Working on Image :  25350
# Working on Image :  25400
# Working on Image :  25450
# Working on Image :  25500
# Working on Image :  25550
# Working on Image :  25600
# Working on Image :  25650
# Working on Image :  25700
# Working on Image :  25750
# Working on Image :  25800
# Working on Image :  25850
# Working on Image :  25900
# Working on Image :  25950
# Working on Image :  26000
# Working on Image :  26050
# Working on Image :  26100
# Working on Image :  26150
# Working on Image :  26200
# Working on Image :  26250
# Working on Image :  26300
# Working on Image :  26350
# Working on Image :  26400
# Working on Image :  26450
# Working on Image :  26500
# Working on Image :  26550
# Working on Image :  26600
# Working on Image :  26650
# Working on Image :  26700
# Working on Image :  26750
# Working on Image :  26800
# Working on Image :  26850
# Working on Image :  26900
# Working on Image :  26950
# Working on Image :  27000
# Working on Image :  27050
# Working on Image :  27100
# Working on Image :  27150
# Working on Image :  27200
# Working on Image :  27250
# Working on Image :  27300
# Working on Image :  27350
# Working on Image :  27400
# Working on Image :  27450
# Working on Image :  27500
# Working on Image :  27550
# Working on Image :  27600
# Working on Image :  27650
# Working on Image :  27700
# Working on Image :  27750
# Working on Image :  27800
# Working on Image :  27850
# Working on Image :  27900
# Working on Image :  27950
# Working on Image :  28000
# Working on Image :  28050
# Working on Image :  28100
# Working on Image :  28150
# Working on Image :  28200
# Working on Image :  28250
# Working on Image :  28300
# Working on Image :  28350
# Working on Image :  28400
# Working on Image :  28450
# Working on Image :  28500
# Working on Image :  28550
# Working on Image :  28600
# Working on Image :  28650
# Working on Image :  28700
# Working on Image :  28750
# Working on Image :  28800
# Working on Image :  28850
# Working on Image :  28900
# Working on Image :  28950
# Working on Image :  29000
# Working on Image :  29050
# Working on Image :  29100
# Working on Image :  29150
# Working on Image :  29200
# Working on Image :  29250
# Working on Image :  29300
# Working on Image :  29350
# Working on Image :  29400
# Working on Image :  29450
# Working on Image :  29500
# Working on Image :  29550
# Working on Image :  29600
# Working on Image :  29650
# Working on Image :  29700
# Working on Image :  29750
# Working on Image :  29800
# Working on Image :  29850
# Working on Image :  29900
# Working on Image :  29950
# Features dumped to pickle file

# %%
len(feature_list1)
# Out:
# 15000

# %%
feature_list1[0].shape
# Out:
# (1, 1000)

# %%
(a,b)=feature_list1[0].shape
feature_size=a*b

np_features=np.zeros((len(feature_list1),feature_size))
for i in range(len(feature_list1)):
    feat=feature_list1[i]
    reshaped_feat=feat.reshape(1,-1)
    np_features[i]=reshaped_feat

# %%
# !ls
# Out:
# drive  sample_data

# %%
import os
poster_movies_1 = os.listdir("/content/drive/My Drive/storage1")
len(poster_movies_1)
# Out:
# 15914

# %%
poster_movies = poster_movies_1

# %%
len(set(poster_movies))
# Out:
# 15914

# %%
poster_movies_copy_1 = [i.replace("_"," ").rstrip(".jpg") for i in poster_movies_1]

# %%
len(poster_movies_copy_1)
# Out:
# 15914

# %%
# !pip install tensorflow==1.14
# Out:
# Collecting tensorflow==1.14
#   Downloading https://files.pythonhosted.org/packages/de/f0/96fb2e0412ae9692dbf400e5b04432885f677ad6241c088ccc5fe7724d69/tensorflow-1.14.0-cp36-cp36m-manylinux1_x86_64.whl (109.2MB)
#      |████████████████████████████████| 109.2MB 91kB/s
# Collecting tensorflow-estimator<1.15.0rc0,>=1.14.0rc0
#   Downloading https://files.pythonhosted.org/packages/3c/d5/21860a5b11caf0678fbc8319341b0ae21a07156911132e0e71bffed0510d/tensorflow_estimator-1.14.0-py2.py3-none-any.whl (488kB)
#      |████████████████████████████████| 491kB 46.3MB/s
# Collecting tensorboard<1.15.0,>=1.14.0
#   Downloading https://files.pythonhosted.org/packages/91/2d/2ed263449a078cd9c8a9ba50ebd50123adf1f8cfbea1492f9084169b89d9/tensorboard-1.14.0-py3-none-any.whl (3.1MB)
#      |████████████████████████████████| 3.2MB 46.0MB/s
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (1.12.1)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (1.18.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (1.1.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (1.1.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (1.28.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (0.34.2)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (0.9.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (0.8.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (1.12.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (0.2.0)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (0.3.3)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (3.10.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (1.0.8)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (46.1.3)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (3.2.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow==1.14) (2.10.0)
# Installing collected packages: tensorflow-estimator, tensorboard, tensorflow
#   Found existing installation: tensorflow-estimator 2.2.0rc0
#     Uninstalling tensorflow-estimator-2.2.0rc0:
#       Successfully uninstalled tensorflow-estimator-2.2.0rc0
#   Found existing installation: tensorboard 2.2.0
#     Uninstalling tensorboard-2.2.0:
#       Successfully uninstalled tensorboard-2.2.0
#   Found existing installation: tensorflow 2.2.0rc2
#     Uninstalling tensorflow-2.2.0rc2:
#       Successfully uninstalled tensorflow-2.2.0rc2
# Successfully installed tensorboard-1.14.0 tensorflow-1.14.0 tensorflow-estimator-1.14.0

# %%
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np

model = VGG16(weights='imagenet', include_top=False)

# %%
import pandas as pd

df = pd.read_csv("/content/drive/My Drive/last.csv",engine="python")
df1 = df[df['title'].isin(poster_movies_copy_1)]
df1 = df1.reset_index()

# %%
len(df1)
# Out:
# 14116

# %%
imnames=poster_movies_1
feature_list1=[]
genre_list1=[]
file_order1=[]
print("Starting extracting VGG features for scraped images. This will take time, Please be patient...")
print("Total images = ",len(imnames))
failed_files1=[]
succesful_files1=[]
i=0
for mov in range(len(df1)):
    i+=1
    mov_name=df1.title[mov]
    mov_name1=mov_name.replace(':','/')
    poster_name=mov_name.replace(' ','_')+'.jpg'
    if poster_name in imnames:
        img_path="/content/drive/My Drive/storage1/"+poster_name
        try:
            img = image.load_img(img_path, target_size=(224, 224))
            succesful_files1.append(poster_name)
            x = image.img_to_array(img)
            x = np.expand_dims(x, axis=0)
            x = preprocess_input(x)
            features = model.predict(x)
            file_order1.append(img_path)
            feature_list1.append(features)
            genre_list1.append(df1.genre_ids[mov])
            if np.max(np.asarray(feature_list1))==0.0:
                print('problematic',i)
            if i%50==0 or i==1:
                print("Working on Image : ",i)
        except:
            failed_files1.append(poster_name)
            continue
        
    else:
        continue
print("Done with all features, please pickle for future use!")

import pickle
list_pickled=(feature_list1,file_order1,failed_files1,succesful_files1,genre_list1)
f=open('posters_new_features1.pckl','wb')
pickle.dump(list_pickled,f)
f.close()
print("Features dumped to pickle file")
# Out:
# Starting extracting VGG features for scraped images. This will take time, Please be patient...
# Total images =  15914
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Working on Image :  1
# Working on Image :  50
# Working on Image :  100
# Working on Image :  150
# Working on Image :  200
# Working on Image :  250
# Working on Image :  300
# Working on Image :  350
# Working on Image :  400
# Working on Image :  450
# Working on Image :  500
# Working on Image :  550
# Working on Image :  600
# Working on Image :  650
# Working on Image :  700
# Working on Image :  750
# Working on Image :  800
# Working on Image :  850
# Working on Image :  900
# Working on Image :  950
# Working on Image :  1000
# Working on Image :  1050
# Working on Image :  1100
# Working on Image :  1150
# Working on Image :  1200
# Working on Image :  1250
# Working on Image :  1300
# Working on Image :  1350
# Working on Image :  1400
# Working on Image :  1450
# Working on Image :  1500
# Working on Image :  1550
# Working on Image :  1600
# Working on Image :  1650
# Working on Image :  1700
# Working on Image :  1750
# Working on Image :  1800
# Working on Image :  1850
# Working on Image :  1900
# Working on Image :  1950
# Working on Image :  2000
# Working on Image :  2050
# Working on Image :  2100
# Working on Image :  2150
# Working on Image :  2200
# Working on Image :  2250
# Working on Image :  2300
# Working on Image :  2350
# Working on Image :  2400
# Working on Image :  2450
# Working on Image :  2500
# Working on Image :  2550
# Working on Image :  2600
# Working on Image :  2650
# Working on Image :  2700
# Working on Image :  2750
# Working on Image :  2800
# Working on Image :  2850
# Working on Image :  2900
# Working on Image :  2950
# Working on Image :  3000
# Working on Image :  3050
# Working on Image :  3100
# Working on Image :  3150
# Working on Image :  3200
# Working on Image :  3250
# Working on Image :  3300
# Working on Image :  3350
# Working on Image :  3400
# Working on Image :  3450
# Working on Image :  3500
# Working on Image :  3550
# Working on Image :  3600
# Working on Image :  3650
# Working on Image :  3700
# Working on Image :  3750
# Working on Image :  3800
# Working on Image :  3850
# Working on Image :  3900
# Working on Image :  3950
# Working on Image :  4000
# Working on Image :  4050
# Working on Image :  4100
# Working on Image :  4150
# Working on Image :  4200
# Working on Image :  4250
# Working on Image :  4300
# Working on Image :  4350
# Working on Image :  4400
# Working on Image :  4450
# Working on Image :  4500
# Working on Image :  4550
# Working on Image :  4600
# Working on Image :  4650
# Working on Image :  4700
# Working on Image :  4750
# Working on Image :  4800
# Working on Image :  4850
# Working on Image :  4900
# Working on Image :  4950
# Working on Image :  5000
# Working on Image :  5050
# Working on Image :  5100
# Working on Image :  5150
# Working on Image :  5200
# Working on Image :  5250
# Working on Image :  5300
# Working on Image :  5350
# Working on Image :  5400
# Working on Image :  5450
# Working on Image :  5500
# Working on Image :  5550
# Working on Image :  5600
# Working on Image :  5650
# Working on Image :  5700
# Working on Image :  5750
# Working on Image :  5800
# Working on Image :  5850
# Working on Image :  5900
# Working on Image :  5950
# Working on Image :  6000
# Working on Image :  6050
# Working on Image :  6100
# Working on Image :  6150
# Working on Image :  6200
# Working on Image :  6250
# Working on Image :  6300
# Working on Image :  6350
# Working on Image :  6400
# Working on Image :  6450
# Working on Image :  6500
# Working on Image :  6550
# Working on Image :  6600
# Working on Image :  6650
# Working on Image :  6700
# Working on Image :  6750
# Working on Image :  6800
# Working on Image :  6850
# Working on Image :  6900
# Working on Image :  6950
# Working on Image :  7000
# Working on Image :  7050
# Working on Image :  7100
# Working on Image :  7150
# Working on Image :  7200
# Working on Image :  7250
# Working on Image :  7300
# Working on Image :  7350
# Working on Image :  7400
# Working on Image :  7450
# Working on Image :  7500
# Working on Image :  7550
# Working on Image :  7600
# Working on Image :  7650
# Working on Image :  7700
# Working on Image :  7750
# Working on Image :  7800
# Working on Image :  7850
# Working on Image :  7900
# Working on Image :  7950
# Working on Image :  8000
# Working on Image :  8050
# Working on Image :  8100
# Working on Image :  8150
# Working on Image :  8200
# Working on Image :  8250
# Working on Image :  8300
# Working on Image :  8350
# Working on Image :  8400
# Working on Image :  8450
# Working on Image :  8500
# Working on Image :  8550
# Working on Image :  8600
# Working on Image :  8650
# Working on Image :  8700
# Working on Image :  8750
# Working on Image :  8800
# Working on Image :  8850
# Working on Image :  8900
# Working on Image :  8950
# Working on Image :  9000
# Working on Image :  9050
# Working on Image :  9100
# Working on Image :  9150
# Working on Image :  9200
# Working on Image :  9250
# Working on Image :  9300
# Working on Image :  9350
# Working on Image :  9400
# Working on Image :  9450
# Working on Image :  9500
# Working on Image :  9550
# Working on Image :  9600
# Working on Image :  9650
# Working on Image :  9700
# Working on Image :  9750
# Working on Image :  9800
# Working on Image :  9850
# Working on Image :  9900
# Working on Image :  9950
# Working on Image :  10000
# Working on Image :  10050
# Working on Image :  10100
# Working on Image :  10150
# Working on Image :  10200
# Working on Image :  10250
# Working on Image :  10300
# Working on Image :  10350
# Working on Image :  10400
# Working on Image :  10450
# Working on Image :  10500
# Working on Image :  10550
# Working on Image :  10600
# Working on Image :  10650
# Working on Image :  10700
# Working on Image :  10750
# Working on Image :  10800
# Working on Image :  10850
# Working on Image :  10900
# Working on Image :  10950
# Working on Image :  11000
# Working on Image :  11050
# Working on Image :  11100
# Working on Image :  11150
# Working on Image :  11200
# Working on Image :  11250
# Working on Image :  11300
# Working on Image :  11350
# Working on Image :  11400
# Working on Image :  11450
# Working on Image :  11500
# Working on Image :  11550
# Working on Image :  11600
# Working on Image :  11650
# Working on Image :  11700
# Working on Image :  11750
# Working on Image :  11800
# Working on Image :  11850
# Working on Image :  11900
# Working on Image :  11950
# Working on Image :  12000
# Working on Image :  12050
# Working on Image :  12100
# Working on Image :  12150
# Working on Image :  12200
# Working on Image :  12250
# Working on Image :  12300
# Working on Image :  12350
# Working on Image :  12400
# Working on Image :  12450
# Working on Image :  12500
# Working on Image :  12550
# Working on Image :  12600
# Working on Image :  12650
# Working on Image :  12700
# Working on Image :  12750
# Working on Image :  12800
# Working on Image :  12850
# Working on Image :  12900
# Working on Image :  12950
# Working on Image :  13000
# Working on Image :  13050
# Working on Image :  13100
# Working on Image :  13150
# Working on Image :  13200
# Working on Image :  13250
# Working on Image :  13300
# Working on Image :  13350
# Working on Image :  13400
# Working on Image :  13450
# Working on Image :  13500
# Working on Image :  13550
# Working on Image :  13600
# Working on Image :  13650
# Working on Image :  13700
# Working on Image :  13750
# Working on Image :  13800
# Working on Image :  13850
# Working on Image :  13900
# Working on Image :  13950
# Working on Image :  14000
# Working on Image :  14050
# Working on Image :  14100
# Done with all features, please pickle for future use!
# Features dumped to pickle file

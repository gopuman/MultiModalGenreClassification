# %%
import pickle

f1=open('/content/drive/My Drive/posters_new_features1.pckl','rb')
list_pickled1=pickle.load(f1)
f1.close()

f2=open('/content/drive/My Drive/posters_new_features2.pckl','rb')
list_pickled2=pickle.load(f2)
f2.close()

f3=open('/content/drive/My Drive/posters_new_features3.pckl','rb')
list_pickled3=pickle.load(f3)
f3.close()

# %%
del f1
del f2
del f3

# %%
a = list_pickled1[0]
b = list_pickled1[1]
c = list_pickled1[2]
d = list_pickled1[3]
e = list_pickled1[4]

a.extend(list_pickled2[0])
b.extend(list_pickled2[1])
c.extend(list_pickled2[2])
d.extend(list_pickled2[3])
e.extend(list_pickled2[4])

a.extend(list_pickled3[0])
b.extend(list_pickled3[1])
c.extend(list_pickled3[2])
d.extend(list_pickled3[3])
e.extend(list_pickled3[4])

# %%
final_feature_list = a
final_files = b
final_failed = c
final_succesful = d
final_genre_list = e

# %%
del a
del b
del c
del d
del e

# %%
import numpy as np
(feature_list,files,failed,succesful,genre_list)=(final_feature_list,final_files,final_failed,final_succesful,final_genre_list)

(a,b,c,d)=feature_list[0].shape
feature_size=a*b*c*d

np_features=np.zeros((len(feature_list),feature_size))
for i in range(len(feature_list)):
    feat=feature_list[i]
    reshaped_feat=feat.reshape(1,-1)
    np_features[i]=reshaped_feat

X=np_features

from sklearn.preprocessing import MultiLabelBinarizer
mlb=MultiLabelBinarizer()
Y=mlb.fit_transform(genre_list)

Y.shape
# Out:
# (39133, 14)

# %%
del feat
del feature_list
del feature_size
del final_failed
del final_feature_list
del final_files
del final_genre_list
del final_succesful
del genre_list
del list_pickled1
del list_pickled2
del list_pickled3
del reshaped_feat
del succesful
del np_features
del mlb

# %%
del failed
del files
del MultiLabelBinarizer

# %%
mask = np.random.rand(len(X)) < 0.8

X_train=X[mask]
X_test=X[~mask]
Y_train=Y[mask]
Y_test=Y[~mask]

# %%
del X
del Y

# %%
visual_problem_data=(X,Y)
f8=open('visual_data.pckl','wb')
pickle.dump(visual_problem_data,f8)
f8.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-e420e44748d4> in <module>()
# ----> 1 visual_problem_data=(X,Y)
#       2 f8=open('visual_data.pckl','wb')
#       3 pickle.dump(visual_problem_data,f8)
#       4 f8.close()
#
# NameError: name 'X' is not defined

# %%
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np

model = VGG16(weights='imagenet', include_top=False)

from keras.models import Sequential
from keras.layers import Dense, Activation
from keras import optimizers
model_visual = Sequential([
    Dense(1024, input_shape=(25088,)),
    Activation('relu'),
    Dense(256),
    Activation('relu'),
    Dense(14),
    Activation('sigmoid'),
])
opt = optimizers.rmsprop(lr=0.0001, decay=1e-6)

#sgd = optimizers.SGD(lr=0.05, decay=1e-6, momentum=0.4, nesterov=False)
model_visual.compile(optimizer=opt,
              loss='binary_crossentropy',
              metrics=['accuracy'])
# Out:
# Using TensorFlow backend.

# %%
model_visual.fit(X_train, Y_train, epochs=10, batch_size=64,verbose=1)
# Out:
# Epoch 1/10
# 31141/31141 [==============================] - 89s 3ms/step - loss: 0.6849 - accuracy: 0.6609
# Epoch 2/10
# 31141/31141 [==============================] - 87s 3ms/step - loss: 0.5218 - accuracy: 0.7116
# Epoch 3/10
# 31141/31141 [==============================] - 88s 3ms/step - loss: 0.4514 - accuracy: 0.7598
# Epoch 4/10
# 31141/31141 [==============================] - 86s 3ms/step - loss: 0.3778 - accuracy: 0.8121
# Epoch 5/10
# 31141/31141 [==============================] - 84s 3ms/step - loss: 0.3161 - accuracy: 0.8488
# Epoch 6/10
# 31141/31141 [==============================] - 85s 3ms/step - loss: 0.2721 - accuracy: 0.8719
# Epoch 7/10
# 31141/31141 [==============================] - 84s 3ms/step - loss: 0.2357 - accuracy: 0.8906
# Epoch 8/10
# 31141/31141 [==============================] - 84s 3ms/step - loss: 0.2077 - accuracy: 0.9057
# Epoch 9/10
# 31141/31141 [==============================] - 84s 3ms/step - loss: 0.1841 - accuracy: 0.9188
# Epoch 10/10
# 31141/31141 [==============================] - 84s 3ms/step - loss: 0.1633 - accuracy: 0.9287

# %%
model_visual.fit(X_train, Y_train, epochs=50, batch_size=64,verbose=1)
# Out:
# Epoch 1/50
# 31141/31141 [==============================] - 84s 3ms/step - loss: 0.1474 - accuracy: 0.9367
# Epoch 2/50
# 31141/31141 [==============================] - 84s 3ms/step - loss: 0.1323 - accuracy: 0.9440
# Epoch 3/50
# 31141/31141 [==============================] - 84s 3ms/step - loss: 0.1196 - accuracy: 0.9501
# Epoch 4/50
# 31141/31141 [==============================] - 84s 3ms/step - loss: 0.1089 - accuracy: 0.9550
# Epoch 5/50
# 31141/31141 [==============================] - 84s 3ms/step - loss: 0.0996 - accuracy: 0.9596
# Epoch 6/50
# 31141/31141 [==============================] - 84s 3ms/step - loss: 0.0902 - accuracy: 0.9635
# Epoch 7/50
# 31141/31141 [==============================] - 84s 3ms/step - loss: 0.0837 - accuracy: 0.9667
# Epoch 8/50
# 31141/31141 [==============================] - 84s 3ms/step - loss: 0.0772 - accuracy: 0.9695
# Epoch 9/50
# 31141/31141 [==============================] - 84s 3ms/step - loss: 0.0713 - accuracy: 0.9721
# Epoch 10/50
# 31141/31141 [==============================] - 91s 3ms/step - loss: 0.0657 - accuracy: 0.9742
# Epoch 11/50
# 31141/31141 [==============================] - 84s 3ms/step - loss: 0.0609 - accuracy: 0.9762
# Epoch 12/50
# 31141/31141 [==============================] - 84s 3ms/step - loss: 0.0572 - accuracy: 0.9780
# Epoch 13/50
# 31141/31141 [==============================] - 84s 3ms/step - loss: 0.0526 - accuracy: 0.9800
# Epoch 14/50
# 31141/31141 [==============================] - 86s 3ms/step - loss: 0.0496 - accuracy: 0.9812
# Epoch 15/50
# 31141/31141 [==============================] - 86s 3ms/step - loss: 0.0464 - accuracy: 0.9824
# Epoch 16/50
# 31141/31141 [==============================] - 89s 3ms/step - loss: 0.0437 - accuracy: 0.9836
# Epoch 17/50
# 31141/31141 [==============================] - 85s 3ms/step - loss: 0.0410 - accuracy: 0.9847
# Epoch 18/50
# 31141/31141 [==============================] - 86s 3ms/step - loss: 0.0393 - accuracy: 0.9856
# Epoch 19/50
# 31141/31141 [==============================] - 87s 3ms/step - loss: 0.0365 - accuracy: 0.9867
# Epoch 20/50
# 31141/31141 [==============================] - 85s 3ms/step - loss: 0.0349 - accuracy: 0.9873
# Epoch 21/50
# 31141/31141 [==============================] - 86s 3ms/step - loss: 0.0330 - accuracy: 0.9879
# Epoch 22/50
# 31141/31141 [==============================] - 87s 3ms/step - loss: 0.0311 - accuracy: 0.9886
# Epoch 23/50
# 31141/31141 [==============================] - 87s 3ms/step - loss: 0.0299 - accuracy: 0.9892
# Epoch 24/50
# 31141/31141 [==============================] - 88s 3ms/step - loss: 0.0288 - accuracy: 0.9898
# Epoch 25/50
# 31141/31141 [==============================] - 87s 3ms/step - loss: 0.0287 - accuracy: 0.9902
# Epoch 26/50
# 31141/31141 [==============================] - 88s 3ms/step - loss: 0.0266 - accuracy: 0.9907
# Epoch 27/50
# 31141/31141 [==============================] - 86s 3ms/step - loss: 0.0272 - accuracy: 0.9907
# Epoch 28/50
# 31141/31141 [==============================] - 83s 3ms/step - loss: 0.0245 - accuracy: 0.9914
# Epoch 29/50
# 31141/31141 [==============================] - 84s 3ms/step - loss: 0.0239 - accuracy: 0.9917
# Epoch 30/50
# 31141/31141 [==============================] - 84s 3ms/step - loss: 0.0230 - accuracy: 0.9921
# Epoch 31/50
# 31141/31141 [==============================] - 84s 3ms/step - loss: 0.0235 - accuracy: 0.9921
# Epoch 32/50
# 31141/31141 [==============================] - 84s 3ms/step - loss: 0.0217 - accuracy: 0.9924
# Epoch 33/50
# 31141/31141 [==============================] - 84s 3ms/step - loss: 0.0207 - accuracy: 0.9927
# Epoch 34/50
# 31141/31141 [==============================] - 84s 3ms/step - loss: 0.0203 - accuracy: 0.9927
# Epoch 35/50
# 31141/31141 [==============================] - 84s 3ms/step - loss: 0.0198 - accuracy: 0.9931
# Epoch 36/50
# 31141/31141 [==============================] - 84s 3ms/step - loss: 0.0195 - accuracy: 0.9934
# Epoch 37/50
# 31141/31141 [==============================] - 84s 3ms/step - loss: 0.0188 - accuracy: 0.9936
# Epoch 38/50
# 31141/31141 [==============================] - 84s 3ms/step - loss: 0.0179 - accuracy: 0.9939
# Epoch 39/50
# 31141/31141 [==============================] - 84s 3ms/step - loss: 0.0179 - accuracy: 0.9939
# Epoch 40/50
# 31141/31141 [==============================] - 84s 3ms/step - loss: 0.0170 - accuracy: 0.9941
# Epoch 41/50
# 31141/31141 [==============================] - 84s 3ms/step - loss: 0.0171 - accuracy: 0.9942
# Epoch 42/50
# 31141/31141 [==============================] - 84s 3ms/step - loss: 0.0172 - accuracy: 0.9943
# Epoch 43/50
# 31141/31141 [==============================] - 83s 3ms/step - loss: 0.0175 - accuracy: 0.9943
# Epoch 44/50
# 31141/31141 [==============================] - 84s 3ms/step - loss: 0.0163 - accuracy: 0.9947
# Epoch 45/50
# 31141/31141 [==============================] - 84s 3ms/step - loss: 0.0158 - accuracy: 0.9947
# Epoch 46/50
# 31141/31141 [==============================] - 85s 3ms/step - loss: 0.0156 - accuracy: 0.9949
# Epoch 47/50
# 31141/31141 [==============================] - 86s 3ms/step - loss: 0.0168 - accuracy: 0.9948
# Epoch 48/50
# 31141/31141 [==============================] - 85s 3ms/step - loss: 0.0148 - accuracy: 0.9951
# Epoch 49/50
# 31141/31141 [==============================] - 86s 3ms/step - loss: 0.0142 - accuracy: 0.9952
# Epoch 50/50
# 31141/31141 [==============================] - 85s 3ms/step - loss: 0.0146 - accuracy: 0.9951

# %%
Y_preds=model_visual.predict(X_test)

# %%
sum(sum(Y_preds))
# Out:
# 64596.593994140625

# %%
f6=open('/content/drive/My Drive/Genredict.pckl','rb')
Genre_ID_to_name=pickle.load(f6)
f6.close()

# %%
sum(Y_preds[1])
sum(Y_preds[2])
# Out:
# 7.99976897340796

# %%
genre_list=sorted(list(Genre_ID_to_name.keys()))

# %%
def precision_recall(gt,preds):
    TP=0
    FP=0
    FN=0
    for t in gt:
        if t in preds:
            TP+=1
        else:
            FN+=1
    for p in preds:
        if p not in gt:
            FP+=1
    if TP+FP==0:
        precision=0
    else:
        precision=TP/float(TP+FP)
    if TP+FN==0:
        recall=0
    else:
        recall=TP/float(TP+FN)
    return precision,recall

# %%
precs=[]
recs=[]
for i in range(len(Y_preds)):
    row=Y_preds[i]
    gt_genres=Y_test[i]
    gt_genre_names=[]
    for j in range(14):
        if gt_genres[j]==1:
            gt_genre_names.append(Genre_ID_to_name[genre_list[j]])
    top_3=np.argsort(row)[-4:]
    predicted_genres=[]
    for genre in top_3:
        predicted_genres.append(Genre_ID_to_name[genre_list[genre]])
    (precision,recall)=precision_recall(gt_genre_names,predicted_genres)
    precs.append(precision)
    recs.append(recall)
    print("Predicted: ",','.join(predicted_genres)," Actual: ",','.join(gt_genre_names))

print(np.mean(np.asarray(precs)),np.mean(np.asarray(recs)))
print("avg=",(np.mean(np.asarray(precs))+np.mean(np.asarray(recs)))/2)
# Out:
# Streaming output truncated to the last 5000 lines.
# Predicted:  Thriller,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,Western,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Western,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Comedy,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Comedy,History,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Crime,Documentary,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Animation,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  History,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Comedy,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  History,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Drama,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  History,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,Western,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  History,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Drama,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  History,Action,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  History,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Horror,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  History,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Crime,Animation,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Western,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Western,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Horror,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Drama,Western,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Drama,Thriller,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Crime,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Drama,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Action,Documentary,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  History,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Action,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Animation,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Action,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Western,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  History,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Action,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Action,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Animation,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  History,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Horror,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Comedy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  History,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,Western,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Drama,Comedy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Crime,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Crime,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Animation,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Drama,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Drama,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Western,Documentary,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  History,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Crime,Documentary,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Horror,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Animation,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Documentary,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Horror,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Documentary,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Action,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Action,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Comedy,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  History,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  History,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Comedy,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Documentary,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Action,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Drama,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Comedy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  History,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Drama,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Documentary,Western,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Animation,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  History,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Comedy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Western,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Drama,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# ...
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Western,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Comedy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Crime,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Action,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Thriller,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Drama,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,Comedy,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  History,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  History,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Horror,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Drama,Western,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Crime,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  History,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Action,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  History,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Crime,Science Fiction,Mystery
# Predicted:  History,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Western,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Drama,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Action,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Action,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Animation,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Comedy,Thriller,Crime,Science Fiction,Mystery
# Predicted:  History,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,Comedy,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Drama,Comedy,Science Fiction,Mystery
# Predicted:  Thriller,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Western,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Crime,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Thriller,Horror,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Horror,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Horror,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Crime,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Thriller,Action,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# 0.8480355355355356 0.48102227442505213
# avg= 0.6645289049802938

# %%
from keras.models import model_from_json

model_json = model_visual.to_json()
with open("VGG.json", "w") as json_file:
    json_file.write(model_json)
model_visual.save_weights("VGG.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
# x = image.img_to_array(img)
# x = np.expand_dims(x, axis=0)
# x = preprocess_input(x)
#features = model.predict(x)

img = image.load_img('/content/drive/My Drive/storage3/Iron_Man.jpg',target_size=(224,224))
img = image.img_to_array(img)
img = np.expand_dims(img,axis=0)
img = preprocess_input(img)

# %%
features = model.predict(img)

# %%
proba = model_visual.predict(features.reshape(1,-1))

# %%
proba
# Out:
# array([[1.0000000e+00, 1.0000000e+00, 7.4302452e-21, 1.0000000e+00,
#         1.0000000e+00, 0.0000000e+00, 1.0580653e-08, 0.0000000e+00,
#         0.0000000e+00, 1.0000000e+00, 1.0000000e+00, 0.0000000e+00,
#         1.0000000e+00, 1.0000000e+00]], dtype=float32)

# %%
top_3 = np.argsort(proba[0])[:-4:-1]

# %%
top_3
# Out:
# array([13, 12, 10])

# %%
for genre in top_3:
       print(Genre_ID_to_name[genre_list[genre]])
# Out:
# Mystery
# Science Fiction
# Crime

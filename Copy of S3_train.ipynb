# %%
import pandas as pd

# %%
df1 = pd.read_csv("/content/drive/My Drive/s1_imagevec.csv")
df2 = pd.read_csv("/content/drive/My Drive/s2_imagevec.csv")
df3 = pd.read_csv("/content/drive/My Drive/s3_imagevec.csv")

# %%
len(df1) + len(df2) + len(df3)
# Out:
# 42978

# %%
df = pd.concat([df1,df2,df3])

# %%
len(df)
# Out:
# 42978

# %%
df = df.reset_index()

# %%
df = df.drop("index",axis=1)
#df = df.drop("Unnamed: 0",axis=1)

# %%
df
# Out:
#                                             title  ...                                          image_vec
# 0                     Travis and the Nitro Circus  ...  [0.         0.         0.         ... 0.      ...
# 1                        Robot Chicken: Star Wars  ...  [3.84463906 0.         0.         ... 0.      ...
# 2                      Sense8: Creating the World  ...  [ 0.          0.          0.         ...  0.  ...
# 3                                   North of Nome  ...                            [0. 0. 0. ... 0. 0. 0.]
# 4      SPIT: The Story of a Caveman and a Chicken  ...  [ 0.          0.          0.         ...  0.  ...
# ...                                           ...  ...                                                ...
# 42973                                   Get Lucky  ...                            [0. 0. 0. ... 0. 0. 0.]
# 42974                      Four Frightened People  ...                            [0. 0. 0. ... 0. 0. 0.]
# 42975                                   Iron Will  ...                            [0. 0. 0. ... 0. 0. 0.]
# 42976                                Bran Nue Dae  ...                            [0. 0. 0. ... 0. 0. 0.]
# 42977                            Bhowani Junction  ...  [0.         0.         0.         ... 0.      ...
#
# [42978 rows x 6 columns]

# %%
x1 = df.text_vec[0]

# %%
x1
# Out:
# '[ 0.01052348  0.02272458  0.00019497  0.0603981  -0.06344117 -0.0236045\n  0.00392871 -0.08252165  0.00733439  0.06351471  0.06254663 -0.14575703\n -0.07823351 -0.01396349 -0.0897967   0.09538184  0.01832411  0.13619655\n  0.03719499 -0.06635836  0.00716485  0.0907508   0.02676392 -0.04020521\n -0.03151353 -0.0312856  -0.11835109  0.15606689  0.09237353 -0.06273736\n -0.05698988  0.00401221  0.0284657   0.01394696 -0.01608785 -0.03233846\n  0.09308836 -0.01223161  0.0763056   0.05145152  0.09899054 -0.05457221\n  0.17269558  0.02340868 -0.01353794 -0.02228631  0.01369392  0.00545756\n  0.09555944  0.03665458 -0.04228062  0.00657781 -0.02507867 -0.03108427\n  0.02618239  0.03327666  0.01634078 -0.05045064  0.04330783 -0.09709252\n -0.06230545 -0.0196601  -0.04795668 -0.05325826 -0.00416904 -0.09178967\n  0.01531304  0.08208551 -0.10161124  0.05563948 -0.01563687  0.04180135\n  0.04110463  0.10894818 -0.15515031 -0.04794036  0.08778021 -0.0645557\n -0.01480526 -0.01962037  0.04164463 -0.02875434  0.00803884 -0.01408195\n -0.01907433 -0.08122846 -0.10084619  0.13033506 -0.01087146  0.04664442\n -0.00421821 -0.04525418 -0.02889564 -0.04888408 -0.0199301  -0.01553429\n  0.00481839  0.01470439  0.01536814 -0.0741272   0.01735391  0.03372362\n  0.03488837 -0.01840719 -0.01379691 -0.0079617   0.04398198 -0.09959432\n  0.0654797  -0.04937999 -0.04446326 -0.00168016  0.01476881 -0.01586575\n  0.05462562  0.02071063 -0.05513509  0.00207901  0.01013501 -0.01272609\n -0.06061639 -0.03727849 -0.03849453  0.03464423  0.07754517 -0.04820845\n -0.05796878 -0.02992164 -0.04260127 -0.01035033 -0.06453112 -0.04819107\n -0.04418267 -0.01072862 -0.00966305 -0.02895694  0.0063502   0.01922014\n  0.04229143  0.06189134  0.05279075 -0.04023404  0.0285831  -0.05861812\n  0.09092712  0.06676398 -0.01735094  0.03553941 -0.08420478 -0.0477456\n  0.1149309   0.03363122 -0.06064182  0.00622209 -0.12343004 -0.05991215\n -0.00886112 -0.03698129 -0.10814243 -0.12698704 -0.00687663  0.11914402\n  0.00871362  0.02597798  0.00228373 -0.07072152  0.05432002 -0.06147173\n -0.01672745 -0.01288139 -0.05083211 -0.05640411  0.04393514 -0.03423394\n -0.03064643 -0.05167474  0.01704237 -0.06978522  0.04101393 -0.0338067\n  0.00294325  0.01685969 -0.02497694  0.01939842  0.0237164  -0.05177985\n  0.01813104 -0.0188054   0.11048169  0.06687757  0.08354441  0.0771317\n  0.04684872  0.00331285  0.05556295  0.01650153 -0.01292106  0.01309289\n -0.05532498 -0.12135654  0.06893023  0.06752099 -0.08082581 -0.0514271\n  0.02038913 -0.06706026 -0.03409243  0.00102912 -0.03936937 -0.02021281\n  0.03548686  0.01717038  0.0082762   0.0243242  -0.0563185   0.00080321\n -0.00481839 -0.06319427 -0.07437812 -0.01967833 -0.07371775  0.00322978\n  0.06126065 -0.0221938   0.06164932 -0.02037472  0.02667681  0.04654609\n -0.01944351 -0.01569324  0.04322815 -0.02235582  0.06464132  0.02183702\n  0.03322347  0.01756202  0.07794105 -0.04390886  0.0754759  -0.01058536\n  0.06206841 -0.00874541 -0.0335439  -0.11445703 -0.01068963  0.02510749\n -0.06255349  0.00267548  0.03322516 -0.0965822   0.02674527  0.04308658\n  0.09961955  0.09660254  0.06500837 -0.0464823   0.01066335 -0.02695719\n -0.03347948 -0.11394501 -0.03348711 -0.04077233  0.05957391  0.06159019\n  0.02914143  0.13197793 -0.05369229 -0.03721958 -0.01202647 -0.03310225\n  0.00484763  0.02681478 -0.00171492  0.06311798  0.03731802 -0.10223389\n -0.06253222 -0.08154127 -0.06572851 -0.00372484 -0.01577165  0.00576295\n  0.03730244 -0.01408047  0.01509804 -0.06968345 -0.0662952   0.02631124\n  0.06183963  0.02045356 -0.02075534 -0.01945326 -0.1375334   0.00535838\n -0.02416738 -0.04605908 -0.00255669 -0.01690674 -0.01494768 -0.06438531]'

# %%
import numpy as np

# %%
mystr = '[1 2 3 4 5]'
x=(mystr)

# %%
x.remove("]")

# %%
x
# Out:
# '[1 2 3 4 5]'

# %%
x=np.array(x)

# %%
x
# Out:
# array('[1 2 3 4 5]', dtype='<U11')

# %%
x = str(x).replace("'", "")

# %%
x
# Out:
# '[1 2 3 4 5]'

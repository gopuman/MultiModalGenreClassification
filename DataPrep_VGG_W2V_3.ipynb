# %%
import pandas as pd
df = pd.read_pickle("/content/drive/My Drive/pinky_promise_last.pckl")

# %%
df
# Out:
#                                             title  ...                                          image_vec
# 0                     Travis and the Nitro Circus  ...  [[[[ 0.          0.          0.          0.   ...
# 1                        Robot Chicken: Star Wars  ...  [[[[ 0.          0.          0.          0.   ...
# 2                      Sense8: Creating the World  ...  [[[[ 0.          0.          0.          0.   ...
# 3                                   North of Nome  ...  [[[[ 0.          0.          0.          0.   ...
# 4      SPIT: The Story of a Caveman and a Chicken  ...  [[[[ 0.          0.          0.          0.   ...
# ...                                           ...  ...                                                ...
# 42973                                   Get Lucky  ...  [[[[0.00000000e+00 0.00000000e+00 0.00000000e+...
# 42974                      Four Frightened People  ...  [[[[0.00000000e+00 0.00000000e+00 0.00000000e+...
# 42975                                   Iron Will  ...  [[[[0.00000000e+00 0.00000000e+00 0.00000000e+...
# 42976                                Bran Nue Dae  ...  [[[[0.00000000e+00 0.00000000e+00 0.00000000e+...
# 42977                            Bhowani Junction  ...  [[[[0.00000000e+00 0.00000000e+00 0.00000000e+...
#
# [42978 rows x 6 columns]

# %%
from ast import literal_eval
df.genre_ids=df.genre_ids.apply(literal_eval)

# %%
genres=[]
all_ids=[]
for i in range(len(df)):
    genre_ids=df.genre_ids[i]
    genres.append(genre_ids)
    all_ids.extend(genre_ids)

# %%
len(all_ids)
# Out:
# 90770

# %%
from sklearn.preprocessing import MultiLabelBinarizer
mlb=MultiLabelBinarizer()
Y=mlb.fit_transform(genres)

# %%
Y.shape
# Out:
# (42978, 19)

# %%
x1 = df.text_vec[0]
x2 = df.image_vec[0]

# %%
X = []
for i in range(len(df)):
  X.append(df.image_vec[i])

# %%
b=df.text_vec[0].flatten()

# %%
len(df)
# Out:
# 42978

# %%
a = df.image_vec[0].flatten()

# %%
import numpy as np
a.shape
# Out:
# (25088,)

# %%
X = np.concatenate((a,b),axis=0)

# %%
import numpy as np
a = a.flatten()
b = b.flatten()

# %%
len(X)
# Out:
# 25388

# %%
X.shape
# Out:
# (21490, 25388)

# %%
import numpy as np

for i in range(21489, len(df)):
  x1 = df.text_vec[i].flatten()
  x2 = df.image_vec[i].flatten()
  x3 = np.concatenate((x1,x2),axis=0)
  X = np.vstack((X,x3))
  if i%5000 == 0:
    print("count is ", i)
# Out:
# count is  25000
# count is  30000
# count is  35000
# count is  40000

# %%
import pickle 
f=open("inputvecs2_1.pckl", "wb")
pickle.dump(X_after, f, protocol=4)

# %%
X_real = X

# %%
X_real.shape
# Out:
# (21490, 25388)

# %%
X[0]
# Out:
# array([ 0.        ,  0.        ,  0.        , ..., -0.01690674,
#        -0.01494768, -0.06438531])

# %%
X_after = np.delete(X, 0, 0)

# %%
X_after.shape
# Out:
# (21489, 25388)

# %%
import pandas as pd
df = pd.read_pickle("/content/drive/My Drive/pinky_promise_last.pckl")

# %%
df
# Out:
#                                             title  ...                                          image_vec
# 0                     Travis and the Nitro Circus  ...  [[[[ 0.          0.          0.          0.   ...
# 1                        Robot Chicken: Star Wars  ...  [[[[ 0.          0.          0.          0.   ...
# 2                      Sense8: Creating the World  ...  [[[[ 0.          0.          0.          0.   ...
# 3                                   North of Nome  ...  [[[[ 0.          0.          0.          0.   ...
# 4      SPIT: The Story of a Caveman and a Chicken  ...  [[[[ 0.          0.          0.          0.   ...
# ...                                           ...  ...                                                ...
# 42973                                   Get Lucky  ...  [[[[0.00000000e+00 0.00000000e+00 0.00000000e+...
# 42974                      Four Frightened People  ...  [[[[0.00000000e+00 0.00000000e+00 0.00000000e+...
# 42975                                   Iron Will  ...  [[[[0.00000000e+00 0.00000000e+00 0.00000000e+...
# 42976                                Bran Nue Dae  ...  [[[[0.00000000e+00 0.00000000e+00 0.00000000e+...
# 42977                            Bhowani Junction  ...  [[[[0.00000000e+00 0.00000000e+00 0.00000000e+...
#
# [42978 rows x 6 columns]

# %%
df.text_vec[0].shape
# Out:
# (300,)

# %%
l = df.image_vec.to_list()

# %%
import numpy as np
import pickle
X = np.array([])

# %%
f=open('/content/drive/My Drive/glove_features.pckl','rb')
glove = pickle.load(f)

# %%
g = []
for i in range(len(glove[0])):
  g.append(glove[0][i])

# %%
g[0].shape
# Out:
# (300,)

# %%
df.image_vec[0].flatten().shape
# Out:
# (25088,)

# %%
a = df.image_vec[0].flatten()
b = g[0].flatten()
X = np.concatenate((a,b),axis=0)

# %%
X.shape
# Out:
# (25388,)

# %%
import numpy as np
for i in range(21489, len(df)):
  x1 = g[i].flatten()
  x2 = df.image_vec[i].flatten()
  x3 = np.concatenate((x1,x2),axis=0)
  X = np.vstack((X,x3))
  if i%5000 == 0:
    print("count is ", i)

# %%
len(X)

# %%
X_after = np.delete(X, 0, 0)

# %%
len(X_after)

# %%
X_after.shape

# %%
import pickle 
f=open("glovecombivecs2.pckl", "wb")
pickle.dump(X_after, f, protocol=4)
#pickle.dump(d, open("inputvecs1.pckl", 'w'), protocol=4)

# %%
del X
del X_after

# %%
import pickle

f1 = open("/content/drive/My Drive/glovecombivecs1.pckl","rb")
x1 = pickle.load(f1)

# %%
f2 = open("/content/drive/My Drive/glovecombivecs2.pckl","rb")
x2 = pickle.load(f2)

# %%
del f1
del f2

# %%
import numpy as np
X = np.concatenate((x1,x2),axis=0)

# %%
X.shape
# Out:
# (42978, 25388)

# %%
del x1 
del x2

# %%
import pandas as pd
import pickle
df = pd.read_pickle("/content/drive/My Drive/pinky_promise_last.pckl")

# %%
Y = df.genre_ids.to_list()

# %%
Y
# Out:
# ['[28, 12]',
#  '[16, 35, 878]',
#  '[99, 878]',
#  '[80, 12]',
#  '[35, 12]',
#  '[28, 12, 53]',
#  '[18, 35]',
#  '[16]',
#  '[10402, 80]',
#  '[99]',
#  '[27, 53, 35]',
#  '[28, 80]',
#  '[16, 35, 10751]',
#  '[28, 12, 37]',
#  '[16]',
#  '[16]',
#  '[80, 18]',
#  '[18]',
#  '[16]',
#  '[80, 35]',
#  '[28, 35, 80]',
#  '[99, 12]',
#  '[12]',
#  '[28, 35]',
#  '[18, 9648, 53]',
#  '[28, 18, 36, 10752]',
#  '[28, 12, 35, 878]',
#  '[35, 10751, 16]',
#  '[28, 27, 878]',
#  '[16]',
#  '[18, 28, 80, 10749]',
#  '[35]',
#  '[10751, 16, 14]',
#  '[99]',
#  '[99]',
#  '[12, 16, 99]',
#  '[16]',
#  '[16, 18, 14, 27]',
#  '[28, 37]',
#  '[99]',
#  '[18, 35, 10751]',
#  '[35, 18]',
#  '[28, 80, 53]',
#  '[28, 27]',
#  '[99]',
#  '[28, 35, 9648, 53]',
#  '[35, 10749]',
#  '[28, 35, 80]',
#  '[28, 878]',
#  '[28, 12, 80]',
#  '[35, 10751]',
#  '[18, 99, 10770]',
#  '[99, 10751]',
#  '[28, 53]',
#  '[14, 27, 28, 53]',
#  '[10751, 12]',
#  '[28, 12, 18, 10751, 10770]',
#  '[99]',
#  '[53, 27, 18]',
#  '[18, 36]',
#  '[80, 18, 53]',
#  '[28, 27, 878, 53]',
#  '[35, 10749]',
#  '[99]',
#  '[12, 35, 10749]',
#  '[28, 37]',
#  '[10752, 28]',
#  '[36, 99]',
#  '[28, 80, 53, 35, 18, 10749]',
#  '[35]',
#  '[80, 18]',
#  '[18, 9648, 53]',
#  '[53, 80, 18]',
#  '[99]',
#  '[16]',
#  '[28, 878, 53]',
#  '[99]',
#  '[18, 878, 53]',
#  '[80, 18, 9648, 53]',
#  '[16]',
#  '[99]',
#  '[27, 28, 53]',
#  '[18, 10749]',
#  '[10749, 18, 28, 53]',
#  '[99]',
#  '[99, 10770]',
#  '[28, 27]',
#  '[35, 18, 10749]',
#  '[80, 53]',
#  '[35, 27, 37]',
#  '[12, 35]',
#  '[35, 18]',
#  '[28, 878]',
#  '[28, 37]',
#  '[99]',
#  '[28, 12, 53]',
#  '[16, 10751]',
#  '[16, 10751]',
#  '[16, 35]',
#  '[35, 99]',
#  '[16, 18]',
#  '[28, 18, 53]',
#  '[12, 27]',
#  '[18, 28]',
#  '[35, 878]',
#  '[28, 27, 53, 10770]',
#  '[35, 80, 53]',
#  '[9648, 16]',
#  '[80, 53, 10770]',
#  '[16]',
#  '[35, 18, 10749]',
#  '[35, 10402, 10749]',
#  '[16, 18]',
#  '[28, 12, 16]',
#  '[99]',
#  '[16]',
#  '[99]',
#  '[28, 12, 9648, 10770]',
#  '[28, 35, 37]',
#  '[18]',
#  '[35, 10749]',
#  '[80, 18, 53]',
#  '[99]',
#  '[16, 14, 10749]',
#  '[28, 35, 80, 18, 53]',
#  '[18, 10749]',
#  '[12, 18, 878, 10749]',
#  '[16]',
#  '[18, 10752]',
#  '[18, 10749]',
#  '[878, 35]',
#  '[12, 16, 35, 10751]',
#  '[80, 35, 9648]',
#  '[16, 10751]',
#  '[35, 18, 10751]',
#  '[10402, 99, 36]',
#  '[12, 10751]',
#  '[28, 80, 18, 53]',
#  '[99]',
#  '[12, 99]',
#  '[12, 12, 14]',
#  '[12]',
#  '[80, 18, 9648, 53]',
#  '[99]',
#  '[16, 10751]',
#  '[16]',
#  '[28, 12, 18, 10749]',
#  '[16]',
#  '[10751, 16]',
#  '[18, 80]',
#  '[99]',
#  '[28, 80, 18, 9648, 53]',
#  '[12, 16, 35, 14, 9648, 10751]',
#  '[10770, 12, 35, 10751]',
#  '[35, 18, 10749]',
#  '[35, 18]',
#  '[12]',
#  '[12, 28, 80, 9648]',
#  '[28, 35]',
#  '[53, 80, 9648]',
#  '[28, 80, 18]',
#  '[28, 12, 878, 53]',
#  '[53, 28, 12]',
#  '[28, 18, 37]',
#  '[16, 14, 10751]',
#  '[28, 35, 37, 10749]',
#  '[16, 99, 10752]',
#  '[14, 16, 28, 27]',
#  '[12, 35, 80, 10751]',
#  '[10402, 16, 18, 10751]',
#  '[28, 12, 878]',
#  '[80, 18]',
#  '[28, 12, 53]',
#  '[99]',
#  '[80, 18, 10749]',
#  '[16, 35, 10751]',
#  '[99]',
#  '[35, 10770]',
#  '[28, 53]',
#  '[80]',
#  '[16, 35, 27, 53, 10751]',
#  '[99]',
#  '[80, 18, 9648]',
#  '[10402, 99]',
#  '[28, 27, 18, 53]',
#  '[80, 18, 10749]',
#  '[80, 35]',
#  '[99]',
#  '[16]',
#  '[80, 18]',
#  '[35]',
#  '[99]',
#  '[99]',
#  '[99]',
#  '[35, 27]',
#  '[28, 53, 80, 18]',
#  '[80, 18, 10770]',
#  '[35, 10749]',
#  '[12, 10749]',
#  '[35, 10749]',
#  '[35]',
#  '[35, 80, 53]',
#  '[18, 53]',
#  '[35, 28, 12]',
#  '[28, 18]',
#  '[28]',
#  '[80, 53]',
#  '[35]',
#  '[10770, 80, 18, 53]',
#  '[16]',
#  '[35, 99]',
#  '[12, 18, 14]',
#  '[99]',
#  '[35, 10749]',
#  '[12, 14]',
#  '[35]',
#  '[18]',
#  '[99]',
#  '[28, 12, 14]',
#  '[18, 36, 10749]',
#  '[35, 10749, 37]',
#  '[35, 27]',
#  '[18, 10749, 80]',
#  '[16, 35, 9648, 10751]',
#  '[18, 10770, 35]',
#  '[28, 80, 878, 53]',
#  '[18, 16, 27]',
#  '[35, 12]',
#  '[28, 27, 53]',
#  '[28, 80, 27, 53]',
#  '[35, 18]',
#  '[28, 12, 27, 53]',
#  '[80, 18]',
#  '[16]',
#  '[16, 10751]',
#  '[28, 35]',
#  '[99]',
#  '[99]',
#  '[80, 18, 53]',
#  '[16]',
#  '[35, 10402, 10752]',
#  '[99]',
#  '[99]',
#  '[35, 10749]',
#  '[99]',
#  '[18, 28, 53, 80]',
#  '[99]',
#  '[99]',
#  '[35, 18]',
#  '[99, 35, 36]',
#  '[80, 18]',
#  '[99]',
#  '[12]',
#  '[28, 35, 10751]',
#  '[10749, 28]',
#  '[99, 10402, 10770]',
#  '[28, 12, 35, 14, 10751]',
#  '[35]',
#  '[18, 36, 10402]',
#  '[12, 18]',
#  '[99]',
#  '[16, 10751]',
#  '[28, 35, 878]',
#  '[35, 878, 10751]',
#  '[12]',
#  '[35, 10402, 10749]',
#  '[12, 16, 35, 14, 10751]',
#  '[80]',
#  '[80, 18]',
#  '[35, 18]',
#  '[99]',
#  '[35, 14, 27]',
#  '[35, 18, 10749]',
#  '[80, 18, 9648]',
#  '[18, 99]',
#  '[99]',
#  '[28, 14]',
#  '[12, 53]',
#  '[35, 18, 10749]',
#  '[16, 18]',
#  '[99]',
#  '[16]',
#  '[12, 28]',
#  '[99, 36]',
#  '[36, 10749, 10752, 18]',
#  '[99, 10402]',
#  '[28, 12, 878]',
#  '[28, 35, 10749]',
#  '[28, 12, 53]',
#  '[18, 10749]',
#  '[28, 53, 878]',
#  '[10751, 35]',
#  '[99]',
#  '[16, 35, 9648, 10751]',
#  '[99, 18]',
#  '[35, 12]',
#  '[18, 10749]',
#  '[80, 18, 53]',
#  '[99]',
#  '[35, 80, 10402]',
#  '[12, 10751]',
#  '[80, 27, 9648, 10770]',
#  '[28, 12, 18, 10751]',
#  '[28]',
#  '[28, 12, 35]',
#  '[9648, 28, 12, 27]',
#  '[28, 12, 53]',
#  '[35, 18]',
#  '[12, 16, 35, 10751]',
#  '[12]',
#  '[18, 14, 10749]',
#  '[10751, 16]',
#  '[16]',
#  '[28, 18, 37]',
#  '[99]',
#  '[18]',
#  '[16, 10402]',
#  '[99]',
#  '[28, 35, 53]',
#  '[80, 53]',
#  '[36, 18, 28, 37]',
#  '[28, 12, 36, 27]',
#  '[16, 14, 10751]',
#  '[28, 12, 18, 10749, 53]',
#  '[28, 80, 53]',
#  '[28]',
#  '[16, 35, 14, 10751]',
#  '[28, 35]',
#  '[18]',
#  '[99]',
#  '[18, 12]',
#  '[35, 10749, 10770]',
#  '[16]',
#  '[80, 53, 18, 27]',
#  '[35, 27]',
#  '[99, 18, 10751]',
#  '[99]',
#  '[16, 10751]',
#  '[35, 10749]',
#  '[80]',
#  '[16, 36]',
#  '[99]',
#  '[80]',
#  '[28, 12, 878, 53]',
#  '[12, 18, 10749]',
#  '[35]',
#  '[99]',
#  '[12, 18]',
#  '[28, 12, 80, 53]',
#  '[35, 10749]',
#  '[18, 10752]',
#  '[27, 9648, 53, 80]',
#  '[12, 35, 18, 878]',
#  '[18, 53, 9648]',
#  '[14, 10751, 12]',
#  '[35, 18, 10749]',
#  '[18, 10402]',
#  '[35, 27, 878]',
#  '[99]',
#  '[28, 80]',
#  '[16]',
#  '[28, 37]',
#  '[99]',
#  '[35, 18, 10749]',
#  '[80, 35]',
#  '[12, 10751]',
#  '[28, 12, 10751]',
#  '[35, 18, 14, 10749]',
#  '[12, 18, 14]',
#  '[12, 18]',
#  '[28, 16, 878]',
#  '[99]',
#  '[99]',
#  '[28, 35]',
#  '[12, 16, 35, 10751]',
#  '[18, 9648, 53, 80]',
#  '[99]',
#  '[10752, 35]',
#  '[28]',
#  '[18]',
#  '[99]',
#  '[35, 18, 14]',
#  '[18, 53]',
#  '[12]',
#  '[99, 10402]',
#  '[18]',
#  '[99]',
#  '[16, 10751]',
#  '[99]',
#  '[99]',
#  '[28, 12, 35, 10751]',
#  '[28, 12, 14, 10751]',
#  '[12, 16, 10751]',
#  '[28, 16, 878]',
#  '[99]',
#  '[18]',
#  '[18, 53]',
#  '[28, 27]',
#  '[28, 18, 36]',
#  '[99]',
#  '[28, 18, 27, 878, 53]',
#  '[28, 878, 53, 10770]',
#  '[28, 12, 18, 10749]',
#  '[18, 80]',
#  '[12, 18, 10751, 878]',
#  '[18, 35, 10749]',
#  '[35]',
#  '[10770, 9648, 80, 18]',
#  '[99, 10402, 36]',
#  '[35, 27]',
#  '[99]',
#  '[28]',
#  '[37, 28]',
#  '[99]',
#  '[27, 35, 10749]',
#  '[80, 18, 53]',
#  '[28, 37]',
#  '[99]',
#  '[35, 10751, 10770]',
#  '[28, 53]',
#  '[35, 10749, 10770]',
#  '[28, 12, 878, 53]',
#  '[28]',
#  '[12, 35]',
#  '[12, 10752, 28]',
#  '[35]',
#  '[10751, 16]',
#  '[10751, 16, 27, 35]',
#  '[35]',
#  '[27, 28, 53]',
#  '[35]',
#  '[28, 12]',
#  '[35, 10749]',
#  '[80, 9648, 53]',
#  '[28, 27, 878]',
#  '[99]',
#  '[16]',
#  '[35]',
#  '[99]',
#  '[28, 18, 53]',
#  '[10751, 16, 10770, 12, 18]',
#  '[80, 18, 10749]',
#  '[18, 80]',
#  '[80, 18, 53]',
#  '[53, 28]',
#  '[28, 35, 10749]',
#  '[16, 35, 10751]',
#  '[18, 10749]',
#  '[12, 18, 10749]',
#  '[99, 18]',
#  '[12, 16, 10751]',
#  '[35, 10751]',
#  '[35, 16]',
#  '[878, 16, 35]',
#  '[16]',
#  '[18, 878, 53]',
#  '[12, 14]',
#  '[10770, 12, 10402, 14]',
#  '[99, 10770]',
#  '[99]',
#  '[35]',
#  '[35, 18]',
#  '[80, 18, 53]',
#  '[99]',
#  '[28, 12, 16, 35]',
#  '[99]',
#  '[80, 18]',
#  '[28, 35]',
#  '[12, 35, 14, 10751]',
#  '[99, 10402]',
#  '[28, 35]',
#  '[99]',
#  '[99]',
#  '[28, 12, 16, 878]',
#  '[35, 18, 10749]',
#  '[18, 27, 53]',
#  '[9648, 53, 27, 80]',
#  '[28, 35, 37]',
#  '[35, 27]',
#  '[12, 16, 10751]',
#  '[99]',
#  '[878, 28]',
#  '[28, 18, 36, 53]',
#  '[35, 27]',
#  '[28, 18]',
#  '[80, 18, 53]',
#  '[28, 80]',
#  '[12, 16, 14, 10751]',
#  '[80, 18]',
#  '[28, 878, 53]',
#  '[28, 12, 14]',
#  '[35, 80]',
#  '[99]',
#  '[35, 18]',
#  '[28, 12, 99]',
#  '[18, 28, 12]',
#  '[10751, 16]',
#  '[28, 18, 53]',
#  '[35, 27, 10749]',
#  '[99]',
#  '[80, 28]',
#  '[28, 80, 18, 53]',
#  '[99, 10402]',
#  '[12, 35, 878]',
#  '[99]',
#  '[18, 53]',
#  '[35, 878]',
#  '[10770, 18, 28]',
#  '[14, 99]',
#  '[12, 878]',
#  '[80, 27]',
#  '[80, 18, 53]',
#  '[35, 80]',
#  '[12, 35, 18]',
#  '[99, 80, 18]',
#  '[28, 12, 18, 53]',
#  '[28, 12, 878]',
#  '[80, 53]',
#  '[10402, 99]',
#  '[12]',
#  '[18, 36, 10752]',
#  '[28, 80, 10752, 53, 27]',
#  '[99]',
#  '[35, 80, 18, 9648, 53]',
#  '[18, 9648, 10749]',
#  '[80, 18, 9648]',
#  '[80]',
#  '[18, 80]',
#  '[80]',
#  '[12, 16, 18]',
#  '[28, 80, 53]',
#  '[18, 10770, 80, 53]',
#  '[28, 12, 18, 10752]',
#  '[36, 99]',
#  '[80, 9648, 18]',
#  '[35, 10751]',
#  '[28, 80, 53]',
#  '[18, 10751]',
#  '[28, 12, 53]',
#  '[28, 18, 53]',
#  '[35, 10749]',
#  '[80, 18, 27]',
#  '[16, 80, 99]',
#  '[16, 14, 10751]',
#  '[35, 12]',
#  '[80, 27]',
#  '[16]',
#  '[28, 12, 878]',
#  '[18, 10749]',
#  '[80, 18, 27]',
#  '[18, 53, 80]',
#  '[35, 27]',
#  '[28, 12, 35, 18]',
#  '[37, 10402, 28, 12]',
#  '[12, 16, 10751]',
#  '[80, 18, 9648, 53]',
#  '[28, 18, 53]',
#  '[99]',
#  '[18, 16]',
#  '[53, 80]',
#  '[28, 878, 53]',
#  '[99]',
#  '[16]',
#  '[16, 35, 10751]',
#  '[18, 53]',
#  '[80, 28]',
#  '[28, 80, 18, 53]',
#  '[16, 35, 878]',
#  '[99, 10402]',
#  '[35, 10749]',
#  '[12, 28, 53, 878]',
#  '[99]',
#  '[18, 53]',
#  '[28, 37]',
#  '[18]',
#  '[28, 80, 18]',
#  '[99]',
#  '[16, 12, 10751]',
#  '[28, 18]',
#  '[99]',
#  '[28, 35, 53]',
#  '[35]',
#  '[10402, 99, 16]',
#  '[28, 80, 10749]',
#  '[35, 27]',
#  '[53, 18, 80]',
#  '[28, 878]',
#  '[878, 18, 27, 9648]',
#  '[12]',
#  '[28, 35, 80, 18]',
#  '[80, 18, 9648, 10770]',
#  '[18, 80]',
#  '[99]',
#  '[10749, 28, 12, 37, 10402]',
#  '[28, 12, 18, 37]',
#  '[99]',
#  '[16, 27]',
#  '[80, 28, 35]',
#  '[80, 18]',
#  '[35, 18]',
#  '[35, 18, 10749]',
#  '[35]',
#  '[99]',
#  '[35]',
#  '[28, 53, 12]',
#  '[80, 18, 53]',
#  '[16]',
#  '[12, 10751]',
#  '[12, 14]',
#  '[14, 18, 35, 10749]',
#  '[80, 53]',
#  '[80, 18, 53]',
#  '[10770, 16, 12, 10751]',
#  '[99]',
#  '[16, 35]',
#  '[18, 99]',
#  '[35, 18, 10749]',
#  '[10749, 35]',
#  '[99]',
#  '[35, 18]',
#  '[28, 80, 53]',
#  '[99, 36]',
#  '[99]',
#  '[28, 12, 878]',
#  '[99]',
#  '[28, 27, 878, 53]',
#  '[99]',
#  '[16]',
#  '[28, 12, 18, 10751]',
#  '[35]',
#  '[16]',
#  '[16, 35, 10751]',
#  '[16]',
#  '[28, 37]',
#  '[36, 12]',
#  '[35, 10749]',
#  '[18, 28, 53, 878]',
#  '[35, 14]',
#  '[12, 18, 14, 878]',
#  '[28, 35, 80, 16]',
#  '[35, 18, 10402, 10749]',
#  '[12, 10751]',
#  '[99]',
#  '[35]',
#  '[16, 18]',
#  '[99]',
#  '[99]',
#  '[28, 12, 53]',
#  '[80, 53]',
#  '[18, 878, 53]',
#  '[99]',
#  '[35, 16]',
#  '[99]',
#  '[28, 36, 18]',
#  '[10770, 35, 12]',
#  '[18, 10402]',
#  '[28, 12, 878, 53]',
#  '[28, 53, 10752]',
#  '[28, 14, 878]',
#  '[12, 99]',
#  '[35, 18]',
#  '[28, 878, 80]',
#  '[10751, 35, 14, 12]',
#  '[99]',
#  '[35, 10749]',
#  '[35, 18, 10749]',
#  '[28, 27, 878]',
#  '[80]',
#  '[16]',
#  '[18]',
#  '[35, 18]',
#  '[28, 18, 10752]',
#  '[80]',
#  '[16, 35]',
#  '[12, 99, 18, 36]',
#  '[35, 10402]',
#  '[18, 12, 10749]',
#  '[35, 18]',
#  '[27, 16]',
#  '[99]',
#  '[27, 35]',
#  '[28, 35, 9648]',
#  '[35, 99]',
#  '[99]',
#  '[16, 35]',
#  '[28, 35, 80]',
#  '[28, 12]',
#  '[28, 9648, 53]',
#  '[12, 16, 35, 18, 10402, 10751]',
#  '[28, 80, 28]',
#  '[80, 18, 53]',
#  '[99]',
#  '[10402, 35]',
#  '[16]',
#  '[99]',
#  '[35, 80]',
#  '[28, 80, 9648, 53]',
#  '[18, 10749]',
#  '[28, 35]',
#  '[28]',
#  '[80, 27, 9648, 53]',
#  '[35, 10402, 10749]',
#  '[12, 10751]',
#  '[80, 9648]',
#  '[18]',
#  '[99]',
#  '[80]',
#  '[99, 10402]',
#  '[16]',
#  '[18, 35]',
#  '[36, 99]',
#  '[14, 35]',
#  '[53, 28, 18]',
#  '[28]',
#  '[99]',
#  '[878, 16]',
#  '[99]',
#  '[12]',
#  '[99]',
#  '[12, 35, 878, 10751]',
#  '[80, 18, 53]',
#  '[35]',
#  '[99, 10402, 14]',
#  '[99, 12]',
#  '[16, 35, 10751]',
#  '[28, 37, 80, 18]',
#  '[28, 35, 80, 10749]',
#  '[35, 18, 10749]',
#  '[18, 36]',
#  '[12, 28]',
#  '[18, 53]',
#  '[28, 12, 878]',
#  '[18, 36]',
#  '[35, 80, 9648]',
#  '[80, 18, 10749]',
#  '[35, 10749]',
#  '[35, 18]',
#  '[35, 9648, 53, 10749]',
#  '[12, 18, 36]',
#  '[99]',
#  '[28]',
#  '[35, 18, 878, 53, 10749]',
#  '[80]',
#  '[16]',
#  '[28, 80, 18, 53]',
#  '[16, 10751, 10402]',
#  '[35]',
#  '[28, 80, 9648, 53]',
#  '[28, 18, 53]',
#  '[28, 53, 878, 9648]',
#  '[35, 53]',
#  '[35, 27]',
#  '[99]',
#  '[16]',
#  '[99]',
#  '[16, 35]',
#  '[35, 27, 10749]',
#  '[28, 18, 10770]',
#  '[18]',
#  '[28, 12, 16, 14, 10751]',
#  '[80, 18, 9648]',
#  '[35, 80, 18]',
#  '[80, 27]',
#  '[18, 14, 878, 10749]',
#  '[16, 35, 14, 10402]',
#  '[99]',
#  '[80, 35, 28]',
#  '[28, 53]',
#  '[28, 16, 35, 14, 10751]',
#  '[28]',
#  '[35, 27, 9648]',
#  '[18, 28, 37, 36]',
#  '[28, 12, 18, 37]',
#  '[18, 99]',
#  '[28]',
#  '[18, 27, 9648, 53]',
#  '[99]',
#  '[35]',
#  '[99]',
#  '[18, 80, 9648, 35]',
#  '[28]',
#  '[99]',
#  '[12, 35]',
#  '[18, 53]',
#  '[99]',
#  '[28, 35, 18, 10749]',
#  '[35, 80, 9648]',
#  '[27, 16, 878]',
#  '[35, 18, 10749]',
#  '[35]',
#  '[35, 10749, 18]',
#  '[35, 10749]',
#  '[18, 35]',
#  '[18, 10751]',
#  '[16]',
#  '[80, 53]',
#  '[99, 36]',
#  '[28, 35]',
#  '[99]',
#  '[28, 18, 53]',
#  '[99]',
#  '[28, 35, 10751]',
#  '[35, 80, 27]',
#  '[35]',
#  '[28, 35, 18, 10751]',
#  '[14, 28, 12]',
#  '[10402, 99]',
#  '[28, 35, 37]',
#  '[12, 18, 53]',
#  '[16]',
#  '[53, 80, 18]',
#  '[12, 16, 35, 10751]',
#  '[35]',
#  '[35, 10749]',
#  '[99]',
#  '[28, 37]',
#  '[16]',
#  '[28, 53]',
#  '[80, 18, 9648]',
#  '[99]',
#  '[12, 35]',
#  '[10770, 35, 18, 10751]',
#  '[35, 18, 10749]',
#  '[28, 18, 35, 80]',
#  '[99, 36]',
#  '[28, 27, 878]',
#  '[16, 10751]',
#  '[99, 10402]',
#  '[99]',
#  '[28, 53]',
#  '[80, 18]',
#  '[18]',
#  '[18, 35]',
#  '[878, 28, 18]',
#  '[53, 12, 27]',
#  '[80]',
#  '[28, 12, 53]',
#  '[16, 10751]',
#  '[80]',
#  '[18, 36, 53]',
#  '[28, 12, 35, 80, 53]',
#  '[27, 35, 18, 53, 14]',
#  '[28, 53]',
#  '[99]',
#  '[80, 9648]',
#  '[28]',
#  '[12, 16, 10751]',
#  '[80, 18]',
#  '[35, 10402]',
#  '[18, 12, 35, 10751]',
#  '[99]',
#  '[18, 27]',
#  '[80, 27, 53]',
#  '[16, 35, 14]',
#  '[18, 35, 80]',
#  '[99]',
#  '[35]',
#  '[35, 10749, 10402]',
#  '[28, 12, 18, 10751]',
#  '[80, 18]',
#  '[18, 27, 9648, 878, 53]',
#  '[35, 80]',
#  '[28, 80]',
#  '[16]',
#  '[99]',
#  '[28, 16, 878, 10751]',
#  '[35, 80]',
#  '[28, 12, 878, 53]',
#  '[18, 80, 10770]',
#  '[28, 80, 53]',
#  '[35, 80, 18, 14, 9648, 53]',
#  '[10751, 16]',
#  '[99, 10402]',
#  '[99]',
#  '[99, 12]',
#  '[28, 12, 35, 14, 10751]',
#  '[35, 18, 10749]',
#  '[18, 28]',
#  '[14, 35, 10402, 27, 878]',
#  '[99]',
#  '[99]',
#  '[18, 36, 10752]',
#  '[35, 18, 10749]',
#  '[28, 12]',
#  '[12, 14]',
#  '[35, 27, 878]',
#  '[28, 80]',
#  '[28, 18, 9648]',
#  '[18, 9648, 878]',
#  '[35, 80, 18]',
#  '[99, 80, 16]',
#  '[16]',
#  '[99]',
#  '[9648, 80, 53, 878, 27]',
#  '[28]',
#  '[10749, 9648, 16]',
#  '[28, 12, 10749]',
#  '[99]',
#  '[16]',
#  '[35, 10749, 53]',
#  '[28, 37]',
#  '[35, 28, 18]',
#  '[16]',
#  '[12, 18, 37]',
#  '[80, 18]',
#  '[28, 12, 35]',
#  '[80]',
#  '[80, 878]',
#  '[28]',
#  '[12, 18]',
#  '[10751, 12, 14]',
#  '[99]',
#  '[80]',
#  '[35, 18]',
#  '[18, 9648, 80]',
#  '[28, 18]',
#  '[16, 10751]',
#  '[99]',
#  '[18, 10749]',
#  '[35]',
#  '[99]',
#  '[35, 27, 878]',
#  '[12, 14, 878]',
#  '[12, 10749]',
#  '[35, 18, 10749]',
#  '[10402, 99]',
#  '[80, 28, 35]',
#  '[99]',
#  '[28, 12, 35]',
#  '[35]',
#  '[28, 12, 878]',
#  '[99]',
#  '[80, 18, 9648, 53, 10770]',
#  '[99]',
#  '[28, 80, 35, 53]',
#  '[53, 10770, 80, 9648]',
#  '[10751, 16]',
#  '[35, 14, 27]',
#  '[12, 18, 10749]',
#  '[35, 18, 10749]',
#  '[99]',
#  '[99, 16]',
#  '[80]',
#  '[16]',
#  '[28, 53]',
#  '[99]',
#  '[35, 10402, 10749]',
#  '[35, 18]',
#  '[28, 12, 53]',
#  '[10402, 99]',
#  '[80]',
#  '[16, 35]',
#  '[35]',
#  '[12, 16, 10751]',
#  '[36, 28, 12, 18]',
#  '[12, 99]',
#  '[28, 12, 878]',
#  '[18]',
#  '[35, 80, 18, 53]',
#  '[12, 16, 35, 10751]',
#  '[12, 10751]',
#  '[99]',
#  '[16, 10770, 35]',
#  '[28]',
#  '[28, 37]',
#  '[99]',
#  '[12, 16, 35, 10751]',
#  '[28, 18]',
#  '[28, 18, 36, 37]',
#  '[35]',
#  '[28, 12, 14]',
#  '[10402, 16]',
#  '[99]',
#  '[16, 35, 878]',
#  '[28, 12, 14]',
#  '[28, 12, 35, 14, 878]',
#  '[99]',
#  '[12]',
#  '[28, 53]',
#  '[35, 18, 10751, 10770]',
#  '[80, 18, 12]',
#  '[10749, 35, 18]',
#  '[16]',
#  '[16]',
#  '[28, 27, 878]',
#  '[80, 18, 9648]',
#  '[80, 53]',
#  '[35, 27]',
#  '[99]',
#  '[28, 12, 18]',
#  '[28, 80]',
#  '[35, 18]',
#  '[80, 53]',
#  '[16]',
#  '[28, 12, 16, 35, 878]',
#  '[18]',
#  '[99]',
#  '[35, 16]',
#  '[16]',
#  '[99]',
#  ...]

# %%
mask = np.random.rand(len(X)) < 0.8

# %%
from sklearn.preprocessing import MultiLabelBinarizer
mlb=MultiLabelBinarizer()
Y=mlb.fit_transform(Y)

Y.shape
# Out:
# (42978, 14)

# %%
X_train=X[mask]
X_test=X[~mask]
Y_train=Y[mask]
Y_test=Y[~mask]

# %%
dir()
# Out:
# ['In',
#  'MultiLabelBinarizer',
#  'Out',
#  'X',
#  'X_test',
#  'X_train',
#  'Y',
#  'Y_test',
#  'Y_train',
#  '_',
#  '_11',
#  '_17',
#  '_2',
#  '_21',
#  '_23',
#  '_3',
#  '_8',
#  '_9',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i2',
#  '_i20',
#  '_i21',
#  '_i22',
#  '_i23',
#  '_i24',
#  '_i25',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  '_sh',
#  'a',
#  'b',
#  'df',
#  'exit',
#  'f',
#  'g',
#  'get_ipython',
#  'glove',
#  'i',
#  'l',
#  'mask',
#  'mlb',
#  'np',
#  'pd',
#  'pickle',
#  'quit',
#  'x3']

# %%
del df
del mlb
del Y
del pickle
del np 
del pd
del X
del MultiLabelBinarizer

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras import optimizers
model_visual = Sequential([
    Dense(1024, input_shape=(25388,)),
    Activation('relu'),
    Dense(256),
    Activation('relu'),
    Dense(14),
    Activation('sigmoid'),
])
opt = optimizers.rmsprop(lr=0.0001, decay=1e-6)

#sgd = optimizers.SGD(lr=0.05, decay=1e-6, momentum=0.4, nesterov=False)
model_visual.compile(optimizer=opt,
              loss='binary_crossentropy',
              metrics=['accuracy'])
# Out:
# Using TensorFlow backend.

# %%
model_visual.fit(X_train, Y_train, epochs=150, batch_size=64,verbose=1)
# Out:
# Epoch 1/150
# 34315/34315 [==============================] - 105s 3ms/step - loss: 1.1761 - accuracy: 0.6258
# Epoch 2/150
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.6265 - accuracy: 0.6476
# Epoch 3/150
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.5782 - accuracy: 0.6635
# Epoch 4/150
# 34315/34315 [==============================] - 105s 3ms/step - loss: 0.5643 - accuracy: 0.6705
# Epoch 5/150
# 34315/34315 [==============================] - 105s 3ms/step - loss: 0.5595 - accuracy: 0.6737
# Epoch 6/150
# 34315/34315 [==============================] - 105s 3ms/step - loss: 0.5564 - accuracy: 0.6775
# Epoch 7/150
# 34315/34315 [==============================] - 106s 3ms/step - loss: 0.5544 - accuracy: 0.6785
# Epoch 8/150
# 34315/34315 [==============================] - 105s 3ms/step - loss: 0.5537 - accuracy: 0.6798
# Epoch 9/150
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.5521 - accuracy: 0.6818
# Epoch 10/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.5510 - accuracy: 0.6833
# Epoch 11/150
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.5509 - accuracy: 0.6835
# Epoch 12/150
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.5495 - accuracy: 0.6852
# Epoch 13/150
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.5490 - accuracy: 0.6856
# Epoch 14/150
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.5476 - accuracy: 0.6872
# Epoch 15/150
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.5468 - accuracy: 0.6881
# Epoch 16/150
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.5465 - accuracy: 0.6883
# Epoch 17/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.5455 - accuracy: 0.6897
# Epoch 18/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.5453 - accuracy: 0.6898
# Epoch 19/150
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.5441 - accuracy: 0.6903
# Epoch 20/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.5439 - accuracy: 0.6918
# Epoch 21/150
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.5426 - accuracy: 0.6927
# Epoch 22/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.5426 - accuracy: 0.6933
# Epoch 23/150
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.5420 - accuracy: 0.6936
# Epoch 24/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.5414 - accuracy: 0.6939
# Epoch 25/150
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.5407 - accuracy: 0.6951
# Epoch 26/150
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.5390 - accuracy: 0.6973
# Epoch 27/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.5378 - accuracy: 0.6987
# Epoch 28/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.5368 - accuracy: 0.6990
# Epoch 29/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.5357 - accuracy: 0.7000
# Epoch 30/150
# 34315/34315 [==============================] - 105s 3ms/step - loss: 0.5352 - accuracy: 0.7008
# Epoch 31/150
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.5343 - accuracy: 0.7012
# Epoch 32/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.5333 - accuracy: 0.7030
# Epoch 33/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.5328 - accuracy: 0.7034
# Epoch 34/150
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.5320 - accuracy: 0.7042
# Epoch 35/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.5313 - accuracy: 0.7046
# Epoch 36/150
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.5310 - accuracy: 0.7048
# Epoch 37/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.5302 - accuracy: 0.7059
# Epoch 38/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.5301 - accuracy: 0.7063
# Epoch 39/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.5298 - accuracy: 0.7072
# Epoch 40/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.5295 - accuracy: 0.7070
# Epoch 41/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.5279 - accuracy: 0.7084
# Epoch 42/150
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.5266 - accuracy: 0.7098
# Epoch 43/150
# 34315/34315 [==============================] - 105s 3ms/step - loss: 0.5268 - accuracy: 0.7093
# Epoch 44/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.5266 - accuracy: 0.7097
# Epoch 45/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.5262 - accuracy: 0.7101
# Epoch 46/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.5252 - accuracy: 0.7113
# Epoch 47/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.5247 - accuracy: 0.7112
# Epoch 48/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.5241 - accuracy: 0.7117
# Epoch 49/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.5237 - accuracy: 0.7125
# Epoch 50/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.5231 - accuracy: 0.7129
# Epoch 51/150
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.5228 - accuracy: 0.7131
# Epoch 52/150
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.5222 - accuracy: 0.7137
# Epoch 53/150
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.5222 - accuracy: 0.7137
# Epoch 54/150
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.5221 - accuracy: 0.7137
# Epoch 55/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.5214 - accuracy: 0.7147
# Epoch 56/150
# 34315/34315 [==============================] - 105s 3ms/step - loss: 0.5203 - accuracy: 0.7156
# Epoch 57/150
# 34315/34315 [==============================] - 105s 3ms/step - loss: 0.5204 - accuracy: 0.7155
# Epoch 58/150
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.5199 - accuracy: 0.7156
# Epoch 59/150
# 34315/34315 [==============================] - 105s 3ms/step - loss: 0.5195 - accuracy: 0.7157
# Epoch 60/150
# 34315/34315 [==============================] - 105s 3ms/step - loss: 0.5192 - accuracy: 0.7160
# Epoch 61/150
# 34315/34315 [==============================] - 105s 3ms/step - loss: 0.5183 - accuracy: 0.7172
# Epoch 62/150
# 34315/34315 [==============================] - 105s 3ms/step - loss: 0.5177 - accuracy: 0.7175
# Epoch 63/150
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.5186 - accuracy: 0.7171
# Epoch 64/150
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.5175 - accuracy: 0.7188
# Epoch 65/150
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.5174 - accuracy: 0.7176
# Epoch 66/150
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.5173 - accuracy: 0.7183
# Epoch 67/150
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.5171 - accuracy: 0.7184
# Epoch 68/150
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.5163 - accuracy: 0.7187
# Epoch 69/150
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.5162 - accuracy: 0.7190
# Epoch 70/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.5165 - accuracy: 0.7187
# Epoch 71/150
# 34315/34315 [==============================] - 102s 3ms/step - loss: 0.5149 - accuracy: 0.7201
# Epoch 72/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.5149 - accuracy: 0.7211
# Epoch 73/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.5152 - accuracy: 0.7202
# Epoch 74/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.5142 - accuracy: 0.7213
# Epoch 75/150
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.5139 - accuracy: 0.7213
# Epoch 76/150
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.5133 - accuracy: 0.7222
# Epoch 77/150
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.5138 - accuracy: 0.7217
# Epoch 78/150
# 34315/34315 [==============================] - 105s 3ms/step - loss: 0.5129 - accuracy: 0.7227
# Epoch 79/150
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.5132 - accuracy: 0.7222
# Epoch 80/150
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.5123 - accuracy: 0.7225
# Epoch 81/150
# 34315/34315 [==============================] - 105s 3ms/step - loss: 0.5121 - accuracy: 0.7235
# Epoch 82/150
# 34315/34315 [==============================] - 105s 3ms/step - loss: 0.5124 - accuracy: 0.7227
# Epoch 83/150
# 34315/34315 [==============================] - 107s 3ms/step - loss: 0.5111 - accuracy: 0.7239
# Epoch 84/150
# 34315/34315 [==============================] - 105s 3ms/step - loss: 0.5116 - accuracy: 0.7236
# Epoch 85/150
# 34315/34315 [==============================] - 106s 3ms/step - loss: 0.5108 - accuracy: 0.7244
# Epoch 86/150
# 34315/34315 [==============================] - 107s 3ms/step - loss: 0.5103 - accuracy: 0.7244
# Epoch 87/150
# 34315/34315 [==============================] - 106s 3ms/step - loss: 0.5105 - accuracy: 0.7254
# Epoch 88/150
# 34315/34315 [==============================] - 106s 3ms/step - loss: 0.5100 - accuracy: 0.7252
# Epoch 89/150
# 34315/34315 [==============================] - 105s 3ms/step - loss: 0.5094 - accuracy: 0.7253
# Epoch 90/150
# 34315/34315 [==============================] - 106s 3ms/step - loss: 0.5095 - accuracy: 0.7256
# Epoch 91/150
# 34315/34315 [==============================] - 105s 3ms/step - loss: 0.5086 - accuracy: 0.7261
# Epoch 92/150
# 34315/34315 [==============================] - 105s 3ms/step - loss: 0.5093 - accuracy: 0.7259
# Epoch 93/150
# 34315/34315 [==============================] - 106s 3ms/step - loss: 0.5088 - accuracy: 0.7263
# Epoch 94/150
# 34315/34315 [==============================] - 106s 3ms/step - loss: 0.5075 - accuracy: 0.7272
# Epoch 95/150
# 34315/34315 [==============================] - 107s 3ms/step - loss: 0.5084 - accuracy: 0.7266
# Epoch 96/150
# 34315/34315 [==============================] - 106s 3ms/step - loss: 0.5079 - accuracy: 0.7270
# Epoch 97/150
# 34315/34315 [==============================] - 107s 3ms/step - loss: 0.5080 - accuracy: 0.7270
# Epoch 98/150
# 34315/34315 [==============================] - 105s 3ms/step - loss: 0.5078 - accuracy: 0.7270
# Epoch 99/150
# 34315/34315 [==============================] - 105s 3ms/step - loss: 0.5075 - accuracy: 0.7275
# Epoch 100/150
# 34315/34315 [==============================] - 106s 3ms/step - loss: 0.5068 - accuracy: 0.7276
# Epoch 101/150
# 34315/34315 [==============================] - 108s 3ms/step - loss: 0.5069 - accuracy: 0.7274
# Epoch 102/150
# 34315/34315 [==============================] - 106s 3ms/step - loss: 0.5060 - accuracy: 0.7278
# Epoch 103/150
# 34315/34315 [==============================] - 108s 3ms/step - loss: 0.5059 - accuracy: 0.7284
# Epoch 104/150
# 34315/34315 [==============================] - 107s 3ms/step - loss: 0.5060 - accuracy: 0.7288
# Epoch 105/150
# 34315/34315 [==============================] - 106s 3ms/step - loss: 0.5065 - accuracy: 0.7282
# Epoch 106/150
# 34315/34315 [==============================] - 108s 3ms/step - loss: 0.5064 - accuracy: 0.7284
# Epoch 107/150
# 34315/34315 [==============================] - 108s 3ms/step - loss: 0.5054 - accuracy: 0.7293
# Epoch 108/150
# 34315/34315 [==============================] - 108s 3ms/step - loss: 0.5054 - accuracy: 0.7291
# Epoch 109/150
# 34315/34315 [==============================] - 108s 3ms/step - loss: 0.5054 - accuracy: 0.7291
# Epoch 110/150
# 34315/34315 [==============================] - 108s 3ms/step - loss: 0.5053 - accuracy: 0.7293
# Epoch 111/150
# 34315/34315 [==============================] - 109s 3ms/step - loss: 0.5039 - accuracy: 0.7305
# Epoch 112/150
# 34315/34315 [==============================] - 109s 3ms/step - loss: 0.5037 - accuracy: 0.7306
# Epoch 113/150
# 34315/34315 [==============================] - 110s 3ms/step - loss: 0.5040 - accuracy: 0.7303
# Epoch 114/150
# 34315/34315 [==============================] - 109s 3ms/step - loss: 0.5044 - accuracy: 0.7301
# Epoch 115/150
# 34315/34315 [==============================] - 109s 3ms/step - loss: 0.5038 - accuracy: 0.7306
# Epoch 116/150
# 34315/34315 [==============================] - 109s 3ms/step - loss: 0.5039 - accuracy: 0.7310
# Epoch 117/150
# 34315/34315 [==============================] - 109s 3ms/step - loss: 0.5032 - accuracy: 0.7308
# Epoch 118/150
# 34315/34315 [==============================] - 108s 3ms/step - loss: 0.5032 - accuracy: 0.7315
# Epoch 119/150
# 34315/34315 [==============================] - 106s 3ms/step - loss: 0.5028 - accuracy: 0.7316
# Epoch 120/150
# 34315/34315 [==============================] - 106s 3ms/step - loss: 0.5022 - accuracy: 0.7316
# Epoch 121/150
# 34315/34315 [==============================] - 106s 3ms/step - loss: 0.5028 - accuracy: 0.7315
# Epoch 122/150
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.5025 - accuracy: 0.7322
# Epoch 123/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.5026 - accuracy: 0.7313
# Epoch 124/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.5023 - accuracy: 0.7314
# Epoch 125/150
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.5018 - accuracy: 0.7323
# Epoch 126/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.5012 - accuracy: 0.7329
# Epoch 127/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.5018 - accuracy: 0.7322
# Epoch 128/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.5011 - accuracy: 0.7330
# Epoch 129/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.5014 - accuracy: 0.7323
# Epoch 130/150
# 34315/34315 [==============================] - 106s 3ms/step - loss: 0.5006 - accuracy: 0.7330
# Epoch 131/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.5001 - accuracy: 0.7338
# Epoch 132/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.5004 - accuracy: 0.7337
# Epoch 133/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.5005 - accuracy: 0.7333
# Epoch 134/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.5005 - accuracy: 0.7335
# Epoch 135/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.5003 - accuracy: 0.7334
# Epoch 136/150
# 34315/34315 [==============================] - 102s 3ms/step - loss: 0.5001 - accuracy: 0.7341
# Epoch 137/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.5000 - accuracy: 0.7341
# Epoch 138/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.4999 - accuracy: 0.7338
# Epoch 139/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.4997 - accuracy: 0.7340
# Epoch 140/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.4996 - accuracy: 0.7344
# Epoch 141/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.4990 - accuracy: 0.7344
# Epoch 142/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.4992 - accuracy: 0.7344
# Epoch 143/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.4994 - accuracy: 0.7347
# Epoch 144/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.4994 - accuracy: 0.7348
# Epoch 145/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.4987 - accuracy: 0.7350
# Epoch 146/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.4987 - accuracy: 0.7350
# Epoch 147/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.4988 - accuracy: 0.7346
# Epoch 148/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.4990 - accuracy: 0.7351
# Epoch 149/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.4991 - accuracy: 0.7350
# Epoch 150/150
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.4988 - accuracy: 0.7348

# %%
model_visual.fit(X_train, Y_train, epochs=50, batch_size=64,verbose=1)
# Out:
# Epoch 1/50
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.4982 - accuracy: 0.7360
# Epoch 2/50
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.4983 - accuracy: 0.7351
# Epoch 3/50
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.4984 - accuracy: 0.7355
# Epoch 4/50
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.4984 - accuracy: 0.7355
# Epoch 5/50
# 34315/34315 [==============================] - 110s 3ms/step - loss: 0.4987 - accuracy: 0.7355
# Epoch 6/50
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.4983 - accuracy: 0.7357
# Epoch 7/50
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.4975 - accuracy: 0.7360
# Epoch 8/50
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.4976 - accuracy: 0.7359
# Epoch 9/50
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.4982 - accuracy: 0.7357
# Epoch 10/50
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.4978 - accuracy: 0.7360
# Epoch 11/50
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.4975 - accuracy: 0.7360
# Epoch 12/50
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.4969 - accuracy: 0.7368
# Epoch 13/50
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.4971 - accuracy: 0.7369
# Epoch 14/50
# 34315/34315 [==============================] - 105s 3ms/step - loss: 0.4971 - accuracy: 0.7366
# Epoch 15/50
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.4977 - accuracy: 0.7370
# Epoch 16/50
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.4968 - accuracy: 0.7373
# Epoch 17/50
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.4966 - accuracy: 0.7368
# Epoch 18/50
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.4969 - accuracy: 0.7366
# Epoch 19/50
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.4963 - accuracy: 0.7372
# Epoch 20/50
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.4969 - accuracy: 0.7373
# Epoch 21/50
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.4961 - accuracy: 0.7376
# Epoch 22/50
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.4963 - accuracy: 0.7375
# Epoch 23/50
# 34315/34315 [==============================] - 106s 3ms/step - loss: 0.4961 - accuracy: 0.7369
# Epoch 24/50
# 34315/34315 [==============================] - 105s 3ms/step - loss: 0.4963 - accuracy: 0.7373
# Epoch 25/50
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.4965 - accuracy: 0.7377
# Epoch 26/50
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.4960 - accuracy: 0.7371
# Epoch 27/50
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.4961 - accuracy: 0.7376
# Epoch 28/50
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.4961 - accuracy: 0.7370
# Epoch 29/50
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.4959 - accuracy: 0.7374
# Epoch 30/50
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.4957 - accuracy: 0.7378
# Epoch 31/50
# 34315/34315 [==============================] - 105s 3ms/step - loss: 0.4957 - accuracy: 0.7381
# Epoch 32/50
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.4951 - accuracy: 0.7387
# Epoch 33/50
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.4959 - accuracy: 0.7379
# Epoch 34/50
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.4954 - accuracy: 0.7382
# Epoch 35/50
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.4954 - accuracy: 0.7386
# Epoch 36/50
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.4958 - accuracy: 0.7380
# Epoch 37/50
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.4950 - accuracy: 0.7393
# Epoch 38/50
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.4952 - accuracy: 0.7383
# Epoch 39/50
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.4951 - accuracy: 0.7385
# Epoch 40/50
# 34315/34315 [==============================] - 105s 3ms/step - loss: 0.4948 - accuracy: 0.7392
# Epoch 41/50
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.4951 - accuracy: 0.7386
# Epoch 42/50
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.4949 - accuracy: 0.7382
# Epoch 43/50
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.4949 - accuracy: 0.7382
# Epoch 44/50
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.4949 - accuracy: 0.7386
# Epoch 45/50
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.4945 - accuracy: 0.7384
# Epoch 46/50
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.4949 - accuracy: 0.7381
# Epoch 47/50
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.4947 - accuracy: 0.7386
# Epoch 48/50
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.4945 - accuracy: 0.7389
# Epoch 49/50
# 34315/34315 [==============================] - 104s 3ms/step - loss: 0.4938 - accuracy: 0.7402
# Epoch 50/50
# 34315/34315 [==============================] - 103s 3ms/step - loss: 0.4943 - accuracy: 0.7388

# %%
def precision_recall(gt,preds):
    TP=0
    FP=0
    FN=0
    for t in gt:
        if t in preds:
            TP+=1
        else:
            FN+=1
    for p in preds:
        if p not in gt:
            FP+=1
    if TP+FP==0:
        precision=0
    else:
        precision=TP/float(TP+FP)
    if TP+FN==0:
        recall=0
    else:
        recall=TP/float(TP+FN)
    return precision,recall

# %%
Y_preds=model_visual.predict(X_test)

# %%
import pickle
f6=open('/content/drive/My Drive/Genredict.pckl','rb')
Genre_ID_to_name=pickle.load(f6)
f6.close()

# %%
genre_list=sorted(list(Genre_ID_to_name.keys()))

# %%
del f6 
del pickle

# %%
sum(sum(Y_preds))
# Out:
# 63863.24011230469

# %%
import pandas as pd
df = pd.read_pickle("/content/drive/My Drive/pinky_promise_last.pckl")

# %%
import numpy as np
positions=range(len(df))
# print positions
test_movies=np.asarray(positions)[~mask]
# test_movies

# %%
import numpy as np

precs=[]
recs=[]
for i in range(len(Y_preds)):
    row=Y_preds[i]
    gt_genres=Y_test[i]
    gt_genre_names=[]
    for j in range(14):
        if gt_genres[j]==1:
            gt_genre_names.append(Genre_ID_to_name[genre_list[j]])
    top_3=np.argsort(row)[-4:]
    predicted_genres=[]
    for genre in top_3:
        predicted_genres.append(Genre_ID_to_name[genre_list[genre]])
    (precision,recall)=precision_recall(gt_genre_names,predicted_genres)
    precs.append(precision)
    recs.append(recall)
    print("Predicted: ",','.join(predicted_genres)," Actual: ",','.join(gt_genre_names))
# Out:
# Streaming output truncated to the last 5000 lines.
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Drama,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,Comedy,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,History,Thriller,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Western,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Western,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Animation,Drama,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Western,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,History,Thriller,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,Western,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Western,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Drama,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Western,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Drama,Comedy,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Comedy,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Thriller,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Western,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Thriller,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Western,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Western,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Comedy,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,Thriller,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Thriller,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,History,Thriller,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Western,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Drama,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Comedy,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Drama,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Drama,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Western,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Western,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Western,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,History,Thriller,Science Fiction,Mystery
# Predicted:  Drama,Horror,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Thriller,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Action,Western,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Thriller,Science Fiction,Mystery  Actual:  Drama,Comedy,Science Fiction,Mystery
# ...
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Western,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Western,Science Fiction,Mystery
# Predicted:  Adventure,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Drama,Documentary,Science Fiction,Mystery  Actual:  Drama,Western,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Animation,Drama,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Western,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,Comedy,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Thriller,Science Fiction,Mystery
# Predicted:  Drama,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Western,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Drama,Documentary,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Documentary,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Western,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Drama,Documentary,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Drama,Documentary,Science Fiction,Mystery  Actual:  Drama,Western,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Western,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Western,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Documentary,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Adventure,Documentary,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Western,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Western,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Horror,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Comedy,Western,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Western,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Horror,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Western,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Western,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Drama,Western,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Western,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Crime,Science Fiction,Mystery
# Predicted:  Drama,Documentary,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Western,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Western,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Western,Science Fiction,Mystery
# Predicted:  Adventure,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Western,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Crime,Science Fiction,Mystery
# Predicted:  Action,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,History,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Drama,Western,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Western,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Horror,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Western,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Action,Adventure,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Western,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Horror,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Crime,Science Fiction,Mystery

# %%
print(np.mean(np.asarray(precs)),np.mean(np.asarray(recs)))
print("avg=",(np.mean(np.asarray(precs))+np.mean(np.asarray(recs)))/2)
# Out:
# 0.862749624841279 0.5037786706348405
# avg= 0.6832641477380598

# %%
print("f1-score", (2*(np.mean(np.asarray(precs)) * np.mean(np.asarray(recs)))) / (np.mean(np.asarray(precs)) + np.mean(np.asarray(recs))))
# Out:
# f1-score 0.6361154182201744

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 63
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2300.000
# cache size	: 46080 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 avx2 smep bmi2 erms invpcid xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs itlb_multihit
# bogomips	: 4600.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 63
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2300.000
# cache size	: 46080 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 2
# initial apicid	: 2
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 avx2 smep bmi2 erms invpcid xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs itlb_multihit
# bogomips	: 4600.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 2
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 63
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2300.000
# cache size	: 46080 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 avx2 smep bmi2 erms invpcid xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs itlb_multihit
# bogomips	: 4600.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 3
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 63
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2300.000
# cache size	: 46080 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 3
# initial apicid	: 3
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 avx2 smep bmi2 erms invpcid xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs itlb_multihit
# bogomips	: 4600.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:

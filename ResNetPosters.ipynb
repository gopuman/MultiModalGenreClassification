# %%
import pickle

f1 = open("/content/drive/My Drive/Resnet_features_1.pckl","rb")
x1 = pickle.load(f1)

# %%
f2 = open("/content/drive/My Drive/Resnet_features_2.pckl","rb")
x2 = pickle.load(f2)

# %%
f3 = open("/content/drive/My Drive/Resnet_features_3.pckl","rb")
x3 = pickle.load(f3)

# %%
X = x1[0]
X.extend(x2[0])
X.extend(x3[0])

# %%
genre_list = x1[4]
genre_list.extend(x2[4])
genre_list.extend(x3[4])

# %%
feature_size=1000

np_features=np.zeros((len(X),feature_size))
for i in range(len(X)):
    feat=X[i]
    reshaped_feat=feat.reshape(1,-1)
    np_features[i]=reshaped_feat

X=np_features

from sklearn.preprocessing import MultiLabelBinarizer
mlb=MultiLabelBinarizer()
Y=mlb.fit_transform(genre_list)

Y.shape
# Out:
# (42978, 14)

# %%
mask = np.random.rand(len(X)) < 0.8

# %%
X_train=X[mask]
X_test=X[~mask]
Y_train=Y[mask]
Y_test=Y[~mask]

# %%
X_test.shape
# Out:
# (8545, 1000)

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras import optimizers
model_visual = Sequential([
    Dense(1024, input_shape=(1000,)),
    Activation('relu'),
    Dense(256),
    Activation('relu'),
    Dense(14),
    Activation('sigmoid'),
])
opt = optimizers.rmsprop(lr=0.0001, decay=1e-6)

#sgd = optimizers.SGD(lr=0.05, decay=1e-6, momentum=0.4, nesterov=False)
model_visual.compile(optimizer=opt,
              loss='binary_crossentropy',
              metrics=['accuracy'])
# Out:
# Using TensorFlow backend.

# %%
model_visual.fit(X_train, Y_train, epochs=60, batch_size=64,verbose=1)
# Out:
# Epoch 1/60
# 34433/34433 [==============================] - 11s 317us/step - loss: 0.5759 - accuracy: 0.6711
# Epoch 2/60
# 34433/34433 [==============================] - 11s 312us/step - loss: 0.5498 - accuracy: 0.6807
# Epoch 3/60
# 34433/34433 [==============================] - 11s 314us/step - loss: 0.5462 - accuracy: 0.6858
# Epoch 4/60
# 34433/34433 [==============================] - 11s 317us/step - loss: 0.5436 - accuracy: 0.6890
# Epoch 5/60
# 34433/34433 [==============================] - 11s 313us/step - loss: 0.5417 - accuracy: 0.6914
# Epoch 6/60
# 34433/34433 [==============================] - 11s 310us/step - loss: 0.5404 - accuracy: 0.6927
# Epoch 7/60
# 34433/34433 [==============================] - 11s 312us/step - loss: 0.5393 - accuracy: 0.6943
# Epoch 8/60
# 34433/34433 [==============================] - 11s 313us/step - loss: 0.5385 - accuracy: 0.6950
# Epoch 9/60
# 34433/34433 [==============================] - 11s 313us/step - loss: 0.5378 - accuracy: 0.6957
# Epoch 10/60
# 34433/34433 [==============================] - 11s 311us/step - loss: 0.5371 - accuracy: 0.6965
# Epoch 11/60
# 34433/34433 [==============================] - 11s 313us/step - loss: 0.5366 - accuracy: 0.6971
# Epoch 12/60
# 34433/34433 [==============================] - 11s 314us/step - loss: 0.5360 - accuracy: 0.6977
# Epoch 13/60
# 34433/34433 [==============================] - 11s 314us/step - loss: 0.5356 - accuracy: 0.6982
# Epoch 14/60
# 34433/34433 [==============================] - 11s 313us/step - loss: 0.5351 - accuracy: 0.6988
# Epoch 15/60
# 34433/34433 [==============================] - 11s 311us/step - loss: 0.5347 - accuracy: 0.6993
# Epoch 16/60
# 34433/34433 [==============================] - 11s 310us/step - loss: 0.5342 - accuracy: 0.6997
# Epoch 17/60
# 34433/34433 [==============================] - 11s 313us/step - loss: 0.5339 - accuracy: 0.7000
# Epoch 18/60
# 34433/34433 [==============================] - 11s 311us/step - loss: 0.5335 - accuracy: 0.7005
# Epoch 19/60
# 34433/34433 [==============================] - 11s 311us/step - loss: 0.5331 - accuracy: 0.7009
# Epoch 20/60
# 34433/34433 [==============================] - 11s 311us/step - loss: 0.5327 - accuracy: 0.7015
# Epoch 21/60
# 34433/34433 [==============================] - 11s 311us/step - loss: 0.5324 - accuracy: 0.7018
# Epoch 22/60
# 34433/34433 [==============================] - 11s 313us/step - loss: 0.5320 - accuracy: 0.7023
# Epoch 23/60
# 34433/34433 [==============================] - 11s 316us/step - loss: 0.5316 - accuracy: 0.7025
# Epoch 24/60
# 34433/34433 [==============================] - 11s 314us/step - loss: 0.5312 - accuracy: 0.7028
# Epoch 25/60
# 34433/34433 [==============================] - 11s 312us/step - loss: 0.5309 - accuracy: 0.7034
# Epoch 26/60
# 34433/34433 [==============================] - 11s 310us/step - loss: 0.5305 - accuracy: 0.7039
# Epoch 27/60
# 34433/34433 [==============================] - 11s 313us/step - loss: 0.5301 - accuracy: 0.7040
# Epoch 28/60
# 34433/34433 [==============================] - 11s 317us/step - loss: 0.5298 - accuracy: 0.7043
# Epoch 29/60
# 34433/34433 [==============================] - 11s 315us/step - loss: 0.5294 - accuracy: 0.7047
# Epoch 30/60
# 34433/34433 [==============================] - 11s 315us/step - loss: 0.5291 - accuracy: 0.7055
# Epoch 31/60
# 34433/34433 [==============================] - 11s 314us/step - loss: 0.5287 - accuracy: 0.7054
# Epoch 32/60
# 34433/34433 [==============================] - 11s 315us/step - loss: 0.5283 - accuracy: 0.7058
# Epoch 33/60
# 34433/34433 [==============================] - 11s 317us/step - loss: 0.5279 - accuracy: 0.7063
# Epoch 34/60
# 34433/34433 [==============================] - 11s 313us/step - loss: 0.5276 - accuracy: 0.7069
# Epoch 35/60
# 34433/34433 [==============================] - 11s 314us/step - loss: 0.5272 - accuracy: 0.7070
# Epoch 36/60
# 34433/34433 [==============================] - 11s 318us/step - loss: 0.5268 - accuracy: 0.7075
# Epoch 37/60
# 34433/34433 [==============================] - 11s 314us/step - loss: 0.5264 - accuracy: 0.7078
# Epoch 38/60
# 34433/34433 [==============================] - 11s 313us/step - loss: 0.5260 - accuracy: 0.7083
# Epoch 39/60
# 34433/34433 [==============================] - 11s 312us/step - loss: 0.5256 - accuracy: 0.7085
# Epoch 40/60
# 34433/34433 [==============================] - 11s 314us/step - loss: 0.5252 - accuracy: 0.7092
# Epoch 41/60
# 34433/34433 [==============================] - 11s 312us/step - loss: 0.5248 - accuracy: 0.7095
# Epoch 42/60
# 34433/34433 [==============================] - 11s 308us/step - loss: 0.5242 - accuracy: 0.7100
# Epoch 43/60
# 34433/34433 [==============================] - 14s 408us/step - loss: 0.5239 - accuracy: 0.7101
# Epoch 44/60
# 34433/34433 [==============================] - 11s 310us/step - loss: 0.5235 - accuracy: 0.7107
# Epoch 45/60
# 34433/34433 [==============================] - 11s 312us/step - loss: 0.5231 - accuracy: 0.7109
# Epoch 46/60
# 34433/34433 [==============================] - 11s 311us/step - loss: 0.5226 - accuracy: 0.7118
# Epoch 47/60
# 34433/34433 [==============================] - 11s 313us/step - loss: 0.5221 - accuracy: 0.7119
# Epoch 48/60
# 34433/34433 [==============================] - 11s 312us/step - loss: 0.5217 - accuracy: 0.7122
# Epoch 49/60
# 34433/34433 [==============================] - 11s 310us/step - loss: 0.5212 - accuracy: 0.7132
# Epoch 50/60
# 34433/34433 [==============================] - 11s 314us/step - loss: 0.5208 - accuracy: 0.7131
# Epoch 51/60
# 34433/34433 [==============================] - 11s 318us/step - loss: 0.5203 - accuracy: 0.7140
# Epoch 52/60
# 34433/34433 [==============================] - 11s 312us/step - loss: 0.5199 - accuracy: 0.7142
# Epoch 53/60
# 34433/34433 [==============================] - 11s 311us/step - loss: 0.5193 - accuracy: 0.7149
# Epoch 54/60
# 34433/34433 [==============================] - 11s 314us/step - loss: 0.5188 - accuracy: 0.7149
# Epoch 55/60
# 34433/34433 [==============================] - 11s 315us/step - loss: 0.5184 - accuracy: 0.7156
# Epoch 56/60
# 34433/34433 [==============================] - 11s 311us/step - loss: 0.5179 - accuracy: 0.7158
# Epoch 57/60
# 34433/34433 [==============================] - 11s 312us/step - loss: 0.5174 - accuracy: 0.7164
# Epoch 58/60
# 34433/34433 [==============================] - 11s 312us/step - loss: 0.5169 - accuracy: 0.7168
# Epoch 59/60
# 34433/34433 [==============================] - 11s 309us/step - loss: 0.5164 - accuracy: 0.7173
# Epoch 60/60
# 34433/34433 [==============================] - 11s 311us/step - loss: 0.5158 - accuracy: 0.7177

# %%
Y_preds=model_visual.predict(X_test)

# %%
sum(sum(Y_preds))
# Out:
# 67102.52746582031

# %%
f6=open('/content/drive/My Drive/Genredict.pckl','rb')
Genre_ID_to_name=pickle.load(f6)
f6.close()

# %%
sum(Y_preds[1])
# Out:
# 7.44036728143692

# %%
genre_list=sorted(list(Genre_ID_to_name.keys()))

# %%
def precision_recall(gt,preds):
    TP=0
    FP=0
    FN=0
    for t in gt:
        if t in preds:
            TP+=1
        else:
            FN+=1
    for p in preds:
        if p not in gt:
            FP+=1
    if TP+FP==0:
        precision=0
    else:
        precision=TP/float(TP+FP)
    if TP+FN==0:
        recall=0
    else:
        recall=TP/float(TP+FN)
    return precision,recall

# %%
precs=[]
recs=[]
for i in range(len(Y_preds)):
    row=Y_preds[i]
    gt_genres=Y_test[i]
    gt_genre_names=[]
    for j in range(14):
        if gt_genres[j]==1:
            gt_genre_names.append(Genre_ID_to_name[genre_list[j]])
    top_3=np.argsort(row)[-4:]
    predicted_genres=[]
    for genre in top_3:
        predicted_genres.append(Genre_ID_to_name[genre_list[genre]])
    (precision,recall)=precision_recall(gt_genre_names,predicted_genres)
    precs.append(precision)
    recs.append(recall)
    print("Predicted: ",','.join(predicted_genres)," Actual: ",','.join(gt_genre_names))
# Out:
# Streaming output truncated to the last 5000 lines.
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Drama,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Comedy,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Drama,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Mystery,Science Fiction  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Comedy,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Drama,Adventure,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Mystery,Science Fiction  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Horror,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Drama,Horror,Science Fiction,Mystery  Actual:  Animation,Drama,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Action,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Animation,Drama,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Horror,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Drama,Documentary,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  History,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Mystery,Science Fiction  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Animation,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Western,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Animation,Drama,History,Thriller,Science Fiction,Mystery
# Predicted:  Documentary,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Comedy,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Drama,Fantasy,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,Comedy,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Mystery,Science Fiction  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Mystery,Science Fiction  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Mystery,Science Fiction  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Mystery,Science Fiction  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Horror,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Documentary,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Western,Drama,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Drama,Documentary,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Crime,Drama,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Drama,Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Mystery,Science Fiction  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Action,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,History,Science Fiction,Mystery  Actual:  Animation,Drama,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Documentary,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Thriller,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Horror,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  History,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Comedy,Thriller,Science Fiction,Mystery
# Predicted:  Drama,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Animation,Drama,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Western,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Comedy,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Comedy,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Documentary,Drama,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Documentary,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Drama,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Mystery,Science Fiction  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Crime,Fantasy,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Comedy,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Drama,Fantasy,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Western,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Western,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Mystery,Science Fiction  Actual:  Horror,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Drama,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Drama,Horror,Action,Comedy,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Crime,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,Western,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Action,Western,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Drama,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Western,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Horror,Action,Comedy,History,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Animation,Drama,Horror,Comedy,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Action,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Western,Thriller,Crime,Documentary,Science Fiction,Mystery
# ...
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Documentary,Science Fiction,Mystery
# Predicted:  Thriller,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Western,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Western,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Western,Science Fiction,Mystery
# Predicted:  Drama,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,History,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Western,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Animation,Drama,Action,Western,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Drama,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Horror,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  History,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Western,Drama,Science Fiction,Mystery  Actual:  Drama,Western,Science Fiction,Mystery
# Predicted:  Action,Thriller,Science Fiction,Mystery  Actual:  Animation,Crime,Science Fiction,Mystery
# Predicted:  Drama,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Horror,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Science Fiction,Mystery
# Predicted:  Action,History,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Horror,Crime,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Documentary,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,Western,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Horror,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Horror,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Drama,Horror,Comedy,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Western,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Western,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Western,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Comedy,History,Western,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Western,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Comedy,Drama,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Action,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Comedy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Mystery,Science Fiction  Actual:  Adventure,Fantasy,Drama,Horror,Western,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,History,Western,Thriller,Science Fiction,Mystery
# Predicted:  Drama,Western,Science Fiction,Mystery  Actual:  Drama,Western,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Comedy,Western,Science Fiction,Mystery
# Predicted:  Adventure,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,Western,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  History,Action,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Crime,Science Fiction,Mystery
# Predicted:  Documentary,Drama,Mystery,Science Fiction  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Comedy,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,History,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,Comedy,History,Western,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Drama,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Action,History,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,History,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Horror,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,Thriller,Documentary,Science Fiction,Mystery
# Predicted:  Drama,Horror,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Thriller,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Action,History,Crime,Science Fiction,Mystery
# Predicted:  Animation,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,History,Thriller,Science Fiction,Mystery
# Predicted:  Horror,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Adventure,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Drama,Horror,Action,History,Crime,Science Fiction,Mystery
# Predicted:  History,Drama,Science Fiction,Mystery  Actual:  Drama,Western,Science Fiction,Mystery
# Predicted:  Fantasy,Adventure,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Adventure,Fantasy,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,Comedy,Western,Thriller,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Thriller,Crime,Documentary,Science Fiction,Mystery
# Predicted:  Crime,Drama,Science Fiction,Mystery  Actual:  Adventure,Fantasy,Animation,Drama,Horror,Action,History,Thriller,Crime,Science Fiction,Mystery
# Predicted:  Fantasy,Drama,Science Fiction,Mystery  Actual:  Drama,Horror,Science Fiction,Mystery

# %%
print(np.mean(np.asarray(precs)),np.mean(np.asarray(recs)))
print("avg=",(np.mean(np.asarray(precs))+np.mean(np.asarray(recs)))/2)
# Out:
# 0.8450555880631948 0.4758314772153274
# avg= 0.6604435326392611

# %%
print("f1-score", (2*(np.mean(np.asarray(precs)) * np.mean(np.asarray(recs)))) / (np.mean(np.asarray(precs)) + np.mean(np.asarray(recs))))
# Out:
# f1-score 0.6088394070425537

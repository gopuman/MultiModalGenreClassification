# %%
# !pip install tmdbsimple
# Out:
# Requirement already satisfied: tmdbsimple in /usr/local/lib/python3.6/dist-packages (2.2.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from tmdbsimple) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->tmdbsimple) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->tmdbsimple) (2020.4.5.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->tmdbsimple) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->tmdbsimple) (3.0.4)

# %%
#XGB

import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import pickle
import tmdbsimple as tmdb

df = pd.DataFrame()
df = pd.read_csv("/content/drive/My Drive/Multimodal Genre Classification/last.csv", engine="python")
 
from ast import literal_eval
df.genre_ids=df.genre_ids.apply(literal_eval)

df.genre_ids[0]

api_key = "d0ccc864ded48afb6a7e28b2d32001ed"
tmdb.API_KEY = api_key
#search = tmdb.Search()

genres=tmdb.Genres()
list_of_genres=genres.movie_list()['genres']
Genre_ID_to_name={}
for i in range(len(list_of_genres)):
    genre_id=list_of_genres[i]['id']
    genre_name=list_of_genres[i]['name']
    Genre_ID_to_name[genre_id]=genre_name

# genres=np.zeros((len(top1000_movies),3))
genres=[]
all_ids=[]
for i in range(len(df)):
    id=df.id[i]
    genre_ids=df.genre_ids[i]
    genres.append(genre_ids)
    all_ids.extend(genre_ids)

print(all_ids)

from sklearn.preprocessing import MultiLabelBinarizer
mlb=MultiLabelBinarizer()
Y=mlb.fit_transform(genres)

print(Y.shape)
print(np.sum(Y, axis=0))

sample_overview=df.overview[5]
sample_title=df.title[5]
print("The overview for the movie",sample_title," is - \n\n")
print(sample_overview)

from sklearn.feature_extraction.text import CountVectorizer
import re

content=[]
for i in range(len(df)):
    id=df.id[i]
    overview=df.overview[i]
    overview=overview.replace(',','')
    overview=overview.replace('.','')
    content.append(overview)

vectorize=CountVectorizer(max_df=0.95, min_df=0.005)
X=vectorize.fit_transform(content)

print("SEE",X.shape)


import pickle
f4=open('X.pckl','wb')
f5=open('Y.pckl','wb')
pickle.dump(X,f4)
pickle.dump(Y,f5)
f6=open('Genredict.pckl','wb')
pickle.dump(Genre_ID_to_name,f6)
f4.close()
f5.close()
f6.close()

from sklearn.feature_extraction.text import TfidfTransformer
tfidf_transformer = TfidfTransformer()
X_tfidf = tfidf_transformer.fit_transform(X)
print("After",X_tfidf.shape)


msk = np.random.rand(X_tfidf.shape[0]) < 0.8

X_train_tfidf=X_tfidf[msk]
X_test_tfidf=X_tfidf[~msk]
Y_train=Y[msk]
Y_test=Y[~msk]

positions=range(len(df))
# print positions
test_movies=np.asarray(positions)[~msk]
# test_movies

from sklearn.multiclass import OneVsRestClassifier
from sklearn.metrics import f1_score
from sklearn.metrics import make_scorer
from sklearn.metrics import classification_report
from xgboost import XGBClassifier

genre_names = []
for id in df.genre_ids:
  for i in id:
    genre_name=Genre_ID_to_name[i]
    genre_names.append(genre_name)
genre_names = set(genre_names)

#New code for the next review

genre_list=sorted(list(Genre_ID_to_name.keys()))
print(genre_list)

clf = OneVsRestClassifier(XGBClassifier(n_jobs=-1, max_depth=4))

clf.fit(X_train_tfidf, Y_train)
predsnb=clf.predict(X_test_tfidf)

import pickle
f2=open('classifer_xgb','wb')
pickle.dump(clf,f2)
f2.close()

print(classification_report(Y_test, predsnb, target_names=genre_names))

predictionsnb=[]
for i in range(X_test_tfidf.shape[0]):
    pred_genres=[]
    movie_label_scores=predsnb[i]
    for j in range(19):
        #print j
        if movie_label_scores[j]!=0:
            genre=Genre_ID_to_name[genre_list[j]]
            pred_genres.append(genre)
    predictionsnb.append(pred_genres)

for i in range(X_test_tfidf.shape[0]):
    if i%50==0 and i!=0:
        print('MOVIE: ',df.title[test_movies[i]],'\tPREDICTION: ',','.join(predictionsnb[i]))
# Out:
# [28, 35, 80, 28, 12, 35, 14, 10751, 28, 80, 53, 28, 18, 10752, 28, 878, 28, 18, 28, 18, 36, 10752, 28, 80, 18, 28, 35, 28, 53, 28, 12, 878, 28, 12, 878, 28, 28, 12, 35, 14, 28, 12, 35, 14, 878, 10751, 28, 878, 28, 35, 80, 28, 12, 878, 28, 12, 35, 28, 18, 53, 28, 12, 14, 28, 80, 18, 878, 53, 28, 12, 14, 28, 12, 16, 35, 10751, 28, 12, 14, 28, 12, 14, 28, 12, 878, 28, 12, 878, 28, 12, 878, 28, 53, 28, 53, 28, 12, 878, 28, 35, 27, 28, 80, 53, 28, 12, 878, 28, 12, 878, 28, 12, 14, 28, 80, 18, 53, 28, 53, 878, 28, 12, 35, 14, 28, 18, 36, 10752, 14, 12, 878, 28, 28, 12, 35, 14, 28, 18, 10752, 28, 12, 878, 53, 28, 12, 14, 28, 12, 35, 878, 28, 878, 28, 12, 35, 28, 12, 14, 878, 28, 12, 14, 878, 28, 12, 878, 28, 12, 53, 28, 12, 16, 35, 878, 28, 12, 14, 878, 28, 878, 28, 12, 35, 28, 12, 14, 878, 80, 28, 53, 28, 28, 80, 53, 28, 53, 878, 28, 878, 28, 12, 878, 53, 28, 12, 14, 10749, 10751, 28, 80, 18, 53, 28, 18, 878, 28, 12, 878, 28, 12, 14, 28, 9648, 878, 53, 28, 35, 53, 28, 12, 14, 28, 12, 14, 28, 12, 878, 28, 12, 878, 28, 12, 18, 878, 28, 12, 14, 878, 28, 12, 14, 28, 35, 10751, 28, 12, 16, 35, 14, 10751, 28, 12, 35, 878, 28, 18, 878, 53, 28, 12, 878, 28, 12, 14, 28, 12, 14, 28, 80, 18, 28, 12, 80, 28, 12, 35, 878, 28, 35, 14, 28, 12, 878, 28, 12, 14, 28, 12, 878, 28, 12, 35, 28, 80, 53, 28, 12, 28, 12, 35, 878, 28, 12, 14, 28, 878, 53, 28, 12, 14, 878, 28, 12, 16, 10751, 28, 12, 14, 12, 28, 53, 28, 12, 14, 878, 28, 80, 18, 53, 28, 12, 14, 878, 53, 28, 12, 80, 53, 28, 80, 53, 28, 12, 878, 53, 28, 12, 878, 28, 12, 14, 28, 878, 53, 28, 12, 80, 14, 878, 28, 12, 28, 12, 35, 28, 14, 28, 12, 14, 28, 12, 27, 28, 80, 28, 80, 18, 53, 28, 80, 53, 28, 53, 28, 12, 53, 28, 18, 9648, 28, 12, 878, 28, 53, 28, 12, 80, 53, 28, 12, 14, 28, 12, 28, 12, 53, 28, 12, 18, 53, 28, 14, 28, 12, 16, 10751, 80, 18, 28, 28, 12, 14, 28, 12, 878, 28, 80, 53, 28, 12, 35, 80, 53, 28, 12, 878, 28, 12, 878, 28, 12, 878, 53, 28, 12, 16, 35, 28, 80, 53, 28, 35, 80, 53, 18, 28, 53, 10752, 28, 18, 53, 28, 12, 14, 878, 28, 12, 28, 12, 16, 35, 14, 10751, 28, 18, 27, 53, 12, 28, 53, 28, 27, 878, 28, 12, 878, 53, 28, 12, 14, 878, 28, 12, 14, 28, 35, 28, 878, 53, 80, 28, 878, 28, 53, 28, 18, 14, 27, 10752, 28, 12, 14, 28, 12, 878, 28, 12, 14, 878, 28, 878, 53, 28, 14, 878, 53, 28, 12, 35, 14, 878, 28, 53, 28, 35, 18, 53, 28, 80, 18, 28, 12, 878, 28, 12, 35, 28, 53, 878, 28, 53, 28, 12, 53, 28, 12, 878, 28, 12, 35, 14, 28, 12, 35, 27, 878, 53, 28, 53, 28, 18, 12, 53, 28, 28, 12, 878, 28, 12, 35, 14, 10751, 28, 12, 878, 28, 80, 14, 28, 27, 878, 53, 28, 12, 878, 28, 12, 35, 14, 28, 12, 14, 878, 28, 12, 28, 35, 878, 28, 12, 14, 878, 28, 18, 53, 28, 12, 28, 12, 53, 28, 12, 14, 28, 12, 53, 10752, 28, 12, 14, 28, 18, 10752, 28, 12, 14, 878, 28, 12, 878, 28, 53, 12, 28, 878, 28, 12, 80, 28, 14, 53, 28, 12, 878, 28, 12, 53, 28, 12, 53, 10752, 28, 878, 53, 28, 18, 27, 878, 53, 28, 12, 18, 28, 35, 14, 28, 12, 878, 28, 9648, 878, 28, 878, 28, 80, 18, 53, 28, 53, 28, 9648, 53, 28, 12, 878, 28, 53, 12, 12, 28, 878, 28, 18, 14, 28, 12, 878, 53, 28, 53, 28, 35, 80, 28, 12, 35, 80, 28, 35, 10751, 14, 28, 28, 12, 878, 53, 28, 18, 878, 28, 35, 28, 12, 14, 28, 80, 53, 878, 28, 12, 28, 12, 53, 28, 35, 80, 28, 12, 53, 28, 53, 28, 80, 53, 28, 878, 28, 12, 878, 53, 12, 28, 53, 878, 28, 18, 878, 53, 53, 878, 28, 12, 28, 12, 878, 28, 53, 878, 27, 28, 12, 878, 53, 28, 80, 28, 878, 53, 28, 12, 14, 28, 12, 53, 28, 14, 28, 35, 28, 80, 53, 28, 35, 28, 18, 36, 10752, 12, 28, 53, 12, 14, 28, 53, 28, 80, 18, 53, 28, 18, 27, 878, 53, 28, 12, 18, 36, 10749, 28, 53, 28, 16, 9648, 28, 18, 53, 28, 12, 53, 28, 16, 9648, 28, 35, 80, 53, 28, 12, 53, 28, 12, 878, 28, 12, 53, 28, 80, 28, 35, 28, 18, 9648, 53, 28, 27, 878, 28, 14, 27, 53, 28, 12, 28, 27, 53, 28, 35, 80, 53, 28, 12, 14, 28, 878, 28, 80, 53, 28, 53, 28, 27, 28, 12, 9648, 878, 28, 12, 35, 878, 37, 28, 80, 878, 28, 12, 14, 28, 10752, 28, 28, 12, 18, 27, 878, 53, 37, 18, 28, 12, 36, 10752, 28, 9648, 878, 53, 28, 80, 53, 28, 12, 35, 28, 18, 36, 10752, 28, 18, 14, 2 ...
# (79244, 19)
# [ 6523  4374  8879 22565  9749 10663 17287  2737  3665 10841  8168 11967
#   6245  4809  8838  9358  7013  2254  4670]
# The overview for the movie Ford v Ferrari  is -
#
#
# American car designer Carroll Shelby and the British-born driver Ken Miles work together to battle corporate interference, the laws of physics, and their own personal demons to build a revolutionary race car for Ford Motor Company and take on the dominating race cars of Enzo Ferrari at the 24 Hours of Le Mans in France in 1966.
# SEE (79244, 1099)
# After (79244, 1099)
# [12, 14, 16, 18, 27, 28, 35, 36, 37, 53, 80, 99, 878, 9648, 10402, 10749, 10751, 10752, 10770]
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                  precision    recall  f1-score   support
#
#         Fantasy       0.51      0.01      0.03      1298
# Science Fiction       0.58      0.02      0.04       864
#         Western       0.86      0.15      0.25      1714
#           Music       0.68      0.14      0.23      4580
#         Mystery       0.81      0.18      0.30      1930
#             War       0.76      0.06      0.12      2141
#          Horror       0.82      0.09      0.16      3365
#         History       0.50      0.02      0.04       542
#          Action       0.86      0.31      0.46       777
#         Romance       0.59      0.04      0.07      2267
#        TV Movie       0.56      0.11      0.19      1574
#           Drama       0.87      0.46      0.60      2330
#           Crime       0.77      0.19      0.30      1281
#          Family       0.50      0.04      0.08      1042
#        Thriller       0.87      0.48      0.62      1772
#       Animation       0.71      0.18      0.29      1894
#          Comedy       0.70      0.08      0.14      1343
#       Adventure       0.69      0.25      0.37       437
#     Documentary       0.72      0.03      0.07       962
#
#       micro avg       0.77      0.16      0.26     32113
#       macro avg       0.70      0.15      0.23     32113
#    weighted avg       0.72      0.16      0.24     32113
#     samples avg       0.27      0.20      0.22     32113
#
# MOVIE:  Escape Room 	PREDICTION:
# MOVIE:  Peppermint 	PREDICTION:
# MOVIE:  Mad Max 2 	PREDICTION:
# MOVIE:  Man on Fire 	PREDICTION:
# MOVIE:  Everly 	PREDICTION:
# MOVIE:  Java Heat 	PREDICTION:
# MOVIE:  Hud 	PREDICTION:
# MOVIE:  Lords of Dogtown 	PREDICTION:
# MOVIE:  Beat the Devil 	PREDICTION:
# MOVIE:  AEW Double or Nothing 	PREDICTION:
# MOVIE:  Andron 	PREDICTION:
# MOVIE:  Gorgo 	PREDICTION:
# MOVIE:  Leonard Part 6 	PREDICTION:
# MOVIE:  The Ambushers 	PREDICTION:  Action,Western,Science Fiction
# MOVIE:  Exit Speed 	PREDICTION:
# MOVIE:  Without Warning 	PREDICTION:
# MOVIE:  Lucky Break 	PREDICTION:  Music
# MOVIE:  Rolling Vengeance 	PREDICTION:
# MOVIE:  A Rising Tide 	PREDICTION:
# MOVIE:  Ten Tall Men 	PREDICTION:
# MOVIE:  Maisie Undercover: Shadow Boxer 	PREDICTION:
# MOVIE:  A Run for Money 	PREDICTION:  Drama
# MOVIE:  Killer Force 	PREDICTION:
# MOVIE:  Karate Cop 	PREDICTION:  Action
# MOVIE:  Double Blast 	PREDICTION:
# MOVIE:  The Rains of Ranchipur 	PREDICTION:  Romance
# MOVIE:  Ultimate Force 	PREDICTION:  Action
# MOVIE:  Project: Kill 	PREDICTION:
# MOVIE:  NJPW G1 Special in USA 2017 - Night 2 	PREDICTION:
# MOVIE:  Beyond The Ring 	PREDICTION:
# MOVIE:  Shootfighter Tekken 	PREDICTION:  Action
# MOVIE:  Empire of Ash III 	PREDICTION:
# MOVIE:  Enteng Kabisote 4: Okay Ka Fairy Ko...The Beginning of the Legend 	PREDICTION:  Family
# MOVIE:  Piranha, Piranha 	PREDICTION:
# MOVIE:  The Masked Marvel 	PREDICTION:
# MOVIE:  Valentine's Day 	PREDICTION:  Crime
# MOVIE:  Manny Pacquiao vs. Jessie Vargas 	PREDICTION:
# MOVIE:  Mirror Mirror 	PREDICTION:  Fantasy,Romance
# MOVIE:  The Spiderwick Chronicles 	PREDICTION:
# MOVIE:  Sorcerer 	PREDICTION:
# MOVIE:  The People That Time Forgot 	PREDICTION:
# MOVIE:  Antarctica: A Year on Ice 	PREDICTION:  Documentary
# MOVIE:  Montana Amazon 	PREDICTION:
# MOVIE:  Out of Range 	PREDICTION:
# MOVIE:  Adventures of the Flying Cadets 	PREDICTION:
# MOVIE:  A Line Across the Sky 	PREDICTION:
# MOVIE:  Captain Kidd and the Slave Girl 	PREDICTION:
# MOVIE:  Karen or Bust 	PREDICTION:  Romance
# MOVIE:  Enteng ng Ina mo 	PREDICTION:  Romance
# MOVIE:  Shira: The Vampire Samurai 	PREDICTION:
# MOVIE:  Robin Hood: Quest for the King 	PREDICTION:  Animation
# MOVIE:  4 Idiots 	PREDICTION:
# MOVIE:  Unseeing Eyes 	PREDICTION:
# MOVIE:  Grit Flick 	PREDICTION:
# MOVIE:  Barbie and the Three Musketeers 	PREDICTION:
# MOVIE:  One Man Band 	PREDICTION:
# MOVIE:  Dragonlance: Dragons Of Autumn Twilight 	PREDICTION:
# MOVIE:  The Danish Poet 	PREDICTION:
# MOVIE:  A Good Time for a Dime 	PREDICTION:
# MOVIE:  Inspector Gadget's Last Case 	PREDICTION:  Animation
# MOVIE:  Walky Talky Hawky 	PREDICTION:  Drama
# MOVIE:  Body Patterns 	PREDICTION:
# MOVIE:  A Computer Animated Hand 	PREDICTION:  Animation
# MOVIE:  Kapture: Fluke 	PREDICTION:
# MOVIE:  Hip Hip-Hurry! 	PREDICTION:
# MOVIE:  One Day a Man Bought a House 	PREDICTION:
# MOVIE:  The Breath of a Nation 	PREDICTION:
# MOVIE:  The Way of Peace 	PREDICTION:
# MOVIE:  Chuck Jones: Extremes and In-Betweens – A Life in Animation 	PREDICTION:  Animation,Documentary
# MOVIE:  Desert Mirage 	PREDICTION:  Animation
# MOVIE:  the words i do not have yet 	PREDICTION:
# MOVIE:  Tom and Jerry:Merry Mice 	PREDICTION:  Animation
# MOVIE:  Spinach Fer Britain 	PREDICTION:
# MOVIE:  Terrier-Stricken 	PREDICTION:
# MOVIE:  The Mice Will Play 	PREDICTION:
# MOVIE:  Forty Pink Winks 	PREDICTION:
# MOVIE:  Pop Goes Your Heart 	PREDICTION:
# MOVIE:  Drowning Nut 	PREDICTION:
# MOVIE:  Mexico: Pátzcuaro, Veracruz and Acapulco 	PREDICTION:
# MOVIE:  The Incredible Story of My Great Grandmother Olive 	PREDICTION:  Science Fiction,Romance
# MOVIE:  How Much is a Million? 	PREDICTION:
# MOVIE:  Those Progressive Meats 	PREDICTION:
# MOVIE:  Rapid Eye Movements 	PREDICTION:  Animation
# MOVIE:  Evan Almighty 	PREDICTION:
# MOVIE:  Game Night 	PREDICTION:  Mystery
# MOVIE:  Weird Science 	PREDICTION:
# MOVIE:  The Cutting Edge 3: Chasing the Dream 	PREDICTION:
# MOVIE:  Date Movie 	PREDICTION:
# MOVIE:  Holy Man 	PREDICTION:
# MOVIE:  Women in Trouble 	PREDICTION:
# MOVIE:  24 Hour Party People 	PREDICTION:
# MOVIE:  Chasing Papi 	PREDICTION:
# MOVIE:  Love and Death 	PREDICTION:  War
# MOVIE:  Sexy Warriors 	PREDICTION:
# MOVIE:  Bo Burnham: What. 	PREDICTION:
# MOVIE:  Goon: Last of the Enforcers 	PREDICTION:
# MOVIE:  Young Doctors in Love 	PREDICTION:
# MOVIE:  My Giant 	PREDICTION:
# MOVIE:  The Party's Just Beginning 	PREDICTION:
# MOVIE:  I Love You Again 	PREDICTION:
# MOVIE:  Pal Joey 	PREDICTION:
# MOVIE:  The Dog Problem 	PREDICTION:  Romance
# MOVIE:  Carnage: Swallowing the Past 	PREDICTION:
# MOVIE:  Pete Holmes: Dirty Clean 	PREDICTION:  Comedy
# MOVIE:  Zilla and Zoe 	PREDICTION:  Horror
# MOVIE:  The Maggie 	PREDICTION:
# MOVIE:  Desert Blue 	PREDICTION:
# MOVIE:  Brief Interviews with Hideous Men 	PREDICTION:
# MOVIE:  Zombie eXs 	PREDICTION:
# MOVIE:  Phoenix, Oregon 	PREDICTION:
# MOVIE:  Jeff Ross Roasts America 	PREDICTION:
# MOVIE:  Robin Williams: An Evening with Robin Williams 	PREDICTION:  Comedy
# MOVIE:  Webseries: The Movie 	PREDICTION:
# MOVIE:  Trainspotting 	PREDICTION:
# MOVIE:  Find Me Guilty 	PREDICTION:  Drama
# MOVIE:  The Limits of Control 	PREDICTION:
# MOVIE:  The Firm 	PREDICTION:
# MOVIE:  Thieves' Highway 	PREDICTION:
# MOVIE:  Buster and Billie 	PREDICTION:
# MOVIE:  Offensive 	PREDICTION:
# MOVIE:  Furthest Witness 	PREDICTION:
# MOVIE:  Undermind 	PREDICTION:
# MOVIE:  Deadly Relations 	PREDICTION:
# MOVIE:  Nick Knight 	PREDICTION:  Horror
# MOVIE:  I am Diego Maradona 	PREDICTION:
# MOVIE:  Transfixed 	PREDICTION:  Crime
# MOVIE:  Diamond Connection 	PREDICTION:
# MOVIE:  Sortilèges 	PREDICTION:
# MOVIE:  Cat Hairs 	PREDICTION:
# MOVIE:  Here Come the Marines 	PREDICTION:
# MOVIE:  X Marks the Spot 	PREDICTION:
# MOVIE:  The Fatal Contract 	PREDICTION:  Mystery
# MOVIE:  Sinners' Parade 	PREDICTION:
# MOVIE:  Shock Ending 	PREDICTION:  Horror
# MOVIE:  Undercover Doctor 	PREDICTION:
# MOVIE:  Due Magnum .38 per una città di carogne 	PREDICTION:  Comedy
# MOVIE:  Billy 	PREDICTION:
# MOVIE:  Let It Be 	PREDICTION:  Documentary,Music
# MOVIE:  Chronos 	PREDICTION:
# MOVIE:  Liberated: The New Sexual Revolution 	PREDICTION:  Documentary
# MOVIE:  From Bedrooms to Billions: The Amiga Years 	PREDICTION:  Documentary,Music
# MOVIE:  In Pursuit of Silence 	PREDICTION:  Documentary
# MOVIE:  Off the Rails 	PREDICTION:  Drama
# MOVIE:  Panic: The Untold Story of the 2008 Financial Crisis 	PREDICTION:  Documentary
# MOVIE:  Let's Spend the Night Together 	PREDICTION:  Music
# MOVIE:  The Newspaperman: The Life and Times of Ben Bradlee 	PREDICTION:
# MOVIE:  Eadweard Muybridge, Zoopraxographer 	PREDICTION:  Documentary
# MOVIE:  Rising Son: The Legend of Skateboarder Christian Hosoi 	PREDICTION:
# MOVIE:  The Upsetter: The Life and Music of Lee Scratch Perry 	PREDICTION:  Music
# MOVIE:  The Harmony Game 	PREDICTION:  Documentary,Music
# MOVIE:  Ghosts of Abu Ghraib 	PREDICTION:
# MOVIE:  The Beatles on the Rooftop 	PREDICTION:  Documentary,Music
# MOVIE:  Rhyme & Reason 	PREDICTION:  Documentary
# MOVIE:  Fred: The Movie 	PREDICTION:  Documentary
# MOVIE:  Italianamerican 	PREDICTION:  Documentary
# MOVIE:  40 Years of Rocky: The Birth of a Classic 	PREDICTION:  Documentary
# MOVIE:  The Hand Behind the Mouse: The Ub Iwerks Story 	PREDICTION:
# MOVIE:  Going Upriver: The Long War of John Kerry 	PREDICTION:  Documentary
# MOVIE:  Just for Kicks 	PREDICTION:  Documentary
# MOVIE:  Islamic Art: Mirror of the Invisible World 	PREDICTION:  Documentary
# MOVIE:  Laddie 	PREDICTION:
# MOVIE:  MicroPlanet 3D 	PREDICTION:
# MOVIE:  Gulîstan, Land of Roses 	PREDICTION:  Documentary
# MOVIE:  Why We Fight: War Comes to America 	PREDICTION:
# MOVIE:  What We Left Unfinished 	PREDICTION:  Documentary
# MOVIE:  Troll Champion: The Charlie Zelenoff Story 	PREDICTION:  Documentary
# MOVIE:  Hip-Hop: Beyond Beats & Rhymes 	PREDICTION:
# MOVIE:  Logistics 	PREDICTION:  Documentary
# MOVIE:  Decorating Disney: Halloween Magic 	PREDICTION:  Documentary
# MOVIE:  Sylvia Plath: Inside the Bell Jar 	PREDICTION:  Drama
# MOVIE:  What Tomorrow Brings 	PREDICTION:
# MOVIE:  Rocky III 	PREDICTION:
# MOVIE:  Martyrs 	PREDICTION:
# MOVIE:  We Need to Talk About Kevin 	PREDICTION:  Drama
# MOVIE:  The Florida Project 	PREDICTION:
# MOVIE:  Born a King 	PREDICTION:
# MOVIE:  Morvern Callar 	PREDICTION:  Drama
# MOVIE:  Lady Jane 	PREDICTION:
# MOVIE:  The Big Red One 	PREDICTION:  War
# MOVIE:  Hustle & Flow 	PREDICTION:
# MOVIE:  Body Shots 	PREDICTION:
# MOVIE:  The Cruel Sea 	PREDICTION:  War
# MOVIE:  Double Teamed 	PREDICTION:  Drama
# MOVIE:  I Shot Andy Warhol 	PREDICTION:  Drama
# MOVIE:  Beast of the Bering Sea 	PREDICTION:
# MOVIE:  War Flowers 	PREDICTION:  Drama
# MOVIE:  Fun 	PREDICTION:
# MOVIE:  The Boy in Blue 	PREDICTION:
# MOVIE:  The Christmas Shepherd 	PREDICTION:  Family,TV Movie
# MOVIE:  Here Comes the Navy 	PREDICTION:
# MOVIE:  Godspell: A Musical Based on the Gospel According to St. Matthew 	PREDICTION:
# MOVIE:  Trek: The Movie 	PREDICTION:
# MOVIE:  Copposites 	PREDICTION:
# MOVIE:  A Change of Heart 	PREDICTION:  Drama
# MOVIE:  Kids of the Round Table 	PREDICTION:
# MOVIE:  Thaala 	PREDICTION:
# MOVIE:  R.I.O.T.: The Movie 	PREDICTION:
# MOVIE:  The Sweetness of Life 	PREDICTION:
# MOVIE:  Sesame Street: Elmo's Magic Numbers 	PREDICTION:  Family
# MOVIE:  Home, Sweet Home 	PREDICTION:
# MOVIE:  Stanley Spring Fever 	PREDICTION:
# MOVIE:  Sex Hex 	PREDICTION:
# MOVIE:  Zero Patience 	PREDICTION:
# MOVIE:  Shrimp 	PREDICTION:
# MOVIE:  Möbius Bond 	PREDICTION:
# MOVIE:  She-Rex 	PREDICTION:
# MOVIE:  Motherboard 	PREDICTION:
# MOVIE:  Serpent's Lullaby 	PREDICTION:
# MOVIE:  Suez 	PREDICTION:
# MOVIE:  Escape From Iran: The Canadian Caper 	PREDICTION:
# MOVIE:  Love Somehow 	PREDICTION:
# MOVIE:  Going Attractions: The Definitive Story of the Movie Palace 	PREDICTION:  Documentary
# MOVIE:  Humanity Through the Ages 	PREDICTION:
# MOVIE:  How Should We Then Live? 	PREDICTION:
# MOVIE:  12 Feet Deep 	PREDICTION:
# MOVIE:  I Am Not a Serial Killer 	PREDICTION:
# MOVIE:  Haunted 	PREDICTION:
# MOVIE:  Dark Night of the Scarecrow 	PREDICTION:
# MOVIE:  From Beyond the Grave 	PREDICTION:
# MOVIE:  Mesa of Lost Women 	PREDICTION:  Science Fiction
# MOVIE:  Three on a Meathook 	PREDICTION:
# MOVIE:  Dreamaniac 	PREDICTION:
# MOVIE:  The Thing Below 	PREDICTION:  Science Fiction
# MOVIE:  Uninhabited 	PREDICTION:
# MOVIE:  Desert of Blood 	PREDICTION:  Horror
# MOVIE:  Christmas Slay 	PREDICTION:
# MOVIE:  At The Door 	PREDICTION:  Science Fiction
# MOVIE:  American Exorcist 	PREDICTION:  Drama,Horror
# MOVIE:  Eden Lodge 	PREDICTION:
# MOVIE:  iPsycho 	PREDICTION:  Horror
# MOVIE:  The Strange Case of Doctor Rx 	PREDICTION:  Crime
# MOVIE:  Remote Viewing 	PREDICTION:
# MOVIE:  A Chronicle of Corpses 	PREDICTION:
# MOVIE:  Penanggal 	PREDICTION:
# MOVIE:  S.I.D.S. 	PREDICTION:
# MOVIE:  Hank Boyd Is Dead 	PREDICTION:
# MOVIE:  MDNA World Tour 	PREDICTION:  Music
# MOVIE:  The Raconteurs -  Live at Montreux 	PREDICTION:  Music
# MOVIE:  Hearts of Fire 	PREDICTION:
# MOVIE:  When It Rains 	PREDICTION:
# MOVIE:  Idina Menzel Live: Barefoot at the Symphony 	PREDICTION:  Music
# MOVIE:  Diana! 	PREDICTION:  Music
# MOVIE:  Steve Vai: Stillness in Motion - Vai Live in L.A. 	PREDICTION:  Music
# MOVIE:  Roy Orbison: Black and White Night 30 	PREDICTION:  Music
# MOVIE:  Meat Loaf: In and Out of Hell 	PREDICTION:  Documentary
# MOVIE:  Swing It... Baby! 	PREDICTION:
# MOVIE:  Australian Homecoming 	PREDICTION:  Documentary,Music
# MOVIE:  Cloud Cult - Arts in Nature Festival 	PREDICTION:  Music
# MOVIE:  I Haven't Done Sh*t This Year: Part 2 	PREDICTION:
# MOVIE:  Records Collecting Dust II 	PREDICTION:  Documentary,Music
# MOVIE:  The Revelers 	PREDICTION:
# MOVIE:  Sodom: Live Depravity 	PREDICTION:  Music
# MOVIE:  Spacehog: Summerland 2014 	PREDICTION:  Music
# MOVIE:  Car Seat Headrest: KEXP Sessions 	PREDICTION:
# MOVIE:  Up the Shambles – Live in Manchester 	PREDICTION:  Music
# MOVIE:  Akram Khan's Giselle 	PREDICTION:
# MOVIE:  Elvis ’68 Comeback Special 	PREDICTION:  Music
# MOVIE:  Georges Bizet: Carmen 	PREDICTION:
# MOVIE:  Ayreon: The Making of The Human Equation 	PREDICTION:
# MOVIE:  Queens Of The Stone Age: Live at SouthSide festival 2013 	PREDICTION:
# MOVIE:  Salvation RMX 	PREDICTION:
# MOVIE:  Elizabeth Harvest 	PREDICTION:
# MOVIE:  The Stranger Within 	PREDICTION:  Drama
# MOVIE:  Isn't It Shocking? 	PREDICTION:
# MOVIE:  The Last Night 	PREDICTION:  Drama
# MOVIE:  Casting the Runes 	PREDICTION:
# MOVIE:  Hollywood Stadium Mystery 	PREDICTION:
# MOVIE:  The Acquittal 	PREDICTION:  Crime,Mystery
# MOVIE:  The Great Gambini 	PREDICTION:
# MOVIE:  Hopeless Romantic 	PREDICTION:  Comedy,Romance
# MOVIE:  Femalien 	PREDICTION:  Science Fiction
# MOVIE:  This Matter of Marriage 	PREDICTION:  Romance
# MOVIE:  The Lad from Old Ireland 	PREDICTION:
# MOVIE:  The Bachelor Father 	PREDICTION:
# MOVIE:  Daughters Courageous 	PREDICTION:  Drama
# MOVIE:  Vazhvey Maayam 	PREDICTION:
# MOVIE:  I Love That Crazy Little Thing 	PREDICTION:  Comedy,Romance
# MOVIE:  Deuce Coupe 	PREDICTION:
# MOVIE:  Lip Service 	PREDICTION:
# MOVIE:  Nothing but the Bests 	PREDICTION:
# MOVIE:  Dreaming Lhasa 	PREDICTION:
# MOVIE:  Sugar: Howling of Angel 	PREDICTION:
# MOVIE:  A.I. Love You 	PREDICTION:
# MOVIE:  Days Of Dirt 	PREDICTION:
# MOVIE:  Genesis II 	PREDICTION:  Animation,Science Fiction
# MOVIE:  Micronauts 	PREDICTION:
# MOVIE:  Alien Agenda: Project Grey 	PREDICTION:  Thriller,Science Fiction
# MOVIE:  Planet of the Vampire Women 	PREDICTION:
# MOVIE:  Running the Gammatar 	PREDICTION:  Comedy
# MOVIE:  Silveraven 	PREDICTION:  Science Fiction
# MOVIE:  The Stowaway 	PREDICTION:
# MOVIE:  The Electronic Diaries 	PREDICTION:
# MOVIE:  Presumed Dead In Paradise 	PREDICTION:  Drama
# MOVIE:  His Double Life 	PREDICTION:  Drama
# MOVIE:  A Mother's Crime 	PREDICTION:
# MOVIE:  White Water 	PREDICTION:
# MOVIE:  Mysterious Creatures 	PREDICTION:  Drama
# MOVIE:  Lock, Stock and Barrel 	PREDICTION:
# MOVIE:  Diary of a Young Comic 	PREDICTION:
# MOVIE:  The Adderall Diaries 	PREDICTION:
# MOVIE:  Alcoholist 	PREDICTION:
# MOVIE:  Trip with the Teacher 	PREDICTION:
# MOVIE:  Grindstone Road 	PREDICTION:
# MOVIE:  Idiot Box 	PREDICTION:
# MOVIE:  Ambush Bay 	PREDICTION:
# MOVIE:  Shooting Captured Insurgents 	PREDICTION:
# MOVIE:  The 7th Match 1979 	PREDICTION:
# MOVIE:  The Moonlighter 	PREDICTION:
# MOVIE:  The Round-Up 	PREDICTION:
# MOVIE:  Trailin' West 	PREDICTION:
# MOVIE:  Sheriff of Wichita 	PREDICTION:
# MOVIE:  Robin Hood of Monterey 	PREDICTION:
# MOVIE:  Outgunned 	PREDICTION:
# MOVIE:  Seven Guns to Mesa 	PREDICTION:  Western
# MOVIE:  Hell Canyon Outlaws 	PREDICTION:  Western
# MOVIE:  The Border Menace 	PREDICTION:

# %%
def precision_recall(gt,preds):
    TP=0
    FP=0
    FN=0
    for t in gt:
        if t in preds:
            TP+=1
        else:
            FN+=1
    for p in preds:
        if p not in gt:
            FP+=1
    if TP+FP==0:
        precision=0
    else:
        precision=TP/float(TP+FP)
    if TP+FN==0:
        recall=0
    else:
        recall=TP/float(TP+FN)
    return precision,recall

# %%
precs=[]
recs=[]
for i in range(len(test_movies)):
    if i%1==0:
        pos=test_movies[i]
        #test_movie=movies_with_overviews[pos]
        gtids=df.genre_ids[pos]
        gt=[]
        for g in gtids:
            g_name=Genre_ID_to_name[g]
            gt.append(g_name)
#         print predictions[i],movies_with_overviews[i]['title'],gt
        a,b=precision_recall(gt,predictionsnb[i])
        precs.append(a)
        recs.append(b)

print(np.mean(np.asarray(precs)),np.mean(np.asarray(recs)))
print("Average = ",(np.mean(np.asarray(precs))+np.mean(np.asarray(recs)))/2)
# Out:
# 0.27482538079609525 0.1998775261177432
# Average =  0.23735145345691921

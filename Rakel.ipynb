# %%
# !pip install tmdbsimple scikit-multilearn

import pandas as pd
import numpy as np
import pickle
import tmdbsimple as tmdb
# Out:
# Collecting tmdbsimple
#   Downloading https://files.pythonhosted.org/packages/c5/19/0be154947cf93a6351d48bb9da208e612f43fefd464ef246e91ef233da35/tmdbsimple-2.2.5-py2.py3-none-any.whl
# Collecting scikit-multilearn
#   Downloading https://files.pythonhosted.org/packages/bb/1f/e6ff649c72a1cdf2c7a1d31eb21705110ce1c5d3e7e26b2cc300e1637272/scikit_multilearn-0.2.0-py3-none-any.whl (89kB)
#      |████████████████████████████████| 92kB 7.6MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from tmdbsimple) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->tmdbsimple) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->tmdbsimple) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->tmdbsimple) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->tmdbsimple) (2020.4.5.1)
# Installing collected packages: tmdbsimple, scikit-multilearn
# Successfully installed scikit-multilearn-0.2.0 tmdbsimple-2.2.5

# %%
df = pd.DataFrame()
df = pd.read_csv("/content/drive/My Drive/last.csv", engine="python")

from ast import literal_eval
df.genre_ids=df.genre_ids.apply(literal_eval)

api_key = "d0ccc864ded48afb6a7e28b2d32001ed"
tmdb.API_KEY = api_key

genres=tmdb.Genres()
list_of_genres=genres.movie_list()['genres']
Genre_ID_to_name={}
for i in range(len(list_of_genres)):
    genre_id=list_of_genres[i]['id']
    genre_name=list_of_genres[i]['name']
    Genre_ID_to_name[genre_id]=genre_name

genres=[]
all_ids=[]
for i in range(len(df)):
    id=df.id[i]
    genre_ids=df.genre_ids[i]
    genres.append(genre_ids)
    all_ids.extend(genre_ids)

from sklearn.preprocessing import MultiLabelBinarizer
mlb=MultiLabelBinarizer()
Y=mlb.fit_transform(genres)

from sklearn.feature_extraction.text import CountVectorizer
import re

content=[]
for i in range(len(df)):
    id=df.id[i]
    overview=df.overview[i]
    overview=overview.replace(',','')
    overview=overview.replace('.','')
    content.append(overview)

vectorize=CountVectorizer(max_df=0.95, min_df=0.005)
X=vectorize.fit_transform(content)

from sklearn.feature_extraction.text import TfidfTransformer
tfidf_transformer = TfidfTransformer()
X_tfidf = tfidf_transformer.fit_transform(X)

msk = np.random.rand(X_tfidf.shape[0]) < 0.8

X_train_tfidf=X_tfidf[msk]
X_test_tfidf=X_tfidf[~msk]
Y_train=Y[msk]
Y_test=Y[~msk]

positions=range(len(df))
# print positions
test_movies=np.asarray(positions)[~msk]

genre_names = []
for id in df.genre_ids:
  for i in id:
    genre_name=Genre_ID_to_name[i]
    genre_names.append(genre_name)
genre_names = set(genre_names)

genre_list=sorted(list(Genre_ID_to_name.keys()))
print(genre_list)
# Out:
# [12, 14, 16, 18, 27, 28, 35, 36, 37, 53, 80, 99, 878, 9648, 10402, 10749, 10751, 10752, 10770]

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from skmultilearn.ensemble import RakelD

classifier = RakelD(
    base_classifier=SVC(),
    base_classifier_require_dense=[True, True],
    labelset_size=3
)

classifier.fit(X[msk].toarray(), Y_train)

# %%
classifier._label_count
# Out:
# 19

# %%
preds=classifier.predict(X[~msk].toarray())

# %%
from sklearn.metrics import classification_report

print(classification_report(Y_test, preds, target_names=genre_names))

# %%
preds = preds.toarray()

# %%
predictions=[]
for i in range(X_test_tfidf.shape[0]):
    pred_genres=[]
    movie_label_scores=preds[i]
    for j in range(19):
        #print j
        if movie_label_scores[j]!=0:
            genre=Genre_ID_to_name[genre_list[j]]
            pred_genres.append(genre)
    predictions.append(pred_genres)

for i in range(X_test_tfidf.shape[0]):
    if i%50==0 and i!=0:
        print('MOVIE: ',df.title[test_movies[i]],'\tPREDICTION: ',','.join(predictions[i]))
# Out:
# MOVIE:  A View to a Kill 	PREDICTION:  Action
# MOVIE:  Surrogates 	PREDICTION:
# MOVIE:  Ben 10: Race Against Time 	PREDICTION:  Animation,Action,Comedy,Family
# MOVIE:  Freelancers 	PREDICTION:  Action,Western,Thriller,Crime
# MOVIE:  Bounty Killer 	PREDICTION:  History,Documentary
# MOVIE:  Gotcha! 	PREDICTION:  Drama
# MOVIE:  Sniper 3 	PREDICTION:  Action,Crime
# MOVIE:  Pink Cadillac 	PREDICTION:  Drama,Thriller
# MOVIE:  Money for Nothing 	PREDICTION:  Action,Comedy,Thriller,Crime
# MOVIE:  PAW Patrol: Mighty Pups 	PREDICTION:  Adventure,Animation,Comedy,Family
# MOVIE:  Blood Shot 	PREDICTION:  Animation
# MOVIE:  The Raspberry Reich 	PREDICTION:  Drama
# MOVIE:  Fire from Below 	PREDICTION:
# MOVIE:  Nuclear Hurricane 	PREDICTION:  Action,Science Fiction
# MOVIE:  Aux 	PREDICTION:  Drama,War
# MOVIE:  No Contest 	PREDICTION:
# MOVIE:  Fury: The Tales of Ronan Pierce 	PREDICTION:  Action,Thriller,Crime
# MOVIE:  OSS 117: Panic in Bangkok 	PREDICTION:  Horror,Action,Science Fiction
# MOVIE:  The Camp on Blood Island 	PREDICTION:  Drama,War
# MOVIE:  Killing American Style 	PREDICTION:  Drama,Action,Western,Thriller,Crime
# MOVIE:  National Lampoon Presents The Beach Party at the Threshold of Hell 	PREDICTION:  Adventure,Action
# MOVIE:  Hardflip 	PREDICTION:  Drama,Family
# MOVIE:  The Fighting Fool 	PREDICTION:  Adventure,Action
# MOVIE:  Code Name: Wolverine 	PREDICTION:  Action,Comedy,Thriller
# MOVIE:  Legion of Iron 	PREDICTION:  Fantasy,Horror
# MOVIE:  Report 51 	PREDICTION:  Horror,Science Fiction
# MOVIE:  The Wylds: The Adventures of Chris Fable 	PREDICTION:  Fantasy,Drama,Family
# MOVIE:  Barood 	PREDICTION:  Action,Thriller,Crime
# MOVIE:  Honor Bound 	PREDICTION:  Drama,War
# MOVIE:  Hero: Jangan Bikin Panas 	PREDICTION:  Drama,Action,Crime
# MOVIE:  Alone 	PREDICTION:  Horror
# MOVIE:  Condo Hell 	PREDICTION:  Horror,Thriller
# MOVIE:  Curse of Evil 	PREDICTION:
# MOVIE:  Mister Deathman 	PREDICTION:  Adventure,Drama,Action
# MOVIE:  Elevator 	PREDICTION:  Animation,Comedy
# MOVIE:  Ms. Cannibal Holocaust 	PREDICTION:  Horror,Thriller
# MOVIE:  Odin's Afterbirth 	PREDICTION:  Animation,Documentary
# MOVIE:  Stardust 	PREDICTION:  Fantasy,Animation,Family
# MOVIE:  Year One 	PREDICTION:  Adventure,Fantasy,Horror
# MOVIE:  Barbie: Dolphin Magic 	PREDICTION:  Comedy
# MOVIE:  Copenhagen 	PREDICTION:  Adventure,Drama
# MOVIE:  The Final Sacrifice 	PREDICTION:  Adventure,Drama,Action
# MOVIE:  After School Special 	PREDICTION:  Comedy,Thriller
# MOVIE:  Lost Wilderness 	PREDICTION:  Horror,Family
# MOVIE:  The Night Train to Kathmandu 	PREDICTION:  Drama,Romance,TV Movie
# MOVIE:  Night of the Fox 	PREDICTION:  Drama,War
# MOVIE:  Thrill Ride: The Science of Fun 	PREDICTION:  Animation,Documentary
# MOVIE:  Trang Quynh 	PREDICTION:
# MOVIE:  It's Not Cricket 	PREDICTION:  Drama,War
# MOVIE:  Mutiny Ahead 	PREDICTION:  Adventure,Mystery
# MOVIE:  The Robotanist 	PREDICTION:  Adventure,Science Fiction,Family
# MOVIE:  Kald Krig og Røde Flasker 	PREDICTION:  Adventure,Drama,Action,Thriller
# MOVIE:  The Old Prospector 	PREDICTION:  Horror
# MOVIE:  Hard XS 	PREDICTION:  Adventure,Documentary,Music
# MOVIE:  Sherlock Gnomes 	PREDICTION:  Thriller,Mystery
# MOVIE:  Lego Star Wars: The Padawan Menace 	PREDICTION:  Adventure,Action,Comedy,Science Fiction
# MOVIE:  Tigger & Pooh and a Musical Too 	PREDICTION:  Animation,Comedy,Family
# MOVIE:  Barbie and The Sensations: Rockin' Back to Earth 	PREDICTION:  Animation
# MOVIE:  Elmer Elephant 	PREDICTION:  Animation,Comedy
# MOVIE:  Mickey's Kangaroo 	PREDICTION:  Comedy,Western
# MOVIE:  Dough Ray Me-ow 	PREDICTION:  Animation,Comedy
# MOVIE:  The Christmas Tree 	PREDICTION:  Comedy,Family,TV Movie
# MOVIE:  The Vanishing Private 	PREDICTION:  Animation,Comedy,Family
# MOVIE:  One Cab's Family 	PREDICTION:  Drama,Romance
# MOVIE:  Bugs Bunny's Mad World of Television  	PREDICTION:  Comedy,Family
# MOVIE:  The Counterfeit Cat 	PREDICTION:  Animation,Comedy,Family
# MOVIE:  Mighty Mighty Monsters in New Fears Eve 	PREDICTION:  Animation,Horror,Comedy,Family,TV Movie
# MOVIE:  Rhapsody in Blue 	PREDICTION:  Comedy,Romance
# MOVIE:  The Teddy Bears' Christmas 	PREDICTION:  Animation,Comedy,Romance,Family
# MOVIE:  The Rude Intruder 	PREDICTION:
# MOVIE:  Anyway 	PREDICTION:  Animation,Documentary
# MOVIE:  Android 207 	PREDICTION:
# MOVIE:  Sobriety, Obesity & Growing Old 	PREDICTION:  History
# MOVIE:  Wednesday with Goddard 	PREDICTION:  Animation,Comedy,Family
# MOVIE:  Who's Who in the Zoo 	PREDICTION:  Animation,Documentary
# MOVIE:  The Legend of the Sky Kingdom 	PREDICTION:  Adventure,Fantasy,Science Fiction,Family
# MOVIE:  Crab 	PREDICTION:  Documentary
# MOVIE:  For the Love of God 	PREDICTION:  Fantasy,Drama
# MOVIE:  Grid Corrections 	PREDICTION:  Documentary,Science Fiction
# MOVIE:  Guest 	PREDICTION:  Horror,Science Fiction
# MOVIE:  One Night in December 	PREDICTION:  Animation,Documentary,Music
# MOVIE:  140 Characters 	PREDICTION:  Documentary
# MOVIE:  Small Things Moving in Unison 	PREDICTION:  Documentary
# MOVIE:  The Princess Diaries 2: Royal Engagement 	PREDICTION:  Romance,TV Movie
# MOVIE:  Second Act 	PREDICTION:  Drama,Comedy,Thriller,Romance,TV Movie
# MOVIE:  Heartbreakers 	PREDICTION:  Comedy
# MOVIE:  Two Night Stand 	PREDICTION:  Horror,Comedy,Thriller
# MOVIE:  The Weather Man 	PREDICTION:  Drama
# MOVIE:  Return of the Living Dead: Necropolis 	PREDICTION:  Adventure,Horror,Action,Science Fiction
# MOVIE:  The People Under the Stairs 	PREDICTION:  Drama
# MOVIE:  The D Train 	PREDICTION:  Drama,Comedy,Family
# MOVIE:  The Good Night 	PREDICTION:  Drama,Thriller,Romance
# MOVIE:  Wristcutters: A Love Story 	PREDICTION:  Action,Comedy,Thriller,Romance
# MOVIE:  Protocol 	PREDICTION:  Drama,Romance,TV Movie
# MOVIE:  The Best of Times 	PREDICTION:
# MOVIE:  Gray Matters 	PREDICTION:  Drama,Comedy,Romance
# MOVIE:  Matchstick Men 	PREDICTION:  Drama,Crime
# MOVIE:  Bart Got a Room 	PREDICTION:  Comedy,Romance,TV Movie
# MOVIE:  The Russians Are Coming, the Russians Are Coming 	PREDICTION:  Comedy
# MOVIE:  Get Santa 	PREDICTION:  Comedy,Family,TV Movie
# MOVIE:  Billy Connolly: Live in London 2010 	PREDICTION:  Documentary,Music
# MOVIE:  Hustler White 	PREDICTION:  Documentary
# MOVIE:  Sun Dogs 	PREDICTION:  Adventure,Drama,Comedy
# MOVIE:  Brian Regan: Nunchucks and Flamethrowers 	PREDICTION:  Comedy
# MOVIE:  Partners 	PREDICTION:  Drama,Action,Thriller,Crime,Mystery
# MOVIE:  Easy Living 	PREDICTION:  Comedy,Romance,Family
# MOVIE:  Captain January 	PREDICTION:  Drama,Romance,TV Movie
# MOVIE:  Measure of a Man 	PREDICTION:  Comedy
# MOVIE:  Blue Man Group: The Complex Rock Tour Live 	PREDICTION:  Documentary,Music
# MOVIE:  Shooting Elizabeth 	PREDICTION:  Drama,Thriller,Crime
# MOVIE:  Yes, God, Yes 	PREDICTION:  Comedy,Thriller,Romance,TV Movie
# MOVIE:  Billy Gardell: Halftime 	PREDICTION:  Comedy,Music,TV Movie
# MOVIE:  All Star Comedy Jam: Live from South Beach 	PREDICTION:  Comedy,Documentary,Music
# MOVIE:  It's Not a Date 	PREDICTION:  Animation,Comedy,Romance
# MOVIE:  The Chimp 	PREDICTION:  Comedy
# MOVIE:  Body Heat 	PREDICTION:  Drama,Thriller,Crime,Mystery,TV Movie
# MOVIE:  Chopper 	PREDICTION:  Drama,Crime
# MOVIE:  Hounds of Love 	PREDICTION:  Drama,Horror,Thriller
# MOVIE:  The Lookalike 	PREDICTION:  Drama,Crime
# MOVIE:  Stone of Destiny 	PREDICTION:  Documentary
# MOVIE:  The Undercover Man 	PREDICTION:  Action,Western,Thriller,Crime
# MOVIE:  The Black Dahlia Haunting 	PREDICTION:  Horror
# MOVIE:  A Christmas Mystery 	PREDICTION:  Thriller,Mystery,TV Movie
# MOVIE:  The Hands of Orlac 	PREDICTION:
# MOVIE:  Call Her Ganda 	PREDICTION:  Horror,Thriller
# MOVIE:  Prime Suspect 3: The Keeper of Souls 	PREDICTION:  Drama,Thriller,Crime,Mystery
# MOVIE:  Naked City: Justice with a Bullet 	PREDICTION:  Action,Comedy,Thriller,Crime
# MOVIE:  Racketeers in Exile 	PREDICTION:  Action,Crime
# MOVIE:  Corkscrew! 	PREDICTION:  Comedy
# MOVIE:  Turned Out: Sexual Assault Behind Bars 	PREDICTION:  Documentary
# MOVIE:  Quite Ugly One Morning 	PREDICTION:  Drama,Thriller,Crime,Mystery
# MOVIE:  A Promise to Carolyn 	PREDICTION:  Horror,Thriller
# MOVIE:  BlackJack: Ace Point Game 	PREDICTION:  Drama,Action,Thriller,Crime
# MOVIE:  The Hang Up 	PREDICTION:  Drama,Crime
# MOVIE:  Appleton 	PREDICTION:  Horror
# MOVIE:  Sensitive 70'S Turtleneck Tough Guys 	PREDICTION:
# MOVIE:  Know Your Money 	PREDICTION:  Documentary
# MOVIE:  Youth on Parole 	PREDICTION:  Action,Comedy,Western,Thriller,Crime
# MOVIE:  Taylor Swift: The 1989 World Tour - Live 	PREDICTION:  Documentary,Music
# MOVIE:  Cuba and the Cameraman 	PREDICTION:  Documentary
# MOVIE:  National Geographic: Journey to the Edge of the Universe 	PREDICTION:  Documentary,Music
# MOVIE:  Reversing Roe 	PREDICTION:  Documentary
# MOVIE:  Pink Floyd: Live at Pompeii 	PREDICTION:  Documentary,Music
# MOVIE:  The Green Prince 	PREDICTION:  Drama
# MOVIE:  49 Up 	PREDICTION:  Documentary,Music
# MOVIE:  Missing 411: The Hunted 	PREDICTION:  Documentary
# MOVIE:  Shadows of Sofia 	PREDICTION:  History,Documentary
# MOVIE:  Elton John: I'm Still Standing - A Grammy Salute 	PREDICTION:  Music
# MOVIE:  War of Words: Battle Rap in the UK 	PREDICTION:  Documentary
# MOVIE:  Bully. Coward. Victim. The Story of Roy Cohn 	PREDICTION:  Documentary
# MOVIE:  I Am Street Fighter 	PREDICTION:  Documentary
# MOVIE:  Detroit Under S.T.R.E.S.S. 	PREDICTION:  Action,Thriller,Crime
# MOVIE:  Burlesque: Heart of the Glitter Tribe 	PREDICTION:  Documentary
# MOVIE:  What Walaa Wants 	PREDICTION:  Drama,TV Movie
# MOVIE:  Strength and Honor: Creating the World of 'Gladiator' 	PREDICTION:  Documentary
# MOVIE:  Who F****d Up the Internet?! 	PREDICTION:  Documentary
# MOVIE:  Starwoids 	PREDICTION:  Documentary
# MOVIE:  Inside Supertramp 1974-1978 	PREDICTION:  Documentary,Music
# MOVIE:  A Boy Named Sue 	PREDICTION:  Drama,Family
# MOVIE:  Classic Albums: Peter Gabriel - So 	PREDICTION:  Documentary,Music
# MOVIE:  The Planets 	PREDICTION:  Documentary,Music
# MOVIE:  Iron and Beyond 	PREDICTION:  Animation,Documentary,Music
# MOVIE:  This Is Congo 	PREDICTION:  Documentary
# MOVIE:  Finger of God 	PREDICTION:  Documentary,Music
# MOVIE:  Spanish Bullfight 	PREDICTION:  Animation,Comedy
# MOVIE:  Twin Brothers 	PREDICTION:
# MOVIE:  American Hollow 	PREDICTION:  Documentary
# MOVIE:  Lost on Location: Behind the Scenes of 'Lost in Translation' 	PREDICTION:  Documentary,Music
# MOVIE:  Stan 	PREDICTION:
# MOVIE:  Cirque du Soleil: Toruk - The First Flight 	PREDICTION:  Adventure,Animation,Comedy,Family
# MOVIE:  Infinite Space: The Architecture of John Lautner 	PREDICTION:  Documentary
# MOVIE:  She Stole My Voice: A Documentary About Lesbian Rape 	PREDICTION:  Documentary
# MOVIE:  The Boys on the Bus 	PREDICTION:  Documentary
# MOVIE:  Eternal Sunshine of the Spotless Mind 	PREDICTION:  Comedy,Thriller,Romance
# MOVIE:  The Whole Truth 	PREDICTION:  Drama,Crime
# MOVIE:  Rain Man 	PREDICTION:  Adventure,Comedy
# MOVIE:  The Promise 	PREDICTION:  Drama,History,Music,Romance
# MOVIE:  You Don't Know Jack 	PREDICTION:  Documentary
# MOVIE:  The Color of Money 	PREDICTION:  Animation,Comedy
# MOVIE:  Atlas Shrugged: Part II 	PREDICTION:  Adventure,Action,Thriller,Science Fiction
# MOVIE:  A Cry in the Dark 	PREDICTION:  Drama,TV Movie
# MOVIE:  Ratcatcher 	PREDICTION:  Fantasy,Drama
# MOVIE:  Bleeding Heart 	PREDICTION:  Drama,Horror,Thriller
# MOVIE:  Desert Hearts 	PREDICTION:  Drama,Romance
# MOVIE:  Come Sunday 	PREDICTION:  Horror
# MOVIE:  Dishonored 	PREDICTION:  Adventure,Action
# MOVIE:  Blood Honey 	PREDICTION:  Drama,Thriller
# MOVIE:  The Story of Louis Pasteur 	PREDICTION:
# MOVIE:  A Woman, a Part 	PREDICTION:  Comedy,Romance,TV Movie
# MOVIE:  Five Moons Plaza 	PREDICTION:  Mystery
# MOVIE:  High Resolution 	PREDICTION:
# MOVIE:  The Undying Monster 	PREDICTION:  Horror,Thriller
# MOVIE:  Dakota's Summer 	PREDICTION:  Drama,TV Movie
# MOVIE:  The Incredible Mrs. Ritchie 	PREDICTION:  Drama,Crime
# MOVIE:  The 60 Yard Line 	PREDICTION:  Drama
# MOVIE:  Behind the Waterfall 	PREDICTION:  Adventure,Drama,Comedy,Family
# MOVIE:  Jamaica Tapes 	PREDICTION:  Documentary
# MOVIE:  Born Forbidden 	PREDICTION:  Drama,Romance,TV Movie
# MOVIE:  Don't Get Angry 	PREDICTION:  Documentary
# MOVIE:  Hasu 	PREDICTION:  Drama,Thriller,Romance,TV Movie
# MOVIE:  Mariah Carey: Merry Christmas to You 	PREDICTION:  Music
# MOVIE:  Four Winds Island Part One Shadows in the Wood 	PREDICTION:  Adventure,Horror
# MOVIE:  The Forgotten Carols 	PREDICTION:  Fantasy,Animation,Family
# MOVIE:  The Wonder Pets - Save The Bengal Tiger 	PREDICTION:  Animation,Comedy,Family
# MOVIE:  Invitation to the Dance 	PREDICTION:  Animation,Documentary
# MOVIE:  Encounter at Raven's Gate 	PREDICTION:  Comedy,Thriller,Mystery
# MOVIE:  East of Kensington 	PREDICTION:  Fantasy,Drama,Horror
# MOVIE:  Heroes of the Realm 	PREDICTION:  Adventure,Fantasy,Family
# MOVIE:  Abuelita Charlestón 	PREDICTION:  Comedy
# MOVIE:  Rock N Roll Dreams 	PREDICTION:  Fantasy,Drama,Comedy,Family
# MOVIE:  Some Mother's Son 	PREDICTION:  Drama,History,War
# MOVIE:  Soekarno 	PREDICTION:  Drama,History
# MOVIE:  The Siege of Sidney Street 	PREDICTION:  Action,Thriller,Crime
# MOVIE:  Naval Sham Battle at Newport 	PREDICTION:  Animation,Science Fiction,War
# MOVIE:  The 43 Group: The Unfinished War 	PREDICTION:  Drama,Action,War
# MOVIE:  The Song of Taras Bulba 	PREDICTION:  Documentary
# MOVIE:  Pet Sematary II 	PREDICTION:  Drama,Comedy
# MOVIE:  The Devil's Hand 	PREDICTION:  Horror
# MOVIE:  Beneath 	PREDICTION:  Drama,Thriller,Mystery,TV Movie
# MOVIE:  The Dead Room 	PREDICTION:  Horror,Thriller
# MOVIE:  Intangents 	PREDICTION:  Horror,Science Fiction
# MOVIE:  The Watermen 	PREDICTION:  Action
# MOVIE:  Horror 	PREDICTION:  Horror
# MOVIE:  The Hideout 	PREDICTION:
# MOVIE:  After... 	PREDICTION:  Horror,Science Fiction
# MOVIE:  UKM: The Ultimate Killing Machine 	PREDICTION:  Comedy,Family
# MOVIE:  The House That Would Not Die 	PREDICTION:  Fantasy,Horror
# MOVIE:  Bunni 	PREDICTION:  Horror,Thriller
# MOVIE:  The Horrible Dr. Hichcock 	PREDICTION:  Drama,Thriller,Crime
# MOVIE:  Alien: Covenant – Epilogue: Advent 	PREDICTION:  Adventure,Action,Science Fiction
# MOVIE:  Deep Tissue 	PREDICTION:
# MOVIE:  Alien Seed 	PREDICTION:  Horror,Action,Science Fiction
# MOVIE:  Altered Skin 	PREDICTION:  Drama,Thriller
# MOVIE:  Macabre Pair of Shorts 	PREDICTION:  Horror,Comedy
# MOVIE:  The Wolf Who Came to Dinner 	PREDICTION:  Horror,Thriller
# MOVIE:  Alone in the Dead of Night 	PREDICTION:  Horror,Thriller
# MOVIE:  S.I.D.S. 	PREDICTION:  Drama
# MOVIE:  #babynymph 	PREDICTION:
# MOVIE:  Legend of the Blue Hole 	PREDICTION:  Documentary
# MOVIE:  Gorillaz: Live in Manchester 	PREDICTION:  Documentary,Music
# MOVIE:  Paul Rodgers: Live in Glasgow 	PREDICTION:  Documentary,Music
# MOVIE:  Larceny with Music 	PREDICTION:  Romance
# MOVIE:  Gangster Rock 	PREDICTION:  Crime
# MOVIE:  Nine Inch Nails: The Downward Spiral Live 	PREDICTION:  Documentary,Music
# MOVIE:  Senorita from the West 	PREDICTION:  Comedy,Romance,TV Movie
# MOVIE:  Kiss The Lost Concert 	PREDICTION:  Documentary,Music
# MOVIE:  Amy Winehouse Live Shepherd's Bush Empire 	PREDICTION:  Music
# MOVIE:  Say One for Me 	PREDICTION:  Comedy,TV Movie
# MOVIE:  Double Pisces, Scorpio Rising 	PREDICTION:  Horror,Comedy
# MOVIE:  Eternal Funeral 	PREDICTION:  Documentary
# MOVIE:  R.E.M. - Automatic Unearthed 	PREDICTION:  Documentary,Music
# MOVIE:  Elixir of Love 	PREDICTION:  Music
# MOVIE:  The Captain's Kid 	PREDICTION:  Family
# MOVIE:  Make Believe Ballroom 	PREDICTION:  Music
# MOVIE:  Duran Duran - Live At Wembley Arena 	PREDICTION:  Music
# MOVIE:  The Naked Brothers Band: Operation Mojo 	PREDICTION:  Drama
# MOVIE:  The Mission: Lighting the Candles 	PREDICTION:  Music
# MOVIE:  On the Come Up at the Source Awards 	PREDICTION:  Adventure,Documentary
# MOVIE:  EN SHAMBLÉ 	PREDICTION:  Music
# MOVIE:  On The Flip Side 	PREDICTION:  Music,TV Movie
# MOVIE:  The Fall ‎– Perverted By Language//Bis + Live At Leeds 	PREDICTION:  Music
# MOVIE:  Pink Floyd Beginnings 1967-1972 	PREDICTION:  Documentary,Music
# MOVIE:  Maze Featuring Frankie Beverly: Live in New Orleans 	PREDICTION:  Documentary,Music
# MOVIE:  Honeymoon Lodge 	PREDICTION:  Comedy,Family
# MOVIE:  The Man in 3B 	PREDICTION:  Comedy,Thriller,Romance,TV Movie
# MOVIE:  The Big Cube 	PREDICTION:  Thriller,Crime
# MOVIE:  The Silk Express 	PREDICTION:  Action,Thriller,Crime
# MOVIE:  The Man from Nowhere 	PREDICTION:  Drama,Thriller,Romance
# MOVIE:  Once Upon a Dead Man 	PREDICTION:  Drama,Thriller,Crime,Mystery
# MOVIE:  Geometric Conspiracy 	PREDICTION:
# MOVIE:  1126 Dewey Ave. Apt. 207 	PREDICTION:
# MOVIE:  Original Sins 	PREDICTION:  Drama,Thriller,Crime,Mystery
# MOVIE:  Wedding March 4: Something Old, Something New 	PREDICTION:  Comedy,Romance
# MOVIE:  Christmas in Montana 	PREDICTION:  Western,Romance,Family,TV Movie
# MOVIE:  Almost You 	PREDICTION:  Drama,Thriller,Romance
# MOVIE:  Our Betters 	PREDICTION:  Documentary
# MOVIE:  Pie in the Sky 	PREDICTION:  Comedy,Romance
# MOVIE:  The Waiting Game 	PREDICTION:  Adventure,Romance
# MOVIE:  The Diary of Preston Plummer 	PREDICTION:  Drama,Thriller,Romance
# MOVIE:  The Singing Marine 	PREDICTION:  Comedy,Romance
# MOVIE:  Woman in a Dressing Gown 	PREDICTION:  Drama,Thriller,Romance,TV Movie
# MOVIE:  Eva 	PREDICTION:  Drama,Romance
# MOVIE:  OPA! 	PREDICTION:
# MOVIE:  Seven Lovers 	PREDICTION:  Drama,Comedy,Romance
# MOVIE:  Such Beautiful People 	PREDICTION:  Documentary
# MOVIE:  Winter Carnival 	PREDICTION:  Romance,TV Movie
# MOVIE:  Warlords of the 21st Century 	PREDICTION:  Adventure,Science Fiction
# MOVIE:  Bipedalism 	PREDICTION:  Documentary
# MOVIE:  Beer Money 	PREDICTION:  Horror,Comedy,Science Fiction
# MOVIE:  Three's A Shroud 	PREDICTION:  Documentary
# MOVIE:  Dark Harbour 	PREDICTION:  Comedy,Thriller,Romance
# MOVIE:  Knightmare 	PREDICTION:
# MOVIE:  Two Worlds 	PREDICTION:  Adventure,Action,Science Fiction
# MOVIE:  Somnolence 	PREDICTION:  Adventure,Action,Thriller,Science Fiction
# MOVIE:  The Wrong Babysitter 	PREDICTION:  Drama,Thriller,Mystery,TV Movie
# MOVIE:  The Portrait 	PREDICTION:  Drama,Horror,TV Movie
# MOVIE:  The Ambush Murders 	PREDICTION:  Drama,Action
# MOVIE:  What If I'm Gay? 	PREDICTION:  Adventure,Drama,Action
# MOVIE:  A Midsummer's Nightmare 	PREDICTION:  Horror,Thriller,Science Fiction
# MOVIE:  Panic in Echo Park 	PREDICTION:  Drama,Crime
# MOVIE:  Rideshare 	PREDICTION:  Documentary,Music
# MOVIE:  Element 	PREDICTION:  Horror,Thriller
# MOVIE:  Sight Unseen 	PREDICTION:  Drama,Thriller,Crime,Mystery
# MOVIE:  The Name of the Game Is Kill 	PREDICTION:  Horror,Thriller
# MOVIE:  Saving Jessica Lynch 	PREDICTION:  Drama,War
# MOVIE:  This Was Paris 	PREDICTION:  War
# MOVIE:  The Hole In The Ground 	PREDICTION:  Documentary,War
# MOVIE:  The Bull Of The West 	PREDICTION:  Music
# MOVIE:  The Lonely Trail 	PREDICTION:  Drama,Western,War
# MOVIE:  The Hard Hombre 	PREDICTION:  Comedy,Western
# MOVIE:  Adventures in Silverado 	PREDICTION:
# MOVIE:  Noon Wine 	PREDICTION:  Documentary,Music
# MOVIE:  Trail of Terror 	PREDICTION:  Drama,Action,Western,Crime
# MOVIE:  Outcasts of Black Mesa 	PREDICTION:  Action,Western,Crime
# MOVIE:  Riders of the Badlands 	PREDICTION:  Drama,History,Western,Crime
# MOVIE:  Water, Water, Everywhere 	PREDICTION:  Romance
# MOVIE:  Between Fighting Men 	PREDICTION:  Drama,Action,Western,Crime

# %%
def precision_recall(gt,preds):
    TP=0
    FP=0
    FN=0
    for t in gt:
        if t in preds:
            TP+=1
        else:
            FN+=1
    for p in preds:
        if p not in gt:
            FP+=1
    if TP+FP==0:
        precision=0
    else:
        precision=TP/float(TP+FP)
    if TP+FN==0:
        recall=0
    else:
        recall=TP/float(TP+FN)
    return precision,recall

# %%
precs=[]
recs=[]
for i in range(len(test_movies)):
    if i%1==0:
        pos=test_movies[i]
        #test_movie=movies_with_overviews[pos]
        gtids=df.genre_ids[pos]
        gt=[]
        for g in gtids:
            g_name=Genre_ID_to_name[g]
            gt.append(g_name)
#         print predictions[i],movies_with_overviews[i]['title'],gt
        a,b=precision_recall(gt,predictions[i])
        precs.append(a)
        recs.append(b)

print(np.mean(np.asarray(precs)),np.mean(np.asarray(recs)))
print("Average = ",(np.mean(np.asarray(precs))+np.mean(np.asarray(recs)))/2)
# Out:
# 0.45929269280986895 0.538371677697237
# Average =  0.498832185253553
